# %% [markdown]
# # first re-capitulate how to find modules with clusters of samples

# %%
import sys
import datetime
import time



from sklearn.decomposition import NMF
import numpy as np
import pandas as pd
from datetime import date
today = str(date.today())

import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

BelugaMode = False
#saveDHSmat = True


# several parameters
axis_fontsize = 30
myrandom = 0
customthresh = 0.5

def mytime():
	ts = time.time()
	sttime = datetime.datetime.fromtimestamp(ts).strftime('%Y%m%d_%H:%M:%S')
	return sttime
print('starting at ', mytime(), flush=True)

def increase_axis_fontsize():
	ax = plt.gca()
	ticklabels = ax.get_xticklabels()
	for label in ticklabels:
		label.set_fontsize(axis_fontsize)
		label.set_family('serif')
	ticklabels = ax.get_yticklabels()
	for label in ticklabels:
		label.set_fontsize(axis_fontsize)
		label.set_family('serif')
		
def make_bar_plot(Nrelevant, BarMatrix, bargraph_out, plotClusterMode=False, barsortorder=[], clusterTopLabels=[], myNMFcomps=16):
	if len(barsortorder)<1:
		barsortorder = np.arange(Nrelevant)
	ttt = np.arange(Nrelevant)
	start = 0
	end = Nrelevant
	ground_pSample = ttt*0
	plt.clf()
	plt.figure(figsize=(150,40))
	plt.bar(ttt[start:end], BarMatrix[0,start:end][barsortorder], color='r',
             bottom=ground_pSample[start:end], alpha=0.75)
	ground_pSample = BarMatrix[0,start:end][barsortorder]
	for i in range(1,myNMFcomps):
		plt.bar(ttt[start:end],BarMatrix[i,start:end][barsortorder], bottom = ground_pSample, color=Comp_colors[i], alpha=0.75)
		ground_pSample = np.sum(BarMatrix[0: i+1,start:end], axis=0)[barsortorder]
	increase_axis_fontsize()
	plt.ylabel('sum of signal in matrix',fontsize=70)
	#plt.title('Full Sample',fontsize=70)
	samplenamesize = 27
	thebottom = 0.25
	if (BelugaMode):
		samplenamesize = 11
		thebottom = 0.15
	if(plotClusterMode):
		plt.xticks(ttt, ttt.astype(str), rotation='vertical', fontsize=samplenamesize)
		if len(clusterTopLabels) > 0:
			ax = plt.gca()
			ax2 = ax.twiny()
			ax2.set_xticks(ttt)
			ax2.set_xticklabels(clusterTopLabels.astype(str), rotation=90, fontsize=samplenamesize)
			#ax.xaxis.tick_top()
			#plt.xticks(ttt, clusterTopLabels.astype(str), rotation='vertical', fontsize=samplenamesize)
	else:
		plt.xticks(ttt, names[barsortorder], rotation='vertical', fontsize=samplenamesize)	
	plot_margin = 5
	plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=thebottom)
	plt.savefig(bargraph_out)
	plt.close()	

#Nsamples
if (BelugaMode):
	Nsamples = 827
	NMFcomps = 0 #will be assigned later
	B = pd.read_table('colTitles_friendly.txt', header=None)
	names = B[1].values
else:
	Nsamples = 176
	NMFcomps = 16 #has to be set here since NMF will be done on the spot
	B = pd.read_table('rowTitles.txt', header=None)
	names = B[0].values


if (BelugaMode):
	if (len(sys.argv) < 3):
		print ('syntax: blah.py pickle1(daslog) pickle2(daslog2)')
		sys.exit()
	finname1 = str(sys.argv[1])
	finname2 = str(sys.argv[2])
	print('starting read at ', mytime(), flush=True)
	A = pd.read_table('masterListPresenceAbsence_827samples_FDR0.0010_hg38.bed')
	print('finished read at ', mytime(), flush=True)
	print(A.head())
	print(A.shape)
	a = A.drop([A.columns[0], A.columns[1], A.columns[2]], axis=1).values
	a = a.T
	print('finished drop at ', mytime(), flush=True)
	del(A)
else:
	IslandSize = 400
	finname = 'mtxlist.txt'
	f = open(finname, 'r')
	dars = f.readlines()
	featurelist = []
	for line in dars:
		g = np.loadtxt(line.strip())
		#daslog = np.log10(g+1)
		daslog = (g > 0).astype(int) 
		if (daslog.shape[1] != IslandSize):
			daslog = daslog[:,:IslandSize]
		featurelist.append(daslog)
	featurelist = np.array(featurelist)
	a = np.copy(featurelist[0])
	for i in range(499):
		a= np.append(a, featurelist[i+1], axis=1)
	#print (a.shape)


if (BelugaMode):
	print('starting read NMF results at ', mytime(), flush=True)
	BasisMat = np.load(finname1)
	MixtureMat = np.load(finname2)
else:
	model = NMF(n_components=NMFcomps, init='random', random_state=0)
	BasisMat = model.fit_transform(a) 
	MixtureMat = model.components_
	print(model.reconstruction_err_)

reconstruction = np.dot(BasisMat, MixtureMat)
NMFcomps = BasisMat.shape[1]
NDHS = MixtureMat.shape[1]

Comp_colors = ['red', 'tan', 'lime','blue','m','k','c', 'coral', 'indigo','darkgreen','orange','grey','gold', 'lightskyblue', 'peru', 'olive']
if (NMFcomps>16):
	from matplotlib import colors as mcolors
	colornames = list(mcolors.CSS4_COLORS.keys())
	count = 16
	while (count < NMFcomps):
		newcolor = colornames[np.random.randint(0,len(colornames))]
		trialcount = 0
		while ((newcolor in Comp_colors) and (trialcount < 100)):
			newcolor = colornames[np.random.randint(0,len(colornames))]
			trialcount+=1
		Comp_colors.append(newcolor)
		count+=1
		
#for now lets just do unweighted version
# Out:
# starting at  20170630_17:03:49
# 1081.9722798050345

# %%
#calculate normed version of Sample-wise component vectors
rawnormed_Basisums = np.sum(BasisMat, axis=1)
rawnormed_VecRats = np.copy(BasisMat)
for i, rat in  enumerate(rawnormed_VecRats):
	if (rawnormed_Basisums[i]>0):
		rat/=rawnormed_Basisums[i]

#calculate normed version of DHS-wise component vectors
rawnormed_Mixturesums = np.sum(MixtureMat.T, axis=1)
rawnormed_MixtureRats = np.copy(MixtureMat.T)
rawnormed_MixtureRats = rawnormed_MixtureRats[rawnormed_Mixturesums>0]
rawnormed_Mixturesums = rawnormed_Mixturesums[rawnormed_Mixturesums>0]
for i, rat in  enumerate(rawnormed_MixtureRats):
    rat/=rawnormed_Mixturesums[i]

from sklearn.cluster import KMeans

kmeans_normed_sample_orig = KMeans(n_clusters=NMFcomps*2, random_state=0).fit(rawnormed_VecRats)
ClusterMeans = kmeans_normed_sample_orig.cluster_centers_
#this doesn't really work... i am using normed versionf of vectors and then throwing them into DHS matrix for reconstruction

ClusterPredictions = kmeans_normed_sample_orig.predict(rawnormed_VecRats)

# %%
ClusterPredictions
# Out:
# array([ 6, 10, 16, 11,  5, 10, 15,  3,  3, 30, 14,  6,  8,  7,  7,  6,  6,
#        31, 29,  2,  2,  2,  1, 16, 23,  6,  2, 23, 20, 16,  8,  4, 17, 15,
#        15, 17,  8,  4,  4, 25, 25,  9,  2, 20, 12,  2, 18, 25,  2, 29, 29,
#         2, 17, 15,  6,  0, 11, 23,  5, 15, 23, 31, 21, 21,  9,  1, 21, 21,
#        21,  6, 15, 15, 15,  1,  4, 23,  4, 23, 15, 23, 11, 17, 17, 28, 31,
#         9,  2, 30,  8,  7,  7, 17,  8,  9,  9,  8, 14, 14,  0, 25, 14, 14,
#         0, 14, 21, 21,  0,  7, 10, 10,  0,  0, 10,  1,  6, 31, 17,  2, 27,
#        21,  3,  8, 26, 26,  5, 11, 18, 10,  4,  3,  8,  8, 20,  5,  8, 26,
#        23,  4, 15, 18, 15, 31,  3,  3,  3,  1, 13, 13,  3,  3, 31, 19, 30,
#         3,  3,  3, 31, 23, 24, 11, 24, 24, 24, 24, 28, 24, 19, 19,  5, 22,
#        17,  4, 25,  4, 13,  4], dtype=int32)

# %%
#which things in which cluster

Clusters = []
# find the "cluster center" in the actual DHS decomposed space
ClusterMeansReal = []

for i in range(NMFcomps*2):
    current_cut = np.argwhere(ClusterPredictions==i).T[0]
    #print (BasisMat[current_cut].shape)
    themean = np.mean(BasisMat[current_cut], axis=0)
    #print(themean.shape)
    print(i, len(ClusterPredictions[current_cut]), names[current_cut])
    ClusterMeansReal.append(themean)
    Clusters.append([i, names[current_cut], current_cut ])
# Out:
# 0 6 ['DS11752_HGF_LN2307' 'DS13219_IMR90_LN2741' 'DS13368_HMF_LN2775'
#  'DS13480_HCFaa_LN2800' 'DS13513_AoAF_LN2811' 'DS13573_HPdLF_LN2823']
# 1 5 ['DS23530_h.KBM_7_LN20483' 'DS12543_NB4_LN2556' 'DS25969A_h.CD34+_LN26316'
#  'DS31642A_h.CD1_LN28530' 'DS17215_h.CD14+_LN3909']
# 2 10 ['DS23286_h.f.Retina_LN20434' 'DS23341_h.f.Retina_LN20451'
#  'DS23368A_h.f.Retina_LN20458' 'DS23833A_h.f.Eye_LN20656'
#  'DS24728A_h.f.Eye_LN21204' 'DS24796A_h.f.Eye_LN21208'
#  'DS24833A_fSpinalCord_LN21289' 'DS24872A_fBrain_LN21323'
#  'DS23339E_h.f.Retina_LN26813' 'DS23849C_fBrain_LN28707']
# 3 12 ['DS17885_CD8+_LN10088' 'DS17212_CD4+_LN10089' 'DS14108_h.Tn_LN2964'
#  'DS14702_hTreg_LN3156' 'DS17189_CD56+_LN3905' 'DS17198_CD3+_LN3906'
#  'DS17203_CD8+_LN3907' 'DS17597_TH2_LN4024' 'DS17603_iTH2_LN4026'
#  'DS17881_CD4+_LN4097' 'DS18015_TH1_LN4128' 'DS18018_iTH1_LN4129']
# 4 10 ['DS24235A_h.SJSA_1_LN20839' 'DS24567A_h.Daoy_LN20970'
#  'DS24640A_h.MG_63_LN21068' 'DS12829_NHLF_LN2632' 'DS26313A_h.ELR_LN26395'
#  'DS14426_HSMM_LN3058' 'DS15192_HAh_LN3285' 'DS20493_M059J_LN4859'
#  'DS20548_LHCN_M2_LN4870' 'DS20909_RPMI.7951_LN4931']
# 5 5 ['DS21042_h.H1.polyMSC_LN10043' 'DS11949_SKMC_LN2373'
#  'DS34574A_h.CEC_LN29827' 'DS14790_HAsp_LN3184'
#  'DS20325_Psoas_muscle_LN4801']
# 6 8 ['DS18406_vHMEC_LN10000' 'DS10518_SAEC_LN1926'
#  'DS22985_MCF10a_ER_SRC_LN20386' 'DS22991_MCF10a_ER_SRC_LN20387'
#  'DS22980_MCF10a_ER_SRC_LN20496' 'DS25129C_h.PC3_LN21648'
#  'DS12763_HEEpiC_LN2613' 'DS25027C_h.PC3_LN28558']
# 7 5 ['DS22816_h.NAMALWA_LN20368' 'DS22823_h.NAMALWA_LN20369'
#  'DS27648A_h.Karpas_422_LN26836' 'DS27641A_h.Karpas_422_LN26838'
#  'DS29219C_h.Oci_Ly_7_LN28035']
# 8 10 ['DS10666_HRCEpiC_LN1959' 'DS24211A_h.Caki_2_LN20836'
#  'DS24547A_h.ACHN_LN20963' 'DS24471A_h.ACHN_LN26820'
#  'DS26693A_h.renal.cell.carcinoma_LN26937' 'DS26685_h.podocytes_LN26974'
#  'DS27824_h.kidney.tubular_LN29654' 'DS27192_h.786_O_LN31650'
#  'DS26689_h.kidney.tubular_LN31651' 'DS39386_h.glomerular_LN32272']
# 9 5 ['DS24731A_fHeart_LN21203' 'DS12531_fHeart_LN2553'
#  'DS23853E_fHeart_LN26812' 'DS24812A_fHeart_LN26948'
#  'DS24799A_fHeart_LN26949']
# 10 6 ['DS19317_h.Trophoblast_LN10001' 'DS20346_fPlacenta_LN10066'
#  'DS30582A_h.Trophoblast_LN28078' 'DS30557A_h.Trophoblast_LN28110'
#  'DS31397A_h.Trophoblast_LN28443' 'DS35787A_h.Trophoblast_LN30439']
# 11 5 ['DS15153_h.IPS_LN10036' 'DS11909_H7_hESC_LN2365' 'DS26455A_h.iPSC_LN26496'
#  'DS34890A_h.FUCCI.cells_LN30023' 'DS19310_Mesendoderm_LN4515']
# 12 1 ['DS24722A_h.f.Umbilical.Cord_LN21207']
# 13 3 ['DS17313_h.f.Intestine.Lg_LN3928' 'DS17317_fIntestine.Sm_LN3929'
#  'DS20770_Small_Bowel_Mucosa_LN4899']
# 14 6 ['DS10060_HUVEC_LN1812' 'DS13150_HMVEC_dLyNeo_LN2725'
#  'DS13185_HMVEC_Lly_LN2732' 'DS13242_HMVEC_dBlNeo_LN2746'
#  'DS13337_HMVEC_dBlAd_LN2768' 'DS13372_HMVEC_LBl_LN2776']
# 15 11 ['DS12734_h.CD34+_LN10087' 'DS24044A_h.CD34+_LN20861'
#  'DS24094A_h.CD34+_LN20866' 'DS24074A_h.CD34+_LN21381'
#  'DS12274_h.CD34+_LN2482' 'DS25687A_h.CD34+_LN26240'
#  'DS25769A_h.CD34+_LN26258' 'DS25730A_h.CD34+_LN26288'
#  'DS26444A_h.CD34+_LN26445' 'DS15363_K562_LN3327' 'DS16924_K562_LN3817']
# 16 3 ['DS21387_SK_N_DZ_LN10005' 'DS23541_h.brain_LN20488'
#  'DS23929C_h.brain_LN20744']
# 17 8 ['DS21924A_fKidney_Right_LN20841' 'DS24154A_h.G401_LN20867'
#  'DS25067A_h.L1_S8_LN21363' 'DS26986A_h.Bipolar_neuron_LN26591'
#  'DS26980A_h.Bipolar_neuron_LN26594' 'DS27667A_h.A673_LN26852'
#  'DS32096A_h.neuronal_stem_cell_LN28669' 'DS20351_fSpinal_cord_LN4807']
# 18 3 ['DS24790A_HeLa_S3_LN21209' 'DS14289_A549_LN3027' 'DS44414_h.RKO_LN35453']
# 19 3 ['DS17767_fMuscle_back_LN4072' 'DS20239_fMuscle_leg_LN4772'
#  'DS20242_fMuscle_trunk_LN4773']
# 20 3 ['DS23983C_fLung_LN20738' 'DS24726A_fLung_LN21205' 'DS14724_fLung_LN3167']
# 21 8 ['DS12447_HCPEpiC_LN2530' 'DS12501_HCF_LN2542' 'DS12599_HCM_LN2565'
#  'DS12663_HAEpiC_LN2579' 'DS12684_HIPEpiC_LN2583' 'DS13390_HPF_LN2780'
#  'DS13411_HPAF_LN2784' 'DS13981_HVMF_LN2925']
# 22 1 ['DS20341_fThymus_LN4803']
# 23 9 ['DS23559_h.EH_LN20491' 'DS23825A_h.EL_LN20660' 'DS11923_NHDF_neo_LN2368'
#  'DS12374_AG10803_LN2497' 'DS26113A_h.Fibroblast_LN26368'
#  'DS12863_NHDF_Ad_LN2643' 'DS26410A_h.AL_LN26455' 'DS15115_HFF_P5_LN3259'
#  'DS18224_Skin_fibroblast_LN4158']
# 24 6 ['DS19174_fSkin_Fibroblast_LN4486' 'DS19449_fSkin_Fibroblast_LN4535'
#  'DS19561_fSkin_Fibroblast_LN4587' 'DS19706_fSkin_Fibroblast_LN4632'
#  'DS19745_fSkin_Fibroblast_LN4644' 'DS19943_fSkin_Fibroblast_LN4690']
# 25 5 ['DS24825A_h.H4_LN21125' 'DS24930A_h.H4_LN21141' 'DS24744A_h.A172_LN21224'
#  'DS21975C_h.NCI_H226_LN27452' 'DS20534_LHCN_M2_LN4866']
# 26 3 ['DS34646A_h.HT29_LN29816' 'DS34628A_h.LoVo_LN29819'
#  'DS38587A_h.HT29_LN32481']
# 27 1 ['DS24147C_h.G401_LN28708']
# 28 2 ['DS27166A_h.PC9_LN26744' 'DS19794_T_47D_LN4656']
# 29 3 ['DS23123A_h.SJCRH30_LN20413' 'DS24808A_h.f.Tongue_LN21290'
#  'DS24888A_h.f.Tongue_LN21292']
# 30 3 ['DS20786_fKidney_LN10113' 'DS23873E_fKidney_LN26814'
#  'DS17878_fStomach_LN4096']
# 31 7 ['DS22919_h.RPMI.8226_LN20400' 'DS12436_GM12865_LN2528'
#  'DS27522A_h.b.lymphoblast.mm.1s_LN26797' 'DS22913C_h.RPMI.8226_LN28562'
#  'DS17186_CD19+_LN3904' 'DS17706_h.Cord.Blood_LN4062'
#  'DS18208_CD20+_LN4156']

# %%
#old way of doing things
for i in range(NMFcomps):
    current_col = rawnormed_VecRats[:,i]
    current_cut = current_col > 0.8
    fung = np.argwhere(current_cut).T[0]
    #print(Comp_colors[i], len(rawnormed_Basisums[current_cut]), names[current_cut], fung)
    #print(Comp_colors[i], len(rawnormed_Basisums[current_cut]), names[current_cut], fung, file=f)
    #if ( len(borfRats[current_cut]) >= Num_for_cluster):
        #Clusters.append([first16colors[i], names[current_cut], fung ])
    #already_clustered[current_cut] = True

# %%
import scipy.spatial.distance as spdist
import matplotlib.markers as themarkers

# %%
#threshold for what counts as a positive prediction in reconstruction matrix
chosenthresh = 0.5
#threshold for cosine similarity distance for samples to be included in this module. 0.1 gives about the same samples as in the original cluster for 80% component dominance. 
cosdist_sample_thresh = 0.3

#threshold for cosine similarity distance for DHS to be included in this module
cosdist_DHS_thresh = 0.3

# This was first attempt that didnt work out because i was using mean_of_cluster which is just 
# my normalized ratio vector... but when i do recon_cluster_DHS step it needs diff values
for i, cluster in enumerate(Clusters):

	print ('doing cluster ',i)
	# mean sample-wise component vector for this cluster
	mean_of_cluster = ClusterMeans[i]
	#create a single 1 x NDHS prediction for the cluster to
	recon_cluster_DHS = np.dot(mean_of_cluster, MixtureMat)
	cluster_length = len(cluster[1])
	print('cluster length ',cluster_length)
	print('name of samples', cluster[1])
    
	#now you tile the vector to a size equivalent to N_samples_in_cluster x NDHS
	kar = np.tile(recon_cluster_DHS, cluster_length).reshape(cluster_length, NDHS)

	#***** NOTE: for some reason I decided to use original version of NMF matrices for cosine 
	#***** Similarity scores. Self-consistent? Not sure! 

	#calculate cosine similarity of cluster mean to all sample-component vectors 
	sample_cosdists = spdist.cdist(BasisMat, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()    
	#calculate cosine similarity of cluster mean to all DHS-component vectors 
	DHScosdists = spdist.cdist(MixtureMat.T, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()
	#now we sort these sample cosine distances
	closers = np.argsort(sample_cosdists)

	#using the thresholds defined outside the loop, we find the samples that meet the closeness
	#criteria 
	Num_samples = len(sample_cosdists[sample_cosdists<cosdist_sample_thresh])
	print(' Num samples', Num_samples)
	print('samples meeting threshold ',names[closers[0:Num_samples]])

	#First we use our decision threshold to figure out if the model predicts a positive
	#for a given position. Using the sample cluster mean component vector
	DHSappear_cut = np.dot(mean_of_cluster, MixtureMat)>chosenthresh
	#now sort the coside distances of DHS's that will appear from previous step    
	DHScloseness = np.argsort(DHScosdists[DHSappear_cut])
	Num_DHSs = len(DHScosdists[DHSappear_cut][DHScosdists[DHSappear_cut] < cosdist_DHS_thresh])
	print(' Num_DHSs', Num_DHSs)

	#now we use the masks to create a miniature version of the reconstruction matrix for the given DHS only
	#strange use of double transpose 
	sorted_Module = np.dot(BasisMat[closers[0:Num_samples]], MixtureMat.T[DHSappear_cut][DHScloseness][0:Num_DHSs].T)
	#no idea how i pulled out this magic
	#this gives the real data corresponding to the module 
	corresponding_data = a[closers[0:Num_samples]][:,np.argwhere(DHSappear_cut == True).T[0][DHScloseness][0:Num_DHSs]]
	#flatten both modules to count accurate predictions. 
	flatsorted_Module = sorted_Module.flatten()
	flatcorresponding_data = corresponding_data.flatten()
	#calculate "density" i.e. number of entries of DHS hits within the module
	if (len(flatsorted_Module) > 0):
		density_in_recon = len(flatsorted_Module[flatsorted_Module>chosenthresh])/len(flatsorted_Module)
	else:
		density_in_recon = 0
	if(len(flatcorresponding_data) > 0):
		density_in_data = len(flatcorresponding_data[flatcorresponding_data>chosenthresh])/len(flatcorresponding_data)
	else:
		density_in_data = 0
	#calculate true positives, false positives, False negatives, precision ,recall
	TP =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
	FP =len(flatcorresponding_data[ np.invert(flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
	FN =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * np.invert(flatsorted_Module>chosenthresh)])
	if ((TP + FN ) > 0):
		recall = TP / (TP + FN)
	else: 
		recall = 0
	if ((TP +FP) > 0):
		precision = TP / (TP + FP)
	else:
		precision = 0
	print('density in reconstruction,  density in data,  precision,  recall')
	print(density_in_recon, density_in_data, precision, recall  )
	# don't remmeber how i figured this out either: I was possessed 
	#saves module as a list of samples in the header followed by a list of eahc DHS position
	#and whether it is or isn't present in the module.
	firstcut = np.copy(DHSappear_cut)
	firstcut[DHSappear_cut] *= (DHScosdists[DHSappear_cut] < cosdist_DHS_thresh)
	list1 = [Num_samples, Num_DHSs, chosenthresh, cosdist_sample_thresh,  cosdist_DHS_thresh, density_in_recon, density_in_data, precision, recall]
	theheader =  ' '.join(str(e) for e in list1)
	namestr = ' '.join(names[closers[0:Num_samples]])
	theheader +=' '+namestr
	#foutname = today+'Module'+str(i)+'.txt'
	#np.savetxt(foutname, firstcut, fmt='%i', header=theheader)
	#'''
# Out:
# doing cluster  0
# cluster length  6
# name of samples ['DS11752_HGF_LN2307' 'DS13219_IMR90_LN2741' 'DS13368_HMF_LN2775'
#  'DS13480_HCFaa_LN2800' 'DS13513_AoAF_LN2811' 'DS13573_HPdLF_LN2823']
#  Num samples 22
#  Num_DHSs 1259
# samples meeting threshold  ['DS13368_HMF_LN2775' 'DS11752_HGF_LN2307' 'DS13219_IMR90_LN2741'
#  'DS13573_HPdLF_LN2823' 'DS13513_AoAF_LN2811' 'DS12684_HIPEpiC_LN2583'
#  'DS13480_HCFaa_LN2800' 'DS34574A_h.CEC_LN29827' 'DS11949_SKMC_LN2373'
#  'DS14790_HAsp_LN3184' 'DS21042_h.H1.polyMSC_LN10043' 'DS13411_HPAF_LN2784'
#  'DS12447_HCPEpiC_LN2530' 'DS12501_HCF_LN2542' 'DS13981_HVMF_LN2925'
#  'DS12663_HAEpiC_LN2579' 'DS12599_HCM_LN2565' 'DS13390_HPF_LN2780'
#  'DS14426_HSMM_LN3058' 'DS20548_LHCN_M2_LN4870' 'DS12863_NHDF_Ad_LN2643'
#  'DS12374_AG10803_LN2497']
# density in reconstruction,  density in data,  precision,  recall
# 0.9942595133222616 0.915733988013575 0.9190602418388467 0.9978709982652578
# doing cluster  1
# cluster length  5
# name of samples ['DS23530_h.KBM_7_LN20483' 'DS12543_NB4_LN2556' 'DS25969A_h.CD34+_LN26316'
#  'DS31642A_h.CD1_LN28530' 'DS17215_h.CD14+_LN3909']
#  Num samples 16
#  Num_DHSs 0
# samples meeting threshold  ['DS12543_NB4_LN2556' 'DS23530_h.KBM_7_LN20483' 'DS31642A_h.CD1_LN28530'
#  'DS17215_h.CD14+_LN3909' 'DS16924_K562_LN3817' 'DS25969A_h.CD34+_LN26316'
#  'DS12274_h.CD34+_LN2482' 'DS24044A_h.CD34+_LN20861'
#  'DS24094A_h.CD34+_LN20866' 'DS15363_K562_LN3327'
#  'DS24074A_h.CD34+_LN21381' 'DS25769A_h.CD34+_LN26258'
#  'DS25730A_h.CD34+_LN26288' 'DS25687A_h.CD34+_LN26240'
#  'DS12734_h.CD34+_LN10087' 'DS26444A_h.CD34+_LN26445']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  2
# cluster length  10
# name of samples ['DS23286_h.f.Retina_LN20434' 'DS23341_h.f.Retina_LN20451'
#  'DS23368A_h.f.Retina_LN20458' 'DS23833A_h.f.Eye_LN20656'
#  'DS24728A_h.f.Eye_LN21204' 'DS24796A_h.f.Eye_LN21208'
#  'DS24833A_fSpinalCord_LN21289' 'DS24872A_fBrain_LN21323'
#  'DS23339E_h.f.Retina_LN26813' 'DS23849C_fBrain_LN28707']
#  Num samples 17
#  Num_DHSs 0
# samples meeting threshold  ['DS23339E_h.f.Retina_LN26813' 'DS24796A_h.f.Eye_LN21208'
#  'DS24833A_fSpinalCord_LN21289' 'DS23368A_h.f.Retina_LN20458'
#  'DS23286_h.f.Retina_LN20434' 'DS23341_h.f.Retina_LN20451'
#  'DS24728A_h.f.Eye_LN21204' 'DS23833A_h.f.Eye_LN20656'
#  'DS24872A_fBrain_LN21323' 'DS23849C_fBrain_LN28707'
#  'DS20351_fSpinal_cord_LN4807' 'DS26980A_h.Bipolar_neuron_LN26594'
#  'DS25067A_h.L1_S8_LN21363' 'DS26986A_h.Bipolar_neuron_LN26591'
#  'DS21924A_fKidney_Right_LN20841' 'DS32096A_h.neuronal_stem_cell_LN28669'
#  'DS24154A_h.G401_LN20867']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  3
# cluster length  12
# name of samples ['DS17885_CD8+_LN10088' 'DS17212_CD4+_LN10089' 'DS14108_h.Tn_LN2964'
#  'DS14702_hTreg_LN3156' 'DS17189_CD56+_LN3905' 'DS17198_CD3+_LN3906'
#  'DS17203_CD8+_LN3907' 'DS17597_TH2_LN4024' 'DS17603_iTH2_LN4026'
#  'DS17881_CD4+_LN4097' 'DS18015_TH1_LN4128' 'DS18018_iTH1_LN4129']
#  Num samples 12
#  Num_DHSs 6765
# samples meeting threshold  ['DS17198_CD3+_LN3906' 'DS17603_iTH2_LN4026' 'DS17597_TH2_LN4024'
#  'DS14702_hTreg_LN3156' 'DS17203_CD8+_LN3907' 'DS17189_CD56+_LN3905'
#  'DS14108_h.Tn_LN2964' 'DS17885_CD8+_LN10088' 'DS18015_TH1_LN4128'
#  'DS17212_CD4+_LN10089' 'DS17881_CD4+_LN4097' 'DS18018_iTH1_LN4129']
# density in reconstruction,  density in data,  precision,  recall
# 0.9103966494210397 0.8163587090416359 0.8673855979216843 0.9673014244326412
# doing cluster  4
# cluster length  10
# name of samples ['DS24235A_h.SJSA_1_LN20839' 'DS24567A_h.Daoy_LN20970'
#  'DS24640A_h.MG_63_LN21068' 'DS12829_NHLF_LN2632' 'DS26313A_h.ELR_LN26395'
#  'DS14426_HSMM_LN3058' 'DS15192_HAh_LN3285' 'DS20493_M059J_LN4859'
#  'DS20548_LHCN_M2_LN4870' 'DS20909_RPMI.7951_LN4931']
#  Num samples 29
#  Num_DHSs 242
# samples meeting threshold  ['DS20909_RPMI.7951_LN4931' 'DS12829_NHLF_LN2632'
#  'DS24640A_h.MG_63_LN21068' 'DS20493_M059J_LN4859' 'DS20548_LHCN_M2_LN4870'
#  'DS24567A_h.Daoy_LN20970' 'DS23825A_h.EL_LN20660' 'DS14426_HSMM_LN3058'
#  'DS24235A_h.SJSA_1_LN20839' 'DS15115_HFF_P5_LN3259'
#  'DS18224_Skin_fibroblast_LN4158' 'DS19174_fSkin_Fibroblast_LN4486'
#  'DS23559_h.EH_LN20491' 'DS26113A_h.Fibroblast_LN26368'
#  'DS26410A_h.AL_LN26455' 'DS19706_fSkin_Fibroblast_LN4632'
#  'DS12374_AG10803_LN2497' 'DS11923_NHDF_neo_LN2368'
#  'DS12863_NHDF_Ad_LN2643' 'DS19943_fSkin_Fibroblast_LN4690'
#  'DS19745_fSkin_Fibroblast_LN4644' 'DS19449_fSkin_Fibroblast_LN4535'
#  'DS19561_fSkin_Fibroblast_LN4587' 'DS26313A_h.ELR_LN26395'
#  'DS15192_HAh_LN3285' 'DS14790_HAsp_LN3184' 'DS34574A_h.CEC_LN29827'
#  'DS20534_LHCN_M2_LN4866' 'DS11949_SKMC_LN2373']
# density in reconstruction,  density in data,  precision,  recall
# 1.0 0.9803362781419208 0.9803362781419208 1.0
# doing cluster  5
# cluster length  5
# name of samples ['DS21042_h.H1.polyMSC_LN10043' 'DS11949_SKMC_LN2373'
#  'DS34574A_h.CEC_LN29827' 'DS14790_HAsp_LN3184'
#  'DS20325_Psoas_muscle_LN4801']
#  Num samples 25
#  Num_DHSs 704
# samples meeting threshold  ['DS13219_IMR90_LN2741' 'DS13573_HPdLF_LN2823' 'DS34574A_h.CEC_LN29827'
#  'DS13368_HMF_LN2775' 'DS11949_SKMC_LN2373' 'DS11752_HGF_LN2307'
#  'DS14790_HAsp_LN3184' 'DS21042_h.H1.polyMSC_LN10043' 'DS13513_AoAF_LN2811'
#  'DS13480_HCFaa_LN2800' 'DS14426_HSMM_LN3058' 'DS12684_HIPEpiC_LN2583'
#  'DS20548_LHCN_M2_LN4870' 'DS12863_NHDF_Ad_LN2643' 'DS13981_HVMF_LN2925'
#  'DS12374_AG10803_LN2497' 'DS13411_HPAF_LN2784' 'DS12663_HAEpiC_LN2579'
#  'DS12447_HCPEpiC_LN2530' 'DS12501_HCF_LN2542' 'DS12599_HCM_LN2565'
#  'DS24640A_h.MG_63_LN21068' 'DS13390_HPF_LN2780' 'DS12829_NHLF_LN2632'
#  'DS11923_NHDF_neo_LN2368']
# density in reconstruction,  density in data,  precision,  recall
# 1.0 0.9888068181818181 0.9888068181818181 1.0
# doing cluster  6
# cluster length  8
# name of samples ['DS18406_vHMEC_LN10000' 'DS10518_SAEC_LN1926'
#  'DS22985_MCF10a_ER_SRC_LN20386' 'DS22991_MCF10a_ER_SRC_LN20387'
#  'DS22980_MCF10a_ER_SRC_LN20496' 'DS25129C_h.PC3_LN21648'
#  'DS12763_HEEpiC_LN2613' 'DS25027C_h.PC3_LN28558']
#  Num samples 10
#  Num_DHSs 921
# samples meeting threshold  ['DS10518_SAEC_LN1926' 'DS22985_MCF10a_ER_SRC_LN20386'
#  'DS22991_MCF10a_ER_SRC_LN20387' 'DS18406_vHMEC_LN10000'
#  'DS22980_MCF10a_ER_SRC_LN20496' 'DS12763_HEEpiC_LN2613'
#  'DS25027C_h.PC3_LN28558' 'DS25129C_h.PC3_LN21648'
#  'DS24790A_HeLa_S3_LN21209' 'DS44414_h.RKO_LN35453']
# density in reconstruction,  density in data,  precision,  recall
# 0.8966340933767644 0.8226927252985885 0.8890772584160814 0.9689850864458229
# doing cluster  7
# cluster length  5
# name of samples ['DS22816_h.NAMALWA_LN20368' 'DS22823_h.NAMALWA_LN20369'
#  'DS27648A_h.Karpas_422_LN26836' 'DS27641A_h.Karpas_422_LN26838'
#  'DS29219C_h.Oci_Ly_7_LN28035']
#  Num samples 12
#  Num_DHSs 4
# samples meeting threshold  ['DS22816_h.NAMALWA_LN20368' 'DS22823_h.NAMALWA_LN20369'
#  'DS27641A_h.Karpas_422_LN26838' 'DS29219C_h.Oci_Ly_7_LN28035'
#  'DS27648A_h.Karpas_422_LN26836' 'DS22919_h.RPMI.8226_LN20400'
#  'DS27522A_h.b.lymphoblast.mm.1s_LN26797' 'DS22913C_h.RPMI.8226_LN28562'
#  'DS17706_h.Cord.Blood_LN4062' 'DS12436_GM12865_LN2528'
#  'DS17186_CD19+_LN3904' 'DS18208_CD20+_LN4156']
# density in reconstruction,  density in data,  precision,  recall
# 0.9583333333333334 1.0 1.0 0.9583333333333334
# doing cluster  8
# cluster length  10
# name of samples ['DS10666_HRCEpiC_LN1959' 'DS24211A_h.Caki_2_LN20836'
#  'DS24547A_h.ACHN_LN20963' 'DS24471A_h.ACHN_LN26820'
#  'DS26693A_h.renal.cell.carcinoma_LN26937' 'DS26685_h.podocytes_LN26974'
#  'DS27824_h.kidney.tubular_LN29654' 'DS27192_h.786_O_LN31650'
#  'DS26689_h.kidney.tubular_LN31651' 'DS39386_h.glomerular_LN32272']
#  Num samples 14
#  Num_DHSs 254
# samples meeting threshold  ['DS26693A_h.renal.cell.carcinoma_LN26937'
#  'DS27824_h.kidney.tubular_LN29654' 'DS27192_h.786_O_LN31650'
#  'DS39386_h.glomerular_LN32272' 'DS24471A_h.ACHN_LN26820'
#  'DS26685_h.podocytes_LN26974' 'DS26689_h.kidney.tubular_LN31651'
#  'DS10666_HRCEpiC_LN1959' 'DS24547A_h.ACHN_LN20963'
#  'DS24211A_h.Caki_2_LN20836' 'DS24744A_h.A172_LN21224'
#  'DS24825A_h.H4_LN21125' 'DS24930A_h.H4_LN21141'
#  'DS21975C_h.NCI_H226_LN27452']
# density in reconstruction,  density in data,  precision,  recall
# 0.7843082114735658 0.7716535433070866 0.9358192900681248 0.9511661807580175
# doing cluster  9
# cluster length  5
# name of samples ['DS24731A_fHeart_LN21203' 'DS12531_fHeart_LN2553'
#  'DS23853E_fHeart_LN26812' 'DS24812A_fHeart_LN26948'
#  'DS24799A_fHeart_LN26949']
#  Num samples 5
#  Num_DHSs 0
# samples meeting threshold  ['DS12531_fHeart_LN2553' 'DS24799A_fHeart_LN26949'
#  'DS24731A_fHeart_LN21203' 'DS24812A_fHeart_LN26948'
#  'DS23853E_fHeart_LN26812']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  10
# cluster length  6
# name of samples ['DS19317_h.Trophoblast_LN10001' 'DS20346_fPlacenta_LN10066'
#  'DS30582A_h.Trophoblast_LN28078' 'DS30557A_h.Trophoblast_LN28110'
#  'DS31397A_h.Trophoblast_LN28443' 'DS35787A_h.Trophoblast_LN30439']
#  Num samples 7
#  Num_DHSs 0
# samples meeting threshold  ['DS30582A_h.Trophoblast_LN28078' 'DS35787A_h.Trophoblast_LN30439'
#  'DS30557A_h.Trophoblast_LN28110' 'DS31397A_h.Trophoblast_LN28443'
#  'DS20346_fPlacenta_LN10066' 'DS19317_h.Trophoblast_LN10001'
#  'DS27166A_h.PC9_LN26744']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  11
# cluster length  5
# name of samples ['DS15153_h.IPS_LN10036' 'DS11909_H7_hESC_LN2365' 'DS26455A_h.iPSC_LN26496'
#  'DS34890A_h.FUCCI.cells_LN30023' 'DS19310_Mesendoderm_LN4515']
#  Num samples 5
#  Num_DHSs 5381
# samples meeting threshold  ['DS34890A_h.FUCCI.cells_LN30023' 'DS15153_h.IPS_LN10036'
#  'DS11909_H7_hESC_LN2365' 'DS26455A_h.iPSC_LN26496'
#  'DS19310_Mesendoderm_LN4515']
# density in reconstruction,  density in data,  precision,  recall
# 0.9857275599330979 0.8439695223936071 0.8506843633347159 0.9935702646760911
# doing cluster  12
# cluster length  1
# name of samples ['DS24722A_h.f.Umbilical.Cord_LN21207']
#  Num samples 5
#  Num_DHSs 0
# samples meeting threshold  ['DS24722A_h.f.Umbilical.Cord_LN21207' 'DS24726A_fLung_LN21205'
#  'DS14724_fLung_LN3167' 'DS23983C_fLung_LN20738' 'DS20786_fKidney_LN10113']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  13
# cluster length  3
# name of samples ['DS17313_h.f.Intestine.Lg_LN3928' 'DS17317_fIntestine.Sm_LN3929'
#  'DS20770_Small_Bowel_Mucosa_LN4899']
#  Num samples 6
#  Num_DHSs 264
# samples meeting threshold  ['DS17313_h.f.Intestine.Lg_LN3928' 'DS17317_fIntestine.Sm_LN3929'
#  'DS20770_Small_Bowel_Mucosa_LN4899' 'DS38587A_h.HT29_LN32481'
#  'DS34646A_h.HT29_LN29816' 'DS34628A_h.LoVo_LN29819']
# density in reconstruction,  density in data,  precision,  recall
# 0.9684343434343434 0.9412878787878788 0.9465449804432855 0.9738430583501007
# doing cluster  14
# cluster length  6
# name of samples ['DS10060_HUVEC_LN1812' 'DS13150_HMVEC_dLyNeo_LN2725'
#  'DS13185_HMVEC_Lly_LN2732' 'DS13242_HMVEC_dBlNeo_LN2746'
#  'DS13337_HMVEC_dBlAd_LN2768' 'DS13372_HMVEC_LBl_LN2776']
#  Num samples 6
#  Num_DHSs 1776
# samples meeting threshold  ['DS13337_HMVEC_dBlAd_LN2768' 'DS13150_HMVEC_dLyNeo_LN2725'
#  'DS13242_HMVEC_dBlNeo_LN2746' 'DS13185_HMVEC_Lly_LN2732'
#  'DS13372_HMVEC_LBl_LN2776' 'DS10060_HUVEC_LN1812']
# density in reconstruction,  density in data,  precision,  recall
# 1.0 0.881006006006006 0.881006006006006 1.0
# doing cluster  15
# cluster length  11
# name of samples ['DS12734_h.CD34+_LN10087' 'DS24044A_h.CD34+_LN20861'
#  'DS24094A_h.CD34+_LN20866' 'DS24074A_h.CD34+_LN21381'
#  'DS12274_h.CD34+_LN2482' 'DS25687A_h.CD34+_LN26240'
#  'DS25769A_h.CD34+_LN26258' 'DS25730A_h.CD34+_LN26288'
#  'DS26444A_h.CD34+_LN26445' 'DS15363_K562_LN3327' 'DS16924_K562_LN3817']
#  Num samples 16
#  Num_DHSs 0
# samples meeting threshold  ['DS25769A_h.CD34+_LN26258' 'DS24094A_h.CD34+_LN20866'
#  'DS25687A_h.CD34+_LN26240' 'DS24074A_h.CD34+_LN21381'
#  'DS25730A_h.CD34+_LN26288' 'DS12274_h.CD34+_LN2482'
#  'DS24044A_h.CD34+_LN20861' 'DS16924_K562_LN3817' 'DS15363_K562_LN3327'
#  'DS12734_h.CD34+_LN10087' 'DS26444A_h.CD34+_LN26445'
#  'DS23530_h.KBM_7_LN20483' 'DS12543_NB4_LN2556' 'DS31642A_h.CD1_LN28530'
#  'DS17215_h.CD14+_LN3909' 'DS25969A_h.CD34+_LN26316']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  16
# cluster length  3
# name of samples ['DS21387_SK_N_DZ_LN10005' 'DS23541_h.brain_LN20488'
#  'DS23929C_h.brain_LN20744']
#  Num samples 3
#  Num_DHSs 464
# samples meeting threshold  ['DS23541_h.brain_LN20488' 'DS23929C_h.brain_LN20744'
#  'DS21387_SK_N_DZ_LN10005']
# density in reconstruction,  density in data,  precision,  recall
# 0.42169540229885055 0.7794540229885057 0.9420783645655877 0.5096774193548387
# doing cluster  17
# cluster length  8
# name of samples ['DS21924A_fKidney_Right_LN20841' 'DS24154A_h.G401_LN20867'
#  'DS25067A_h.L1_S8_LN21363' 'DS26986A_h.Bipolar_neuron_LN26591'
#  'DS26980A_h.Bipolar_neuron_LN26594' 'DS27667A_h.A673_LN26852'
#  'DS32096A_h.neuronal_stem_cell_LN28669' 'DS20351_fSpinal_cord_LN4807']
#  Num samples 18
#  Num_DHSs 0
# samples meeting threshold  ['DS25067A_h.L1_S8_LN21363' 'DS26980A_h.Bipolar_neuron_LN26594'
#  'DS26986A_h.Bipolar_neuron_LN26591' 'DS23849C_fBrain_LN28707'
#  'DS24872A_fBrain_LN21323' 'DS24833A_fSpinalCord_LN21289'
#  'DS23286_h.f.Retina_LN20434' 'DS23339E_h.f.Retina_LN26813'
#  'DS20351_fSpinal_cord_LN4807' 'DS24796A_h.f.Eye_LN21208'
#  'DS23833A_h.f.Eye_LN20656' 'DS23368A_h.f.Retina_LN20458'
#  'DS24728A_h.f.Eye_LN21204' 'DS23341_h.f.Retina_LN20451'
#  'DS32096A_h.neuronal_stem_cell_LN28669' 'DS24154A_h.G401_LN20867'
#  'DS21924A_fKidney_Right_LN20841' 'DS27667A_h.A673_LN26852']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  18
# cluster length  3
# name of samples ['DS24790A_HeLa_S3_LN21209' 'DS14289_A549_LN3027' 'DS44414_h.RKO_LN35453']
#  Num samples 12
#  Num_DHSs 442
# samples meeting threshold  ['DS24790A_HeLa_S3_LN21209' 'DS44414_h.RKO_LN35453'
#  'DS25129C_h.PC3_LN21648' 'DS25027C_h.PC3_LN28558' 'DS14289_A549_LN3027'
#  'DS18406_vHMEC_LN10000' 'DS12763_HEEpiC_LN2613'
#  'DS22980_MCF10a_ER_SRC_LN20496' 'DS10518_SAEC_LN1926'
#  'DS22991_MCF10a_ER_SRC_LN20387' 'DS22985_MCF10a_ER_SRC_LN20386'
#  'DS21975C_h.NCI_H226_LN27452']
# density in reconstruction,  density in data,  precision,  recall
# 0.986236802413273 0.9617269984917044 0.9694131141273179 0.994118800235248
# doing cluster  19
# cluster length  3
# name of samples ['DS17767_fMuscle_back_LN4072' 'DS20239_fMuscle_leg_LN4772'
#  'DS20242_fMuscle_trunk_LN4773']
#  Num samples 6
#  Num_DHSs 1060
# samples meeting threshold  ['DS20242_fMuscle_trunk_LN4773' 'DS20239_fMuscle_leg_LN4772'
#  'DS17767_fMuscle_back_LN4072' 'DS24888A_h.f.Tongue_LN21292'
#  'DS24808A_h.f.Tongue_LN21290' 'DS23123A_h.SJCRH30_LN20413']
# density in reconstruction,  density in data,  precision,  recall
# 0.9438679245283019 0.9286163522012578 0.9700149925037481 0.9859464950897392
# doing cluster  20
# cluster length  3
# name of samples ['DS23983C_fLung_LN20738' 'DS24726A_fLung_LN21205' 'DS14724_fLung_LN3167']
#  Num samples 7
#  Num_DHSs 2
# samples meeting threshold  ['DS14724_fLung_LN3167' 'DS23983C_fLung_LN20738' 'DS24726A_fLung_LN21205'
#  'DS20786_fKidney_LN10113' 'DS23873E_fKidney_LN26814'
#  'DS24722A_h.f.Umbilical.Cord_LN21207' 'DS17878_fStomach_LN4096']
# density in reconstruction,  density in data,  precision,  recall
# 1.0 1.0 1.0 1.0
# doing cluster  21
# cluster length  8
# name of samples ['DS12447_HCPEpiC_LN2530' 'DS12501_HCF_LN2542' 'DS12599_HCM_LN2565'
#  'DS12663_HAEpiC_LN2579' 'DS12684_HIPEpiC_LN2583' 'DS13390_HPF_LN2780'
#  'DS13411_HPAF_LN2784' 'DS13981_HVMF_LN2925']
#  Num samples 18
#  Num_DHSs 603
# samples meeting threshold  ['DS12447_HCPEpiC_LN2530' 'DS12501_HCF_LN2542' 'DS13411_HPAF_LN2784'
#  'DS12599_HCM_LN2565' 'DS13981_HVMF_LN2925' 'DS12684_HIPEpiC_LN2583'
#  'DS12663_HAEpiC_LN2579' 'DS13390_HPF_LN2780' 'DS13513_AoAF_LN2811'
#  'DS13480_HCFaa_LN2800' 'DS13368_HMF_LN2775' 'DS11752_HGF_LN2307'
#  'DS21042_h.H1.polyMSC_LN10043' 'DS13219_IMR90_LN2741'
#  'DS13573_HPdLF_LN2823' 'DS14790_HAsp_LN3184' 'DS34574A_h.CEC_LN29827'
#  'DS11949_SKMC_LN2373']
# density in reconstruction,  density in data,  precision,  recall
# 0.9835083840058965 0.8813340703887967 0.8925526932084309 0.9960275977420029
# doing cluster  22
# cluster length  1
# name of samples ['DS20341_fThymus_LN4803']
#  Num samples 6
#  Num_DHSs 1029
# samples meeting threshold  ['DS20341_fThymus_LN4803' 'DS18208_CD20+_LN4156' 'DS12436_GM12865_LN2528'
#  'DS17706_h.Cord.Blood_LN4062' 'DS17186_CD19+_LN3904'
#  'DS17212_CD4+_LN10089']
# density in reconstruction,  density in data,  precision,  recall
# 1.0 0.9604794298671849 0.9604794298671849 1.0
# doing cluster  23
# cluster length  9
# name of samples ['DS23559_h.EH_LN20491' 'DS23825A_h.EL_LN20660' 'DS11923_NHDF_neo_LN2368'
#  'DS12374_AG10803_LN2497' 'DS26113A_h.Fibroblast_LN26368'
#  'DS12863_NHDF_Ad_LN2643' 'DS26410A_h.AL_LN26455' 'DS15115_HFF_P5_LN3259'
#  'DS18224_Skin_fibroblast_LN4158']
#  Num samples 28
#  Num_DHSs 1
# samples meeting threshold  ['DS15115_HFF_P5_LN3259' 'DS18224_Skin_fibroblast_LN4158'
#  'DS19706_fSkin_Fibroblast_LN4632' 'DS23559_h.EH_LN20491'
#  'DS26113A_h.Fibroblast_LN26368' 'DS11923_NHDF_neo_LN2368'
#  'DS19174_fSkin_Fibroblast_LN4486' 'DS19745_fSkin_Fibroblast_LN4644'
#  'DS19449_fSkin_Fibroblast_LN4535' 'DS19943_fSkin_Fibroblast_LN4690'
#  'DS19561_fSkin_Fibroblast_LN4587' 'DS23825A_h.EL_LN20660'
#  'DS26410A_h.AL_LN26455' 'DS12374_AG10803_LN2497' 'DS12863_NHDF_Ad_LN2643'
#  'DS12829_NHLF_LN2632' 'DS20909_RPMI.7951_LN4931' 'DS14426_HSMM_LN3058'
#  'DS24640A_h.MG_63_LN21068' 'DS26313A_h.ELR_LN26395'
#  'DS20548_LHCN_M2_LN4870' 'DS11949_SKMC_LN2373' 'DS24235A_h.SJSA_1_LN20839'
#  'DS15192_HAh_LN3285' 'DS20493_M059J_LN4859' 'DS34574A_h.CEC_LN29827'
#  'DS24567A_h.Daoy_LN20970' 'DS14790_HAsp_LN3184']
# density in reconstruction,  density in data,  precision,  recall
# 0.9642857142857143 1.0 1.0 0.9642857142857143
# doing cluster  24
# cluster length  6
# name of samples ['DS19174_fSkin_Fibroblast_LN4486' 'DS19449_fSkin_Fibroblast_LN4535'
#  'DS19561_fSkin_Fibroblast_LN4587' 'DS19706_fSkin_Fibroblast_LN4632'
#  'DS19745_fSkin_Fibroblast_LN4644' 'DS19943_fSkin_Fibroblast_LN4690']
#  Num samples 24
#  Num_DHSs 210
# samples meeting threshold  ['DS19449_fSkin_Fibroblast_LN4535' 'DS19943_fSkin_Fibroblast_LN4690'
#  'DS19745_fSkin_Fibroblast_LN4644' 'DS19561_fSkin_Fibroblast_LN4587'
#  'DS19174_fSkin_Fibroblast_LN4486' 'DS19706_fSkin_Fibroblast_LN4632'
#  'DS23559_h.EH_LN20491' 'DS15115_HFF_P5_LN3259' 'DS23825A_h.EL_LN20660'
#  'DS26113A_h.Fibroblast_LN26368' 'DS11923_NHDF_neo_LN2368'
#  'DS18224_Skin_fibroblast_LN4158' 'DS20909_RPMI.7951_LN4931'
#  'DS12374_AG10803_LN2497' 'DS12829_NHLF_LN2632' 'DS12863_NHDF_Ad_LN2643'
#  'DS26410A_h.AL_LN26455' 'DS14426_HSMM_LN3058' 'DS24640A_h.MG_63_LN21068'
#  'DS26313A_h.ELR_LN26395' 'DS20548_LHCN_M2_LN4870'
#  'DS24235A_h.SJSA_1_LN20839' 'DS20493_M059J_LN4859' 'DS15192_HAh_LN3285']
# density in reconstruction,  density in data,  precision,  recall
# 0.9021825396825397 0.8271825396825396 0.8669452386188696 0.9455504917246342
# doing cluster  25
# cluster length  5
# name of samples ['DS24825A_h.H4_LN21125' 'DS24930A_h.H4_LN21141' 'DS24744A_h.A172_LN21224'
#  'DS21975C_h.NCI_H226_LN27452' 'DS20534_LHCN_M2_LN4866']
#  Num samples 19
#  Num_DHSs 678
# samples meeting threshold  ['DS24930A_h.H4_LN21141' 'DS24825A_h.H4_LN21125' 'DS24744A_h.A172_LN21224'
#  'DS21975C_h.NCI_H226_LN27452' 'DS39386_h.glomerular_LN32272'
#  'DS10666_HRCEpiC_LN1959' 'DS27192_h.786_O_LN31650'
#  'DS26685_h.podocytes_LN26974' 'DS24471A_h.ACHN_LN26820'
#  'DS27824_h.kidney.tubular_LN29654' 'DS26689_h.kidney.tubular_LN31651'
#  'DS26693A_h.renal.cell.carcinoma_LN26937' 'DS20534_LHCN_M2_LN4866'
#  'DS24547A_h.ACHN_LN20963' 'DS20548_LHCN_M2_LN4870'
#  'DS24211A_h.Caki_2_LN20836' 'DS14289_A549_LN3027'
#  'DS24640A_h.MG_63_LN21068' 'DS20493_M059J_LN4859']
# density in reconstruction,  density in data,  precision,  recall
# 0.9882005899705014 0.9415463437354448 0.9465043205027495 0.9934042377772281
# doing cluster  26
# cluster length  3
# name of samples ['DS34646A_h.HT29_LN29816' 'DS34628A_h.LoVo_LN29819'
#  'DS38587A_h.HT29_LN32481']
#  Num samples 7
#  Num_DHSs 16
# samples meeting threshold  ['DS34646A_h.HT29_LN29816' 'DS34628A_h.LoVo_LN29819'
#  'DS38587A_h.HT29_LN32481' 'DS20770_Small_Bowel_Mucosa_LN4899'
#  'DS17313_h.f.Intestine.Lg_LN3928' 'DS17317_fIntestine.Sm_LN3929'
#  'DS19794_T_47D_LN4656']
# density in reconstruction,  density in data,  precision,  recall
# 0.9285714285714286 1.0 1.0 0.9285714285714286
# doing cluster  27
# cluster length  1
# name of samples ['DS24147C_h.G401_LN28708']
#  Num samples 5
#  Num_DHSs 10
# samples meeting threshold  ['DS24147C_h.G401_LN28708' 'DS22919_h.RPMI.8226_LN20400'
#  'DS22913C_h.RPMI.8226_LN28562' 'DS27522A_h.b.lymphoblast.mm.1s_LN26797'
#  'DS12436_GM12865_LN2528']
# density in reconstruction,  density in data,  precision,  recall
# 0.68 0.36 0.23529411764705882 0.4444444444444444
# doing cluster  28
# cluster length  2
# name of samples ['DS27166A_h.PC9_LN26744' 'DS19794_T_47D_LN4656']
#  Num samples 4
#  Num_DHSs 24
# samples meeting threshold  ['DS27166A_h.PC9_LN26744' 'DS19794_T_47D_LN4656' 'DS24790A_HeLa_S3_LN21209'
#  'DS19317_h.Trophoblast_LN10001']
# density in reconstruction,  density in data,  precision,  recall
# 0.84375 0.96875 0.9753086419753086 0.8494623655913979
# doing cluster  29
# cluster length  3
# name of samples ['DS23123A_h.SJCRH30_LN20413' 'DS24808A_h.f.Tongue_LN21290'
#  'DS24888A_h.f.Tongue_LN21292']
#  Num samples 6
#  Num_DHSs 0
# samples meeting threshold  ['DS24888A_h.f.Tongue_LN21292' 'DS24808A_h.f.Tongue_LN21290'
#  'DS20239_fMuscle_leg_LN4772' 'DS17767_fMuscle_back_LN4072'
#  'DS20242_fMuscle_trunk_LN4773' 'DS23123A_h.SJCRH30_LN20413']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  30
# cluster length  3
# name of samples ['DS20786_fKidney_LN10113' 'DS23873E_fKidney_LN26814'
#  'DS17878_fStomach_LN4096']
#  Num samples 8
#  Num_DHSs 0
# samples meeting threshold  ['DS20786_fKidney_LN10113' 'DS23873E_fKidney_LN26814'
#  'DS24726A_fLung_LN21205' 'DS23983C_fLung_LN20738' 'DS14724_fLung_LN3167'
#  'DS17878_fStomach_LN4096' 'DS24722A_h.f.Umbilical.Cord_LN21207'
#  'DS21924A_fKidney_Right_LN20841']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
# doing cluster  31
# cluster length  7
# name of samples ['DS22919_h.RPMI.8226_LN20400' 'DS12436_GM12865_LN2528'
#  'DS27522A_h.b.lymphoblast.mm.1s_LN26797' 'DS22913C_h.RPMI.8226_LN28562'
#  'DS17186_CD19+_LN3904' 'DS17706_h.Cord.Blood_LN4062'
#  'DS18208_CD20+_LN4156']
#  Num samples 14
#  Num_DHSs 0
# samples meeting threshold  ['DS12436_GM12865_LN2528' 'DS17706_h.Cord.Blood_LN4062'
#  'DS18208_CD20+_LN4156' 'DS27522A_h.b.lymphoblast.mm.1s_LN26797'
#  'DS22919_h.RPMI.8226_LN20400' 'DS29219C_h.Oci_Ly_7_LN28035'
#  'DS17186_CD19+_LN3904' 'DS22913C_h.RPMI.8226_LN28562'
#  'DS27648A_h.Karpas_422_LN26836' 'DS27641A_h.Karpas_422_LN26838'
#  'DS22816_h.NAMALWA_LN20368' 'DS22823_h.NAMALWA_LN20369'
#  'DS20341_fThymus_LN4803' 'DS24147C_h.G401_LN28708']
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0

# %%
#using ClusterMeans Real (actual values from newdaslog)

#threshold for what counts as a positive prediction in reconstruction matrix
chosenthresh = 0.5
#threshold for cosine similarity distance for samples to be included in this module. 0.1 gives about the same samples as in the original cluster for 80% component dominance. 
cosdist_sample_thresh = 0.3

#threshold for cosine similarity distance for DHS to be included in this module
cosdist_DHS_thresh = 0.3
for i, cluster in enumerate(Clusters):

	print ('doing cluster ',i)
	# mean sample-wise component vector for this cluster
	mean_of_cluster = ClusterMeansReal[i]
	#create a single 1 x NDHS prediction for the cluster to
	recon_cluster_DHS = np.dot(mean_of_cluster, MixtureMat)
	cluster_length = len(cluster[1])
	print('cluster length ',cluster_length)
	print('name of samples', cluster[1])
    
	#now you tile the vector to a size equivalent to N_samples_in_cluster x NDHS
	kar = np.tile(recon_cluster_DHS, cluster_length).reshape(cluster_length, NDHS)

	#***** NOTE: for some reason I decided to use original version of NMF matrices for cosine 
	#***** Similarity scores. Self-consistent? Not sure! 

	#calculate cosine similarity of cluster mean to all sample-component vectors 
	sample_cosdists = spdist.cdist(BasisMat, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()    
	#calculate cosine similarity of cluster mean to all DHS-component vectors 
	DHScosdists = spdist.cdist(MixtureMat.T, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()
	#now we sort these sample cosine distances
	closers = np.argsort(sample_cosdists)

	#using the thresholds defined outside the loop, we find the samples that meet the closeness
	#criteria 
	Num_samples = len(sample_cosdists[sample_cosdists<cosdist_sample_thresh])
	print(' Num samples', Num_samples)
	print('samples meeting threshold ',names[closers[0:Num_samples]])

	#First we use our decision threshold to figure out if the model predicts a positive
	#for a given position. Using the sample cluster mean component vector
	DHSappear_cut = np.dot(mean_of_cluster, MixtureMat)>chosenthresh
	#now sort the coside distances of DHS's that will appear from previous step    
	DHScloseness = np.argsort(DHScosdists[DHSappear_cut])
	Num_DHSs = len(DHScosdists[DHSappear_cut][DHScosdists[DHSappear_cut] < cosdist_DHS_thresh])
	print(' Num_DHSs', Num_DHSs)

	#now we use the masks to create a miniature version of the reconstruction matrix for the given DHS only
	#strange use of double transpose 
	sorted_Module = np.dot(BasisMat[closers[0:Num_samples]], MixtureMat.T[DHSappear_cut][DHScloseness][0:Num_DHSs].T)
	#no idea how i pulled out this magic
	#this gives the real data corresponding to the module 
	corresponding_data = a[closers[0:Num_samples]][:,np.argwhere(DHSappear_cut == True).T[0][DHScloseness][0:Num_DHSs]]
	#flatten both modules to count accurate predictions. 
	flatsorted_Module = sorted_Module.flatten()
	flatcorresponding_data = corresponding_data.flatten()
	#calculate "density" i.e. number of entries of DHS hits within the module
	if (len(flatsorted_Module) > 0):
		density_in_recon = len(flatsorted_Module[flatsorted_Module>chosenthresh])/len(flatsorted_Module)
	else:
		density_in_recon = 0
	if(len(flatcorresponding_data) > 0):
		density_in_data = len(flatcorresponding_data[flatcorresponding_data>chosenthresh])/len(flatcorresponding_data)
	else:
		density_in_data = 0
	#calculate true positives, false positives, False negatives, precision ,recall
	TP =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
	FP =len(flatcorresponding_data[ np.invert(flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
	FN =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * np.invert(flatsorted_Module>chosenthresh)])
	if ((TP + FN ) > 0):
		recall = TP / (TP + FN)
	else: 
		recall = 0
	if ((TP +FP) > 0):
		precision = TP / (TP + FP)
	else:
		precision = 0
	print('density in reconstruction,  density in data,  precision,  recall')
	print(density_in_recon, density_in_data, precision, recall  )
	# don't remmeber how i figured this out either: I was possessed 
	#saves module as a list of samples in the header followed by a list of eahc DHS position
	#and whether it is or isn't present in the module.
	firstcut = np.copy(DHSappear_cut)
	firstcut[DHSappear_cut] *= (DHScosdists[DHSappear_cut] < cosdist_DHS_thresh)
	list1 = [Num_samples, Num_DHSs, chosenthresh, cosdist_sample_thresh,  cosdist_DHS_thresh, density_in_recon, density_in_data, precision, recall]
	theheader =  ' '.join(str(e) for e in list1)
	namestr = ' '.join(names[closers[0:Num_samples]])
	theheader +=' '+namestr
	#foutname = today+'Module'+str(i)+'.txt'
	#np.savetxt(foutname, firstcut, fmt='%i', header=theheader)
	#'''
# Out:
# doing cluster  0
# cluster length  6
# name of samples ['DS11752_HGF_LN2307' 'DS13219_IMR90_LN2741' 'DS13368_HMF_LN2775'
#  'DS13480_HCFaa_LN2800' 'DS13513_AoAF_LN2811' 'DS13573_HPdLF_LN2823']
# samples meeting threshold  []
#  Num samples 22
#  Num_DHSs 2314
# density in reconstruction,  density in data,  precision,  recall
# 0.9058301249312485 0.7871061522746916 0.8328707117144468 0.9584976291489893
# doing cluster  1
# cluster length  5
# name of samples ['DS23530_h.KBM_7_LN20483' 'DS12543_NB4_LN2556' 'DS25969A_h.CD34+_LN26316'
#  'DS31642A_h.CD1_LN28530' 'DS17215_h.CD14+_LN3909']
# samples meeting threshold  ['DS12543_NB4_LN2556' 'DS23530_h.KBM_7_LN20483' 'DS31642A_h.CD1_LN28530'
#  'DS16924_K562_LN3817' 'DS12274_h.CD34+_LN2482' 'DS24094A_h.CD34+_LN20866'
#  'DS24044A_h.CD34+_LN20861' 'DS17215_h.CD14+_LN3909'
#  'DS25969A_h.CD34+_LN26316' 'DS24074A_h.CD34+_LN21381'
#  'DS25769A_h.CD34+_LN26258' 'DS15363_K562_LN3327'
#  'DS25730A_h.CD34+_LN26288' 'DS25687A_h.CD34+_LN26240'
#  'DS12734_h.CD34+_LN10087' 'DS26444A_h.CD34+_LN26445'
#  'DS20341_fThymus_LN4803' 'DS27667A_h.A673_LN26852'
#  'DS22913C_h.RPMI.8226_LN28562' 'DS12436_GM12865_LN2528'
#  'DS24147C_h.G401_LN28708' 'DS22919_h.RPMI.8226_LN20400']
#  Num samples 16
#  Num_DHSs 243
# density in reconstruction,  density in data,  precision,  recall
# 0.8266460905349794 0.8297325102880658 0.9044803982576229 0.9011159330440174
# doing cluster  2
# cluster length  10
# name of samples ['DS23286_h.f.Retina_LN20434' 'DS23341_h.f.Retina_LN20451'
#  'DS23368A_h.f.Retina_LN20458' 'DS23833A_h.f.Eye_LN20656'
#  'DS24728A_h.f.Eye_LN21204' 'DS24796A_h.f.Eye_LN21208'
#  'DS24833A_fSpinalCord_LN21289' 'DS24872A_fBrain_LN21323'
#  'DS23339E_h.f.Retina_LN26813' 'DS23849C_fBrain_LN28707']
# samples meeting threshold  ['DS24796A_h.f.Eye_LN21208' 'DS23339E_h.f.Retina_LN26813'
#  'DS23368A_h.f.Retina_LN20458' 'DS23341_h.f.Retina_LN20451'
#  'DS24728A_h.f.Eye_LN21204' 'DS23833A_h.f.Eye_LN20656'
#  'DS24833A_fSpinalCord_LN21289' 'DS23286_h.f.Retina_LN20434'
#  'DS24872A_fBrain_LN21323' 'DS23849C_fBrain_LN28707'
#  'DS20351_fSpinal_cord_LN4807' 'DS26980A_h.Bipolar_neuron_LN26594'
#  'DS25067A_h.L1_S8_LN21363' 'DS26986A_h.Bipolar_neuron_LN26591'
#  'DS21924A_fKidney_Right_LN20841' 'DS32096A_h.neuronal_stem_cell_LN28669']
#  Num samples 17
#  Num_DHSs 2076
# density in reconstruction,  density in data,  precision,  recall
# 0.5087838603649553 0.5607503116853678 0.8377701047003787 0.7601313794845882
# doing cluster  3
# cluster length  12
# name of samples ['DS17885_CD8+_LN10088' 'DS17212_CD4+_LN10089' 'DS14108_h.Tn_LN2964'
#  'DS14702_hTreg_LN3156' 'DS17189_CD56+_LN3905' 'DS17198_CD3+_LN3906'
#  'DS17203_CD8+_LN3907' 'DS17597_TH2_LN4024' 'DS17603_iTH2_LN4026'
#  'DS17881_CD4+_LN4097' 'DS18015_TH1_LN4128' 'DS18018_iTH1_LN4129']
# samples meeting threshold  ['DS17198_CD3+_LN3906' 'DS17603_iTH2_LN4026' 'DS17597_TH2_LN4024'
#  'DS17203_CD8+_LN3907' 'DS14702_hTreg_LN3156' 'DS17189_CD56+_LN3905'
#  'DS17885_CD8+_LN10088' 'DS14108_h.Tn_LN2964' 'DS17212_CD4+_LN10089'
#  'DS17881_CD4+_LN4097' 'DS18015_TH1_LN4128' 'DS18018_iTH1_LN4129'
#  'DS20341_fThymus_LN4803' 'DS17706_h.Cord.Blood_LN4062'
#  'DS18208_CD20+_LN4156' 'DS12436_GM12865_LN2528' 'DS17215_h.CD14+_LN3909']
#  Num samples 12
#  Num_DHSs 6693
# density in reconstruction,  density in data,  precision,  recall
# 0.9178121420389461 0.8211564320932317 0.8688055348300888 0.9710698689956332
# doing cluster  4
# cluster length  10
# name of samples ['DS24235A_h.SJSA_1_LN20839' 'DS24567A_h.Daoy_LN20970'
#  'DS24640A_h.MG_63_LN21068' 'DS12829_NHLF_LN2632' 'DS26313A_h.ELR_LN26395'
#  'DS14426_HSMM_LN3058' 'DS15192_HAh_LN3285' 'DS20493_M059J_LN4859'
#  'DS20548_LHCN_M2_LN4870' 'DS20909_RPMI.7951_LN4931']
# samples meeting threshold  ['DS20909_RPMI.7951_LN4931' 'DS12829_NHLF_LN2632'
#  'DS24640A_h.MG_63_LN21068' 'DS20493_M059J_LN4859'
#  'DS24567A_h.Daoy_LN20970' 'DS23825A_h.EL_LN20660' 'DS20548_LHCN_M2_LN4870'
#  'DS24235A_h.SJSA_1_LN20839' 'DS18224_Skin_fibroblast_LN4158'
#  'DS14426_HSMM_LN3058' 'DS15115_HFF_P5_LN3259'
#  'DS19174_fSkin_Fibroblast_LN4486']
#  Num samples 28
#  Num_DHSs 1524
# density in reconstruction,  density in data,  precision,  recall
# 0.9126124859392576 0.812429696287964 0.8541714813958863 0.9595015576323987
# doing cluster  5
# cluster length  5
# name of samples ['DS21042_h.H1.polyMSC_LN10043' 'DS11949_SKMC_LN2373'
#  'DS34574A_h.CEC_LN29827' 'DS14790_HAsp_LN3184'
#  'DS20325_Psoas_muscle_LN4801']
# samples meeting threshold  ['DS13573_HPdLF_LN2823' 'DS13219_IMR90_LN2741' 'DS11949_SKMC_LN2373'
#  'DS34574A_h.CEC_LN29827' 'DS13368_HMF_LN2775' 'DS11752_HGF_LN2307'
#  'DS14790_HAsp_LN3184' 'DS21042_h.H1.polyMSC_LN10043' 'DS13513_AoAF_LN2811'
#  'DS13480_HCFaa_LN2800' 'DS14426_HSMM_LN3058' 'DS12684_HIPEpiC_LN2583'
#  'DS20548_LHCN_M2_LN4870' 'DS12863_NHDF_Ad_LN2643' 'DS13981_HVMF_LN2925'
#  'DS12374_AG10803_LN2497' 'DS13411_HPAF_LN2784' 'DS12447_HCPEpiC_LN2530'
#  'DS12663_HAEpiC_LN2579' 'DS12501_HCF_LN2542' 'DS12599_HCM_LN2565'
#  'DS13390_HPF_LN2780' 'DS24640A_h.MG_63_LN21068' 'DS12829_NHLF_LN2632'
#  'DS11923_NHDF_neo_LN2368' 'DS15115_HFF_P5_LN3259' 'DS26410A_h.AL_LN26455'
#  'DS18224_Skin_fibroblast_LN4158']
#  Num samples 25
#  Num_DHSs 3491
# density in reconstruction,  density in data,  precision,  recall
# 0.9475794901174449 0.833159553136637 0.8596856106408706 0.977748439090134
# doing cluster  6
# cluster length  8
# name of samples ['DS18406_vHMEC_LN10000' 'DS10518_SAEC_LN1926'
#  'DS22985_MCF10a_ER_SRC_LN20386' 'DS22991_MCF10a_ER_SRC_LN20387'
#  'DS22980_MCF10a_ER_SRC_LN20496' 'DS25129C_h.PC3_LN21648'
#  'DS12763_HEEpiC_LN2613' 'DS25027C_h.PC3_LN28558']
# samples meeting threshold  ['DS10518_SAEC_LN1926' 'DS22985_MCF10a_ER_SRC_LN20386'
#  'DS22991_MCF10a_ER_SRC_LN20387' 'DS18406_vHMEC_LN10000'
#  'DS22980_MCF10a_ER_SRC_LN20496' 'DS12763_HEEpiC_LN2613'
#  'DS25027C_h.PC3_LN28558' 'DS25129C_h.PC3_LN21648'
#  'DS24790A_HeLa_S3_LN21209' 'DS44414_h.RKO_LN35453'
#  'DS27166A_h.PC9_LN26744' 'DS14289_A549_LN3027' 'DS26313A_h.ELR_LN26395'
#  'DS21975C_h.NCI_H226_LN27452' 'DS24567A_h.Daoy_LN20970'
#  'DS19794_T_47D_LN4656' 'DS20325_Psoas_muscle_LN4801'
#  'DS24744A_h.A172_LN21224' 'DS20493_M059J_LN4859'
#  'DS24640A_h.MG_63_LN21068' 'DS34646A_h.HT29_LN29816'
#  'DS38587A_h.HT29_LN32481' 'DS34628A_h.LoVo_LN29819'
#  'DS34574A_h.CEC_LN29827' 'DS13480_HCFaa_LN2800']
#  Num samples 10
#  Num_DHSs 1723
# density in reconstruction,  density in data,  precision,  recall
# 0.788160185722577 0.6969820081253627 0.8136966126656848 0.9201432259138979
# doing cluster  7
# cluster length  5
# name of samples ['DS22816_h.NAMALWA_LN20368' 'DS22823_h.NAMALWA_LN20369'
#  'DS27648A_h.Karpas_422_LN26836' 'DS27641A_h.Karpas_422_LN26838'
#  'DS29219C_h.Oci_Ly_7_LN28035']
# samples meeting threshold  ['DS22823_h.NAMALWA_LN20369' 'DS22816_h.NAMALWA_LN20368'
#  'DS27641A_h.Karpas_422_LN26838' 'DS29219C_h.Oci_Ly_7_LN28035'
#  'DS27648A_h.Karpas_422_LN26836' 'DS22919_h.RPMI.8226_LN20400'
#  'DS27522A_h.b.lymphoblast.mm.1s_LN26797' 'DS22913C_h.RPMI.8226_LN28562'
#  'DS17706_h.Cord.Blood_LN4062' 'DS12436_GM12865_LN2528']
#  Num samples 12
#  Num_DHSs 1666
# density in reconstruction,  density in data,  precision,  recall
# 0.42892156862745096 0.5277611044417767 0.8679883381924198 0.7054307648564118
# doing cluster  8
# cluster length  10
# name of samples ['DS10666_HRCEpiC_LN1959' 'DS24211A_h.Caki_2_LN20836'
#  'DS24547A_h.ACHN_LN20963' 'DS24471A_h.ACHN_LN26820'
#  'DS26693A_h.renal.cell.carcinoma_LN26937' 'DS26685_h.podocytes_LN26974'
#  'DS27824_h.kidney.tubular_LN29654' 'DS27192_h.786_O_LN31650'
#  'DS26689_h.kidney.tubular_LN31651' 'DS39386_h.glomerular_LN32272']
# samples meeting threshold  ['DS26693A_h.renal.cell.carcinoma_LN26937'
#  'DS27824_h.kidney.tubular_LN29654' 'DS27192_h.786_O_LN31650'
#  'DS24471A_h.ACHN_LN26820' 'DS39386_h.glomerular_LN32272'
#  'DS26685_h.podocytes_LN26974' 'DS26689_h.kidney.tubular_LN31651'
#  'DS10666_HRCEpiC_LN1959' 'DS24547A_h.ACHN_LN20963'
#  'DS24211A_h.Caki_2_LN20836' 'DS24744A_h.A172_LN21224'
#  'DS24825A_h.H4_LN21125']
#  Num samples 14
#  Num_DHSs 964
# density in reconstruction,  density in data,  precision,  recall
# 0.7006520450503853 0.6124036751630113 0.8175761421319797 0.9353901996370236
# doing cluster  9
# cluster length  5
# name of samples ['DS24731A_fHeart_LN21203' 'DS12531_fHeart_LN2553'
#  'DS23853E_fHeart_LN26812' 'DS24812A_fHeart_LN26948'
#  'DS24799A_fHeart_LN26949']
# samples meeting threshold  ['DS12531_fHeart_LN2553' 'DS24731A_fHeart_LN21203'
#  'DS24799A_fHeart_LN26949' 'DS24812A_fHeart_LN26948'
#  'DS23853E_fHeart_LN26812' 'DS24154A_h.G401_LN20867'
#  'DS20325_Psoas_muscle_LN4801' 'DS24722A_h.f.Umbilical.Cord_LN21207'
#  'DS10060_HUVEC_LN1812' 'DS20534_LHCN_M2_LN4866' 'DS13513_AoAF_LN2811'
#  'DS24235A_h.SJSA_1_LN20839' 'DS12599_HCM_LN2565' 'DS12501_HCF_LN2542']
#  Num samples 5
#  Num_DHSs 2029
# density in reconstruction,  density in data,  precision,  recall
# 0.9867915229176935 0.8126170527353376 0.8111077814404155 0.984958757884522
# doing cluster  10
# cluster length  6
# name of samples ['DS19317_h.Trophoblast_LN10001' 'DS20346_fPlacenta_LN10066'
#  'DS30582A_h.Trophoblast_LN28078' 'DS30557A_h.Trophoblast_LN28110'
#  'DS31397A_h.Trophoblast_LN28443' 'DS35787A_h.Trophoblast_LN30439']
# samples meeting threshold  ['DS35787A_h.Trophoblast_LN30439' 'DS30582A_h.Trophoblast_LN28078'
#  'DS31397A_h.Trophoblast_LN28443' 'DS30557A_h.Trophoblast_LN28110'
#  'DS20346_fPlacenta_LN10066']
#  Num samples 7
#  Num_DHSs 2178
# density in reconstruction,  density in data,  precision,  recall
# 0.6842450478814115 0.6204250295159386 0.8155674846625767 0.8994608309546464
# doing cluster  11
# cluster length  5
# name of samples ['DS15153_h.IPS_LN10036' 'DS11909_H7_hESC_LN2365' 'DS26455A_h.iPSC_LN26496'
#  'DS34890A_h.FUCCI.cells_LN30023' 'DS19310_Mesendoderm_LN4515']
# samples meeting threshold  ['DS34890A_h.FUCCI.cells_LN30023' 'DS15153_h.IPS_LN10036'
#  'DS11909_H7_hESC_LN2365' 'DS26455A_h.iPSC_LN26496'
#  'DS19310_Mesendoderm_LN4515' 'DS32096A_h.neuronal_stem_cell_LN28669'
#  'DS24147C_h.G401_LN28708']
#  Num samples 5
#  Num_DHSs 5432
# density in reconstruction,  density in data,  precision,  recall
# 0.9824742268041237 0.8424521354933726 0.850097436666167 0.991390236440715
# doing cluster  12
# cluster length  1
# name of samples ['DS24722A_h.f.Umbilical.Cord_LN21207']
# samples meeting threshold  ['DS24722A_h.f.Umbilical.Cord_LN21207' 'DS24726A_fLung_LN21205'
#  'DS14724_fLung_LN3167' 'DS23983C_fLung_LN20738' 'DS20786_fKidney_LN10113']
#  Num samples 5
#  Num_DHSs 1480
# density in reconstruction,  density in data,  precision,  recall
# 0.9591891891891892 0.8579729729729729 0.8867286559594252 0.9913372184596
# doing cluster  13
# cluster length  3
# name of samples ['DS17313_h.f.Intestine.Lg_LN3928' 'DS17317_fIntestine.Sm_LN3929'
#  'DS20770_Small_Bowel_Mucosa_LN4899']
# samples meeting threshold  ['DS17313_h.f.Intestine.Lg_LN3928' 'DS17317_fIntestine.Sm_LN3929'
#  'DS20770_Small_Bowel_Mucosa_LN4899' 'DS38587A_h.HT29_LN32481'
#  'DS34646A_h.HT29_LN29816']
#  Num samples 6
#  Num_DHSs 3002
# density in reconstruction,  density in data,  precision,  recall
# 0.4934488119031757 0.5414168332222963 0.9420567056705671 0.8585931091058244
# doing cluster  14
# cluster length  6
# name of samples ['DS10060_HUVEC_LN1812' 'DS13150_HMVEC_dLyNeo_LN2725'
#  'DS13185_HMVEC_Lly_LN2732' 'DS13242_HMVEC_dBlNeo_LN2746'
#  'DS13337_HMVEC_dBlAd_LN2768' 'DS13372_HMVEC_LBl_LN2776']
# samples meeting threshold  ['DS13337_HMVEC_dBlAd_LN2768' 'DS13150_HMVEC_dLyNeo_LN2725'
#  'DS13242_HMVEC_dBlNeo_LN2746' 'DS13185_HMVEC_Lly_LN2732'
#  'DS13372_HMVEC_LBl_LN2776' 'DS10060_HUVEC_LN1812']
#  Num samples 6
#  Num_DHSs 2321
# density in reconstruction,  density in data,  precision,  recall
# 0.9682608071233664 0.8197615970127818 0.836027884900623 0.9874737210932025
# doing cluster  15
# cluster length  11
# name of samples ['DS12734_h.CD34+_LN10087' 'DS24044A_h.CD34+_LN20861'
#  'DS24094A_h.CD34+_LN20866' 'DS24074A_h.CD34+_LN21381'
#  'DS12274_h.CD34+_LN2482' 'DS25687A_h.CD34+_LN26240'
#  'DS25769A_h.CD34+_LN26258' 'DS25730A_h.CD34+_LN26288'
#  'DS26444A_h.CD34+_LN26445' 'DS15363_K562_LN3327' 'DS16924_K562_LN3817']
# samples meeting threshold  ['DS25769A_h.CD34+_LN26258' 'DS24094A_h.CD34+_LN20866'
#  'DS25687A_h.CD34+_LN26240' 'DS24074A_h.CD34+_LN21381'
#  'DS25730A_h.CD34+_LN26288' 'DS12274_h.CD34+_LN2482']
#  Num samples 16
#  Num_DHSs 1052
# density in reconstruction,  density in data,  precision,  recall
# 0.5939876425855514 0.5718274714828897 0.7789557911582317 0.8091428571428572
# doing cluster  16
# cluster length  3
# name of samples ['DS21387_SK_N_DZ_LN10005' 'DS23541_h.brain_LN20488'
#  'DS23929C_h.brain_LN20744']
# samples meeting threshold  ['DS23541_h.brain_LN20488' 'DS23929C_h.brain_LN20744'
#  'DS21387_SK_N_DZ_LN10005' 'DS27667A_h.A673_LN26852'
#  'DS24154A_h.G401_LN20867' 'DS25067A_h.L1_S8_LN21363'
#  'DS26980A_h.Bipolar_neuron_LN26594' 'DS26986A_h.Bipolar_neuron_LN26591'
#  'DS24825A_h.H4_LN21125' 'DS23849C_fBrain_LN28707' 'DS19794_T_47D_LN4656'
#  'DS24930A_h.H4_LN21141' 'DS24872A_fBrain_LN21323'
#  'DS24147C_h.G401_LN28708' 'DS14289_A549_LN3027' 'DS18018_iTH1_LN4129']
#  Num samples 4
#  Num_DHSs 208
# density in reconstruction,  density in data,  precision,  recall
# 0.8629807692307693 0.8233173076923077 0.8537604456824512 0.8948905109489051
# doing cluster  17
# cluster length  8
# name of samples ['DS21924A_fKidney_Right_LN20841' 'DS24154A_h.G401_LN20867'
#  'DS25067A_h.L1_S8_LN21363' 'DS26986A_h.Bipolar_neuron_LN26591'
#  'DS26980A_h.Bipolar_neuron_LN26594' 'DS27667A_h.A673_LN26852'
#  'DS32096A_h.neuronal_stem_cell_LN28669' 'DS20351_fSpinal_cord_LN4807']
# samples meeting threshold  ['DS25067A_h.L1_S8_LN21363' 'DS23849C_fBrain_LN28707'
#  'DS24872A_fBrain_LN21323' 'DS26980A_h.Bipolar_neuron_LN26594']
#  Num samples 17
#  Num_DHSs 299
# density in reconstruction,  density in data,  precision,  recall
# 0.8817627385402321 0.8801888648435963 0.9163319946452476 0.9179704962002683
# doing cluster  18
# cluster length  3
# name of samples ['DS24790A_HeLa_S3_LN21209' 'DS14289_A549_LN3027' 'DS44414_h.RKO_LN35453']
# samples meeting threshold  ['DS24790A_HeLa_S3_LN21209' 'DS44414_h.RKO_LN35453'
#  'DS25129C_h.PC3_LN21648' 'DS25027C_h.PC3_LN28558' 'DS14289_A549_LN3027'
#  'DS18406_vHMEC_LN10000' 'DS12763_HEEpiC_LN2613'
#  'DS22980_MCF10a_ER_SRC_LN20496' 'DS10518_SAEC_LN1926'
#  'DS22991_MCF10a_ER_SRC_LN20387' 'DS22985_MCF10a_ER_SRC_LN20386'
#  'DS21975C_h.NCI_H226_LN27452' 'DS27166A_h.PC9_LN26744'
#  'DS19794_T_47D_LN4656' 'DS24744A_h.A172_LN21224' 'DS38587A_h.HT29_LN32481'
#  'DS34646A_h.HT29_LN29816']
#  Num samples 12
#  Num_DHSs 1131
# density in reconstruction,  density in data,  precision,  recall
# 0.8981727085175361 0.8803418803418803 0.9337981952420017 0.9527117509206562
# doing cluster  19
# cluster length  3
# name of samples ['DS17767_fMuscle_back_LN4072' 'DS20239_fMuscle_leg_LN4772'
#  'DS20242_fMuscle_trunk_LN4773']
# samples meeting threshold  ['DS20242_fMuscle_trunk_LN4773' 'DS20239_fMuscle_leg_LN4772'
#  'DS17767_fMuscle_back_LN4072' 'DS24888A_h.f.Tongue_LN21292'
#  'DS24808A_h.f.Tongue_LN21290' 'DS23123A_h.SJCRH30_LN20413'
#  'DS20534_LHCN_M2_LN4866' 'DS20325_Psoas_muscle_LN4801'
#  'DS24722A_h.f.Umbilical.Cord_LN21207' 'DS17878_fStomach_LN4096'
#  'DS20351_fSpinal_cord_LN4807' 'DS11949_SKMC_LN2373']
#  Num samples 6
#  Num_DHSs 4036
# density in reconstruction,  density in data,  precision,  recall
# 0.7176660059464817 0.6752560290716881 0.8525231601357961 0.9060665362035225
# doing cluster  20
# cluster length  3
# name of samples ['DS23983C_fLung_LN20738' 'DS24726A_fLung_LN21205' 'DS14724_fLung_LN3167']
# samples meeting threshold  ['DS14724_fLung_LN3167' 'DS23983C_fLung_LN20738' 'DS24726A_fLung_LN21205'
#  'DS20786_fKidney_LN10113' 'DS23873E_fKidney_LN26814'
#  'DS24722A_h.f.Umbilical.Cord_LN21207']
#  Num samples 7
#  Num_DHSs 1429
# density in reconstruction,  density in data,  precision,  recall
# 0.47885634309707087 0.4851544536639008 0.8870563674321503 0.8755409025345148
# doing cluster  21
# cluster length  8
# name of samples ['DS12447_HCPEpiC_LN2530' 'DS12501_HCF_LN2542' 'DS12599_HCM_LN2565'
#  'DS12663_HAEpiC_LN2579' 'DS12684_HIPEpiC_LN2583' 'DS13390_HPF_LN2780'
#  'DS13411_HPAF_LN2784' 'DS13981_HVMF_LN2925']
# samples meeting threshold  ['DS12447_HCPEpiC_LN2530' 'DS12501_HCF_LN2542' 'DS13411_HPAF_LN2784'
#  'DS12599_HCM_LN2565' 'DS13981_HVMF_LN2925' 'DS12663_HAEpiC_LN2579'
#  'DS12684_HIPEpiC_LN2583']
#  Num samples 18
#  Num_DHSs 1297
# density in reconstruction,  density in data,  precision,  recall
# 0.8350038550501157 0.719138182129701 0.8018364625012825 0.9310262671987611
# doing cluster  22
# cluster length  1
# name of samples ['DS20341_fThymus_LN4803']
# samples meeting threshold  ['DS20341_fThymus_LN4803' 'DS18208_CD20+_LN4156' 'DS12436_GM12865_LN2528'
#  'DS17706_h.Cord.Blood_LN4062' 'DS17186_CD19+_LN3904'
#  'DS17212_CD4+_LN10089' 'DS17597_TH2_LN4024' 'DS14702_hTreg_LN3156'
#  'DS17215_h.CD14+_LN3909' 'DS18015_TH1_LN4128' 'DS17603_iTH2_LN4026'
#  'DS14108_h.Tn_LN2964' 'DS17198_CD3+_LN3906' 'DS17885_CD8+_LN10088'
#  'DS17881_CD4+_LN4097' 'DS18018_iTH1_LN4129' 'DS17203_CD8+_LN3907'
#  'DS17189_CD56+_LN3905']
#  Num samples 6
#  Num_DHSs 3616
# density in reconstruction,  density in data,  precision,  recall
# 0.9387444690265486 0.8036504424778761 0.83792409289537 0.9787795365909612
# doing cluster  23
# cluster length  9
# name of samples ['DS23559_h.EH_LN20491' 'DS23825A_h.EL_LN20660' 'DS11923_NHDF_neo_LN2368'
#  'DS12374_AG10803_LN2497' 'DS26113A_h.Fibroblast_LN26368'
#  'DS12863_NHDF_Ad_LN2643' 'DS26410A_h.AL_LN26455' 'DS15115_HFF_P5_LN3259'
#  'DS18224_Skin_fibroblast_LN4158']
# samples meeting threshold  ['DS15115_HFF_P5_LN3259' 'DS18224_Skin_fibroblast_LN4158'
#  'DS23559_h.EH_LN20491' 'DS26113A_h.Fibroblast_LN26368'
#  'DS19706_fSkin_Fibroblast_LN4632' 'DS19174_fSkin_Fibroblast_LN4486']
#  Num samples 28
#  Num_DHSs 1219
# density in reconstruction,  density in data,  precision,  recall
# 0.7078694480253135 0.6505332239540607 0.7826662803691901 0.8516483516483516
# doing cluster  24
# cluster length  6
# name of samples ['DS19174_fSkin_Fibroblast_LN4486' 'DS19449_fSkin_Fibroblast_LN4535'
#  'DS19561_fSkin_Fibroblast_LN4587' 'DS19706_fSkin_Fibroblast_LN4632'
#  'DS19745_fSkin_Fibroblast_LN4644' 'DS19943_fSkin_Fibroblast_LN4690']
# samples meeting threshold  ['DS19449_fSkin_Fibroblast_LN4535' 'DS19943_fSkin_Fibroblast_LN4690'
#  'DS19745_fSkin_Fibroblast_LN4644' 'DS19561_fSkin_Fibroblast_LN4587'
#  'DS19174_fSkin_Fibroblast_LN4486' 'DS19706_fSkin_Fibroblast_LN4632'
#  'DS23559_h.EH_LN20491' 'DS15115_HFF_P5_LN3259' 'DS23825A_h.EL_LN20660'
#  'DS26113A_h.Fibroblast_LN26368' 'DS11923_NHDF_neo_LN2368'
#  'DS18224_Skin_fibroblast_LN4158' 'DS20909_RPMI.7951_LN4931'
#  'DS12374_AG10803_LN2497' 'DS12829_NHLF_LN2632' 'DS12863_NHDF_Ad_LN2643'
#  'DS26410A_h.AL_LN26455' 'DS14426_HSMM_LN3058' 'DS24640A_h.MG_63_LN21068'
#  'DS26313A_h.ELR_LN26395' 'DS20548_LHCN_M2_LN4870'
#  'DS24235A_h.SJSA_1_LN20839' 'DS20493_M059J_LN4859' 'DS15192_HAh_LN3285'
#  'DS24567A_h.Daoy_LN20970' 'DS11949_SKMC_LN2373' 'DS34574A_h.CEC_LN29827'
#  'DS14790_HAsp_LN3184']
#  Num samples 24
#  Num_DHSs 950
# density in reconstruction,  density in data,  precision,  recall
# 0.6444298245614035 0.6088157894736842 0.7588647655346084 0.8032562495497443
# doing cluster  25
# cluster length  5
# name of samples ['DS24825A_h.H4_LN21125' 'DS24930A_h.H4_LN21141' 'DS24744A_h.A172_LN21224'
#  'DS21975C_h.NCI_H226_LN27452' 'DS20534_LHCN_M2_LN4866']
# samples meeting threshold  ['DS24930A_h.H4_LN21141' 'DS24744A_h.A172_LN21224' 'DS24825A_h.H4_LN21125'
#  'DS21975C_h.NCI_H226_LN27452' 'DS39386_h.glomerular_LN32272'
#  'DS10666_HRCEpiC_LN1959' 'DS26685_h.podocytes_LN26974'
#  'DS20534_LHCN_M2_LN4866' 'DS27192_h.786_O_LN31650'
#  'DS24471A_h.ACHN_LN26820' 'DS27824_h.kidney.tubular_LN29654'
#  'DS26689_h.kidney.tubular_LN31651'
#  'DS26693A_h.renal.cell.carcinoma_LN26937' 'DS20548_LHCN_M2_LN4870'
#  'DS24547A_h.ACHN_LN20963' 'DS24640A_h.MG_63_LN21068'
#  'DS24211A_h.Caki_2_LN20836' 'DS14289_A549_LN3027' 'DS20493_M059J_LN4859'
#  'DS14426_HSMM_LN3058' 'DS24567A_h.Daoy_LN20970' 'DS14790_HAsp_LN3184'
#  'DS20909_RPMI.7951_LN4931' 'DS12829_NHLF_LN2632']
#  Num samples 19
#  Num_DHSs 1272
# density in reconstruction,  density in data,  precision,  recall
# 0.9381413439258524 0.8764068189341278 0.9090107175936135 0.9730418771540532
# doing cluster  26
# cluster length  3
# name of samples ['DS34646A_h.HT29_LN29816' 'DS34628A_h.LoVo_LN29819'
#  'DS38587A_h.HT29_LN32481']
# samples meeting threshold  ['DS34646A_h.HT29_LN29816' 'DS34628A_h.LoVo_LN29819'
#  'DS38587A_h.HT29_LN32481' 'DS20770_Small_Bowel_Mucosa_LN4899'
#  'DS17313_h.f.Intestine.Lg_LN3928' 'DS17317_fIntestine.Sm_LN3929'
#  'DS19794_T_47D_LN4656' 'DS17878_fStomach_LN4096' 'DS14289_A549_LN3027'
#  'DS44414_h.RKO_LN35453' 'DS24790A_HeLa_S3_LN21209'
#  'DS22913C_h.RPMI.8226_LN28562' 'DS24211A_h.Caki_2_LN20836'
#  'DS25027C_h.PC3_LN28558' 'DS22919_h.RPMI.8226_LN20400'
#  'DS21924A_fKidney_Right_LN20841' 'DS25129C_h.PC3_LN21648'
#  'DS18406_vHMEC_LN10000' 'DS22991_MCF10a_ER_SRC_LN20387']
#  Num samples 7
#  Num_DHSs 612
# density in reconstruction,  density in data,  precision,  recall
# 0.8195611577964519 0.8235294117647058 0.9139846197664483 0.9095804988662132
# doing cluster  27
# cluster length  1
# name of samples ['DS24147C_h.G401_LN28708']
# samples meeting threshold  ['DS24147C_h.G401_LN28708' 'DS22919_h.RPMI.8226_LN20400'
#  'DS22913C_h.RPMI.8226_LN28562' 'DS27522A_h.b.lymphoblast.mm.1s_LN26797'
#  'DS12436_GM12865_LN2528' 'DS27648A_h.Karpas_422_LN26836'
#  'DS29219C_h.Oci_Ly_7_LN28035']
#  Num samples 5
#  Num_DHSs 24
# density in reconstruction,  density in data,  precision,  recall
# 0.6916666666666667 0.525 0.5542168674698795 0.7301587301587301
# doing cluster  28
# cluster length  2
# name of samples ['DS27166A_h.PC9_LN26744' 'DS19794_T_47D_LN4656']
# samples meeting threshold  ['DS27166A_h.PC9_LN26744' 'DS19794_T_47D_LN4656' 'DS24790A_HeLa_S3_LN21209'
#  'DS19317_h.Trophoblast_LN10001' 'DS30557A_h.Trophoblast_LN28110']
#  Num samples 4
#  Num_DHSs 174
# density in reconstruction,  density in data,  precision,  recall
# 0.6954022988505747 0.7945402298850575 0.9235537190082644 0.8083182640144665
# doing cluster  29
# cluster length  3
# name of samples ['DS23123A_h.SJCRH30_LN20413' 'DS24808A_h.f.Tongue_LN21290'
#  'DS24888A_h.f.Tongue_LN21292']
# samples meeting threshold  ['DS24888A_h.f.Tongue_LN21292' 'DS24808A_h.f.Tongue_LN21290'
#  'DS20239_fMuscle_leg_LN4772' 'DS17767_fMuscle_back_LN4072']
#  Num samples 6
#  Num_DHSs 2749
# density in reconstruction,  density in data,  precision,  recall
# 0.9040863344246393 0.8548563113859585 0.906987660944206 0.9592198581560284
# doing cluster  30
# cluster length  3
# name of samples ['DS20786_fKidney_LN10113' 'DS23873E_fKidney_LN26814'
#  'DS17878_fStomach_LN4096']
# samples meeting threshold  ['DS20786_fKidney_LN10113' 'DS23873E_fKidney_LN26814'
#  'DS24726A_fLung_LN21205' 'DS23983C_fLung_LN20738' 'DS14724_fLung_LN3167'
#  'DS17878_fStomach_LN4096']
#  Num samples 8
#  Num_DHSs 448
# density in reconstruction,  density in data,  precision,  recall
# 0.7452566964285714 0.7536272321428571 0.8719580681392737 0.8622732321362458
# doing cluster  31
# cluster length  7
# name of samples ['DS22919_h.RPMI.8226_LN20400' 'DS12436_GM12865_LN2528'
#  'DS27522A_h.b.lymphoblast.mm.1s_LN26797' 'DS22913C_h.RPMI.8226_LN28562'
#  'DS17186_CD19+_LN3904' 'DS17706_h.Cord.Blood_LN4062'
#  'DS18208_CD20+_LN4156']
# samples meeting threshold  ['DS12436_GM12865_LN2528' 'DS17706_h.Cord.Blood_LN4062'
#  'DS18208_CD20+_LN4156' 'DS27522A_h.b.lymphoblast.mm.1s_LN26797'
#  'DS22919_h.RPMI.8226_LN20400' 'DS17186_CD19+_LN3904'
#  'DS29219C_h.Oci_Ly_7_LN28035' 'DS22913C_h.RPMI.8226_LN28562']
#  Num samples 14
#  Num_DHSs 392
# density in reconstruction,  density in data,  precision,  recall
# 0.7257653061224489 0.7458090379008746 0.8789856891790108 0.8553628145614464

# %% [markdown]
# # now find modules starting from DHS clusters

# %%
#reminder of how this works
'''
rawnormed_Mixturesums = np.sum(MixtureMat.T, axis=1)
rawnormed_MixtureRats = np.copy(MixtureMat.T)
rawnormed_MixtureRats = rawnormed_MixtureRats[rawnormed_Mixturesums>0]
rawnormed_Mixturesums = rawnormed_Mixturesums[rawnormed_Mixturesums>0]
for i, rat in  enumerate(rawnormed_MixtureRats):
    rat/=rawnormed_Mixturesums[i]

from sklearn.cluster import KMeans

kmeans_normed_sample_orig = KMeans(n_clusters=NMFcomps*2, random_state=0).fit(rawnormed_VecRats)
ClusterMeans = kmeans_normed_sample_orig.cluster_centers_
ClusterPredictions = kmeans_normed_sample_orig.predict(rawnormed_VecRats)
'''
# Out:
# '\nrawnormed_Mixturesums = np.sum(MixtureMat.T, axis=1)\nrawnormed_MixtureRats = np.copy(MixtureMat.T)\nrawnormed_MixtureRats = rawnormed_MixtureRats[rawnormed_Mixturesums>0]\nrawnormed_Mixturesums = rawnormed_Mixturesums[rawnormed_Mixturesums>0]\nfor i, rat in  enumerate(rawnormed_MixtureRats):\n    rat/=rawnormed_Mixturesums[i]\n\nfrom sklearn.cluster import KMeans\n\nkmeans_normed_sample_orig = KMeans(n_clusters=NMFcomps*2, random_state=0).fit(rawnormed_VecRats)\nClusterMeans = kmeans_normed_sample_orig.cluster_centers_\nClusterPredictions = kmeans_normed_sample_orig.predict(rawnormed_VecRats)\n'

# %%
kmeans_normed_DHS_orig = KMeans(n_clusters=NMFcomps*2, random_state=0).fit(rawnormed_MixtureRats)

# %%
ClusterMeansDHS = kmeans_normed_DHS_orig.cluster_centers_
ClusterPredictionsDHS = kmeans_normed_DHS_orig.predict(rawnormed_MixtureRats)

# %%
ClusterPredictionsDHS.shape
# Out:
# (142969,)

# %%
ClusterMeansDHS.shape
# Out:
# (32, 16)

# %%
ClustersDHS = []
ClusterMeanRealDHS = []
for i in range(NMFcomps*2):
    current_cut = np.argwhere(ClusterPredictionsDHS==i).T[0]
    themean = np.mean(MixtureMat.T[current_cut], axis=0)
    ClusterMeanRealDHS.append(themean)
    print(len(current_cut), themean.shape)
    print(i, len(ClusterPredictionsDHS[current_cut]), current_cut)
    #to mimic sample names, I'm just using the second element to "name" DHS's
    ClustersDHS.append([i, current_cut.astype(str), current_cut])
# Out:
# 8502 (16,)
# 0 8502 [    31     32     33 ..., 142390 142392 142393]
# 5553 (16,)
# 1 5553 [  2226   2227   2244 ..., 142728 142825 142826]
# 3641 (16,)
# 2 3641 [  1166   1167   1168 ..., 142949 142967 142968]
# 2886 (16,)
# 3 2886 [  1463   1464   1477 ..., 142752 142753 142754]
# 11815 (16,)
# 4 11815 [   206    207    208 ..., 142510 142511 142512]
# 3434 (16,)
# 5 3434 [     0      1     52 ..., 142449 142450 142451]
# 4141 (16,)
# 6 4141 [    11     12     13 ..., 142403 142404 142405]
# 3374 (16,)
# 7 3374 [   739    740    741 ..., 141501 141502 142367]
# 2954 (16,)
# 8 2954 [  1249   1307   1308 ..., 142850 142915 142916]
# 2371 (16,)
# 9 2371 [   611    612    613 ..., 142227 142368 142373]
# 3789 (16,)
# 10 3789 [   933    934    935 ..., 142166 142167 142168]
# 12052 (16,)
# 11 12052 [   175    177    178 ..., 142930 142931 142932]
# 4689 (16,)
# 12 4689 [  1124   1164   1172 ..., 142396 142397 142398]
# 4079 (16,)
# 13 4079 [   319    320    327 ..., 142520 142521 142522]
# 1541 (16,)
# 14 1541 [  5826   5827   5828 ..., 142067 142364 142365]
# 1423 (16,)
# 15 1423 [  1584   1585   1586 ..., 141874 141875 141876]
# 3258 (16,)
# 16 3258 [  1292   1293   1294 ..., 142822 142823 142824]
# 2393 (16,)
# 17 2393 [   654    655    656 ..., 140442 140455 140456]
# 3870 (16,)
# 18 3870 [    64     65     66 ..., 142964 142965 142966]
# 6122 (16,)
# 19 6122 [   209    210    211 ..., 142058 142059 142060]
# 2483 (16,)
# 20 2483 [   280    281    282 ..., 141172 141173 141174]
# 2893 (16,)
# 21 2893 [    15     16     17 ..., 141441 141442 141443]
# 2472 (16,)
# 22 2472 [   303    304    305 ..., 142479 142480 142481]
# 5273 (16,)
# 23 5273 [     2      3      4 ..., 142359 142391 142394]
# 3834 (16,)
# 24 3834 [   599    600    601 ..., 142282 142283 142284]
# 7580 (16,)
# 25 7580 [   920    947    948 ..., 142352 142353 142354]
# 7667 (16,)
# 26 7667 [    28     29     30 ..., 142528 142529 142530]
# 3006 (16,)
# 27 3006 [   368    369    370 ..., 142174 142175 142176]
# 7374 (16,)
# 28 7374 [  1984   1985   1986 ..., 142703 142704 142705]
# 3599 (16,)
# 29 3599 [  2030   2031   2032 ..., 142370 142371 142372]
# 2860 (16,)
# 30 2860 [   596    597    598 ..., 140393 140394 141267]
# 2041 (16,)
# 31 2041 [  2574   4511   4512 ..., 140620 140621 140622]

# %%
#threshold for what counts as a positive prediction in reconstruction matrix
chosenthresh = 0.5
#threshold for cosine similarity distance for samples to be included in this module. 0.1 gives about the same samples as in the original cluster for 80% component dominance. 
cosdist_sample_thresh = 0.5

#threshold for cosine similarity distance for DHS to be included in this module
cosdist_DHS_thresh = 0.3
for i, cluster in enumerate(ClustersDHS):

	print ('doing cluster ',i)
	# mean sample-wise component vector for this cluster
	mean_of_cluster = ClusterMeanRealDHS[i]
	#create a single 1 x NDHS prediction for the cluster to
	recon_cluster_Sam = np.dot(BasisMat, mean_of_cluster)
	#recon_cluster_DHS = np.dot(mean_of_cluster, MixtureMat)

	cluster_length = len(cluster[1])
	print('cluster length ',cluster_length)
	print('name of samples', cluster[1])
    
	#now you tile the vector to a size equivalent to N_DHS_in_cluster x NSamples
	kar = np.tile(recon_cluster_Sam, cluster_length).reshape(cluster_length, Nsamples)
	print(kar.shape)
	kar = kar.T
    
	#print(kar[0]-kar[1])    
	#***** NOTE: for some reason I decided to use original version of NMF matrices for cosine 
	#***** Similarity scores. Self-consistent? Not sure! 

	#calculate cosine similarity of cluster mean to all sample-component vectors 
	sample_cosdists = spdist.cdist(BasisMat, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()    
	#calculate cosine similarity of cluster mean to all DHS-component vectors 
	DHScosdists = spdist.cdist(MixtureMat.T, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()
	#now we sort these sample cosine distances

	closers = np.argsort(DHScosdists)

	#using the thresholds defined outside the loop, we find the samples that meet the closeness
	#criteria 
	Num_DHSs = len(DHScosdists[DHScosdists<cosdist_sample_thresh])
	print(' Num DHSs', Num_DHSs)
	print('DHSs meeting threshold ',closers[0:Num_DHSs])
	#First we use our decision threshold to figure out if the model predicts a positive
	#for a given position. Using the sample cluster mean component vector
	Sample_appear_cut = np.dot(mean_of_cluster, BasisMat.T)>chosenthresh
	#now sort the coside distances of DHS's that will appear from previous step    

	Sample_closeness = np.argsort(sample_cosdists[Sample_appear_cut])
	print('close samples ',sample_cosdists[Sample_appear_cut])
	Num_samples = len(sample_cosdists[Sample_appear_cut][sample_cosdists[Sample_appear_cut] < cosdist_sample_thresh])
	print(' Num_samples', Num_samples)

	'''
	#now we use the masks to create a miniature version of the reconstruction matrix for the given DHS only
	#strange use of double transpose 
	sorted_Module = np.dot(BasisMat[closers[0:Num_samples]], MixtureMat.T[DHSappear_cut][DHScloseness][0:Num_DHSs].T)
	#no idea how i pulled out this magic
	#this gives the real data corresponding to the module 
	corresponding_data = a[closers[0:Num_samples]][:,np.argwhere(DHSappear_cut == True).T[0][DHScloseness][0:Num_DHSs]]
	#flatten both modules to count accurate predictions. 
	flatsorted_Module = sorted_Module.flatten()
	flatcorresponding_data = corresponding_data.flatten()
	#calculate "density" i.e. number of entries of DHS hits within the module
	if (len(flatsorted_Module) > 0):
		density_in_recon = len(flatsorted_Module[flatsorted_Module>chosenthresh])/len(flatsorted_Module)
	else:
		density_in_recon = 0
	if(len(flatcorresponding_data) > 0):
		density_in_data = len(flatcorresponding_data[flatcorresponding_data>chosenthresh])/len(flatcorresponding_data)
	else:
		density_in_data = 0
	#calculate true positives, false positives, False negatives, precision ,recall
	TP =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
	FP =len(flatcorresponding_data[ np.invert(flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
	FN =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * np.invert(flatsorted_Module>chosenthresh)])
	if ((TP + FN ) > 0):
		recall = TP / (TP + FN)
	else: 
		recall = 0
	if ((TP +FP) > 0):
		precision = TP / (TP + FP)
	else:
		precision = 0
	print('density in reconstruction,  density in data,  precision,  recall')
	print(density_in_recon, density_in_data, precision, recall  )
	# don't remmeber how i figured this out either: I was possessed 
	#saves module as a list of samples in the header followed by a list of eahc DHS position
	#and whether it is or isn't present in the module.
	firstcut = np.copy(DHSappear_cut)
	firstcut[DHSappear_cut] *= (DHScosdists[DHSappear_cut] < cosdist_DHS_thresh)
	list1 = [Num_samples, Num_DHSs, chosenthresh, cosdist_sample_thresh,  cosdist_DHS_thresh, density_in_recon, density_in_data, precision, recall]
	theheader =  ' '.join(str(e) for e in list1)
	namestr = ' '.join(names[closers[0:Num_samples]])
	theheader +=' '+namestr
	#foutname = today+'Module'+str(i)+'.txt'
	#np.savetxt(foutname, firstcut, fmt='%i', header=theheader)
	'''
# Out:
# doing cluster  0
# cluster length  8502
# name of samples ['31' '32' '33' ..., '142390' '142392' '142393']
# (8502, 176)
#  Num DHSs 60448
# DHSs meeting threshold  [ 82968  82958  29503 ..., 135436 135435  64646]
# close samples  []
#  Num_samples 0
# doing cluster  1
# cluster length  5553
# name of samples ['2226' '2227' '2244' ..., '142728' '142825' '142826']
# (5553, 176)
#  Num DHSs 63205
# DHSs meeting threshold  [ 82969  82957 157485 ...,  64224  64227 185909]
# close samples  []
#  Num_samples 0
# doing cluster  2
# cluster length  3641
# name of samples ['1166' '1167' '1168' ..., '142949' '142967' '142968']
# (3641, 176)
#  Num DHSs 65898
# DHSs meeting threshold  [ 82968 158156  66488 ..., 150950 185846  27334]
# close samples  []
#  Num_samples 0
# doing cluster  3
# cluster length  2886
# name of samples ['1463' '1464' '1477' ..., '142752' '142753' '142754']
# (2886, 176)
#  Num DHSs 61987
# DHSs meeting threshold  [ 82968  71096  47064 ..., 126811 126813 139813]
# close samples  []
#  Num_samples 0
# doing cluster  4
# cluster length  11815
# name of samples ['206' '207' '208' ..., '142510' '142511' '142512']
# (11815, 176)
#  Num DHSs 65623
# DHSs meeting threshold  [ 82968  82969 171733 ...,  66914  67341 127935]
# close samples  []
#  Num_samples 0
# doing cluster  5
# cluster length  3434
# name of samples ['0' '1' '52' ..., '142449' '142450' '142451']
# (3434, 176)
#  Num DHSs 61337
# DHSs meeting threshold  [171734  82968 171735 ..., 176600  77807   3689]
# close samples  []
#  Num_samples 0
# doing cluster  6
# cluster length  4141
# name of samples ['11' '12' '13' ..., '142403' '142404' '142405']
# (4141, 176)
#  Num DHSs 60436
# DHSs meeting threshold  [ 82958  21033 127815 ...,  26972 185498  28937]
# close samples  []
#  Num_samples 0
# doing cluster  7
# cluster length  3374
# name of samples ['739' '740' '741' ..., '141501' '141502' '142367']
# (3374, 176)
#  Num DHSs 63254
# DHSs meeting threshold  [ 34333 119776  34334 ...,  38212 121077  67330]
# close samples  []
#  Num_samples 0
# doing cluster  8
# cluster length  2954
# name of samples ['1249' '1307' '1308' ..., '142850' '142915' '142916']
# (2954, 176)
#  Num DHSs 63016
# DHSs meeting threshold  [ 22240 131984 131985 ...,  49782 128875 162278]
# close samples  []
#  Num_samples 0
# doing cluster  9
# cluster length  2371
# name of samples ['611' '612' '613' ..., '142227' '142368' '142373']
# (2371, 176)
#  Num DHSs 60507
# DHSs meeting threshold  [127815  82958  60661 ...,   4694   4691   4693]
# close samples  []
#  Num_samples 0
# doing cluster  10
# cluster length  3789
# name of samples ['933' '934' '935' ..., '142166' '142167' '142168']
# (3789, 176)
#  Num DHSs 60247
# DHSs meeting threshold  [ 82968 171734 171735 ..., 119316   5004   5003]
# close samples  []
#  Num_samples 0
# doing cluster  11
# cluster length  12052
# name of samples ['175' '177' '178' ..., '142930' '142931' '142932']
# (12052, 176)
#  Num DHSs 61843
# DHSs meeting threshold  [ 82968 171734 171735 ..., 176530 142416 174585]
# close samples  []
#  Num_samples 0
# doing cluster  12
# cluster length  4689
# name of samples ['1124' '1164' '1172' ..., '142396' '142397' '142398']
# (4689, 176)
#  Num DHSs 64037
# DHSs meeting threshold  [146610  82969  84486 ..., 121395 121394 109367]
# close samples  []
#  Num_samples 0
# doing cluster  13
# cluster length  4079
# name of samples ['319' '320' '327' ..., '142520' '142521' '142522']
# (4079, 176)
#  Num DHSs 61272
# DHSs meeting threshold  [ 82968  47064 158149 ..., 153509  50916 192558]
# close samples  []
#  Num_samples 0
# doing cluster  14
# cluster length  1541
# name of samples ['5826' '5827' '5828' ..., '142067' '142364' '142365']
# (1541, 176)
#  Num DHSs 57173
# DHSs meeting threshold  [171773 171772 171774 ...,  35748 127912  85025]
# close samples  []
#  Num_samples 0
# doing cluster  15
# cluster length  1423
# name of samples ['1584' '1585' '1586' ..., '141874' '141875' '141876']
# (1423, 176)
#  Num DHSs 54381
# DHSs meeting threshold  [ 56602 171745  79404 ...,  79825  79826  79827]
# close samples  []
#  Num_samples 0
# doing cluster  16
# cluster length  3258
# name of samples ['1292' '1293' '1294' ..., '142822' '142823' '142824']
# (3258, 176)
#  Num DHSs 59314
# DHSs meeting threshold  [ 82969 141356  82968 ..., 145721 196743 196742]
# close samples  []
#  Num_samples 0
# doing cluster  17
# cluster length  2393
# name of samples ['654' '655' '656' ..., '140442' '140455' '140456']
# (2393, 176)
#  Num DHSs 62695
# DHSs meeting threshold  [ 82968  21033  21032 ..., 154554  33523 100914]
# close samples  []
#  Num_samples 0
# doing cluster  18
# cluster length  3870
# name of samples ['64' '65' '66' ..., '142964' '142965' '142966']
# (3870, 176)
#  Num DHSs 63994
# DHSs meeting threshold  [ 21033 119832 119776 ..., 155700  47386  47387]
# close samples  []
#  Num_samples 0
# doing cluster  19
# cluster length  6122
# name of samples ['209' '210' '211' ..., '142058' '142059' '142060']
# (6122, 176)
#  Num DHSs 60380
# DHSs meeting threshold  [ 82968  21033 171735 ...,  23701  23705  54910]
# close samples  []
#  Num_samples 0
# doing cluster  20
# cluster length  2483
# name of samples ['280' '281' '282' ..., '141172' '141173' '141174']
# (2483, 176)
#  Num DHSs 61262
# DHSs meeting threshold  [ 21033 127815 157717 ..., 159556 135118  20292]
# close samples  []
#  Num_samples 0
# doing cluster  21
# cluster length  2893
# name of samples ['15' '16' '17' ..., '141441' '141442' '141443']
# (2893, 176)
#  Num DHSs 61758
# DHSs meeting threshold  [ 82968  10309 119831 ...,  42712 115066 181693]
# close samples  []
#  Num_samples 0
# doing cluster  22
# cluster length  2472
# name of samples ['303' '304' '305' ..., '142479' '142480' '142481']
# (2472, 176)
#  Num DHSs 63828
# DHSs meeting threshold  [ 34333  34337  34335 ...,  49800 182134 153256]
# close samples  []
#  Num_samples 0
# doing cluster  23
# cluster length  5273
# name of samples ['2' '3' '4' ..., '142359' '142391' '142394']
# (5273, 176)
#  Num DHSs 59992
# DHSs meeting threshold  [171752  82968  82969 ...,  62231 163277 188177]
# close samples  []
#  Num_samples 0
# doing cluster  24
# cluster length  3834
# name of samples ['599' '600' '601' ..., '142282' '142283' '142284']
# (3834, 176)
#  Num DHSs 60952
# DHSs meeting threshold  [ 29503 119832  82958 ..., 149704  82566  50564]
# close samples  []
#  Num_samples 0
# doing cluster  25
# cluster length  7580
# name of samples ['920' '947' '948' ..., '142352' '142353' '142354']
# (7580, 176)
#  Num DHSs 62929
# DHSs meeting threshold  [ 82969  82968  82957 ..., 122292  31348  31347]
# close samples  []
#  Num_samples 0
# doing cluster  26
# cluster length  7667
# name of samples ['28' '29' '30' ..., '142528' '142529' '142530']
# (7667, 176)
#  Num DHSs 59763
# DHSs meeting threshold  [ 82968  47051  82958 ...,  34937  93380 116154]
# close samples  []
#  Num_samples 0
# doing cluster  27
# cluster length  3006
# name of samples ['368' '369' '370' ..., '142174' '142175' '142176']
# (3006, 176)
#  Num DHSs 65285
# DHSs meeting threshold  [ 68208  68207 119776 ...,  32710  40192 196670]
# close samples  []
#  Num_samples 0
# doing cluster  28
# cluster length  7374
# name of samples ['1984' '1985' '1986' ..., '142703' '142704' '142705']
# (7374, 176)
#  Num DHSs 65670
# DHSs meeting threshold  [ 21033 158149  82968 ...,  85796 142942 142943]
# close samples  []
#  Num_samples 0
# doing cluster  29
# cluster length  3599
# name of samples ['2030' '2031' '2032' ..., '142370' '142371' '142372']
# (3599, 176)
#  Num DHSs 60497
# DHSs meeting threshold  [127815  82968  29503 ...,  68959  68958 180968]
# close samples  []
#  Num_samples 0
# doing cluster  30
# cluster length  2860
# name of samples ['596' '597' '598' ..., '140393' '140394' '141267']
# (2860, 176)
#  Num DHSs 65612
# DHSs meeting threshold  [108934 171752  68208 ..., 131119 131120  96285]
# close samples  []
#  Num_samples 0
# doing cluster  31
# cluster length  2041
# name of samples ['2574' '4511' '4512' ..., '140620' '140621' '140622']
# (2041, 176)
#  Num DHSs 59881
# DHSs meeting threshold  [157485 171752  47051 ..., 147399 147398 147400]
# close samples  []
#  Num_samples 0

# %% [markdown]
# # confused as to why there are no hits so far
# # breaking down what this loop is doing

# %%
i = 1
cluster = ClustersDHS[1]

# %%
i
# Out:
# 1

# %%
cluster
# Out:
# [1, array(['2226', '2227', '2244', ..., '142728', '142825', '142826'],
#        dtype='<U21'), array([  2226,   2227,   2244, ..., 142728, 142825, 142826])]

# %%
mean_of_cluster = ClusterMeanRealDHS[i]

# %%
mean_of_cluster
# Out:
# array([ 0.05822718,  0.06602308,  0.07433184,  0.09739714,  0.08120447,
#         0.0742244 ,  0.12758088,  0.05706969,  0.04158215,  0.04890431,
#         0.04539347,  0.05544609,  0.04930681,  0.04954408,  0.04463254,
#         0.03677961])

# %%
ClusterMeansDHS[i]
# Out:
# array([ 0.01198427,  0.00371326,  0.00688537,  0.01065807,  0.00209255,
#         0.0054197 ,  0.86434062,  0.00405588,  0.00183566,  0.0137023 ,
#         0.00205556,  0.00882534,  0.00344329,  0.01664763,  0.00177357,
#         0.04256691])

# %% [markdown]
# So using the normalization method actually brings out DHS component prominence significantly. (look at component [3])

# %%
np.sum(mean_of_cluster)
# Out:
# 1.0076477354396465

# %% [markdown]
# strangely the mean of the cluster is earily clsoe too 1

# %%
recon_cluster_Sam = np.dot(BasisMat, mean_of_cluster)
recon_cluster_Sam
# Out:
# array([ 0.1020025 ,  0.07768347,  0.05108312,  0.08168151,  0.12938347,
#         0.18651251,  0.14132165,  0.12187916,  0.13372164,  0.11913432,
#         0.11390353,  0.08655075,  0.07204568,  0.10000272,  0.10128194,
#         0.12112767,  0.11283353,  0.09136   ,  0.11300922,  0.08389669,
#         0.15535111,  0.15129931,  0.12088458,  0.05239591,  0.131231  ,
#         0.1010999 ,  0.17291445,  0.11526417,  0.10263092,  0.02892085,
#         0.09485474,  0.10932463,  0.12720252,  0.10478395,  0.11363785,
#         0.08120893,  0.10497748,  0.10982251,  0.08293941,  0.05359996,
#         0.05656346,  0.14840515,  0.1630957 ,  0.11769693,  0.10791017,
#         0.13920757,  0.09096403,  0.07185517,  0.12589026,  0.11741236,
#         0.12384789,  0.10295215,  0.08686159,  0.13181881,  0.08467922,
#         0.08165411,  0.08646335,  0.10433852,  0.11890637,  0.1170187 ,
#         0.09001719,  0.09557137,  0.1045769 ,  0.10414237,  0.12661849,
#         0.11804146,  0.11192252,  0.09648954,  0.0966603 ,  0.10310811,
#         0.13996472,  0.11506703,  0.13131441,  0.07489117,  0.09959972,
#         0.14523291,  0.12329576,  0.09183727,  0.075222  ,  0.12962052,
#         0.09837553,  0.08214219,  0.08007845,  0.07276451,  0.0704708 ,
#         0.13887379,  0.11447221,  0.11007369,  0.07950396,  0.06530406,
#         0.09210116,  0.0800727 ,  0.09813099,  0.15563863,  0.11769852,
#         0.0895773 ,  0.09686545,  0.09296301,  0.08319047,  0.07028661,
#         0.10975478,  0.09666207,  0.09653846,  0.09928844,  0.10010057,
#         0.09684745,  0.11751453,  0.08252772,  0.11278335,  0.13091674,
#         0.10620962,  0.09076814,  0.1801441 ,  0.10680326,  0.09717469,
#         0.09070527,  0.11322513,  0.09567959,  0.07294905,  0.11148682,
#         0.08715008,  0.07309543,  0.09254588,  0.08258155,  0.07941949,
#         0.08595162,  0.07988517,  0.14744049,  0.07885288,  0.10100727,
#         0.06161508,  0.09652784,  0.11050504,  0.09579604,  0.07199293,
#         0.09975704,  0.10427273,  0.13352692,  0.09547001,  0.07442945,
#         0.1110103 ,  0.13872081,  0.13001314,  0.10966825,  0.13350755,
#         0.10103323,  0.12448133,  0.12816133,  0.10750621,  0.10848521,
#         0.10595629,  0.15790421,  0.13757179,  0.13345406,  0.08997231,
#         0.07939521,  0.11084304,  0.13370616,  0.09271718,  0.10040463,
#         0.09152844,  0.08587376,  0.08655605,  0.09530489,  0.08200219,
#         0.08630026,  0.13504532,  0.14950235,  0.10232173,  0.10900044,
#         0.12486696,  0.10825467,  0.10524549,  0.08703398,  0.09697634,
#         0.09762225])

# %%
len(recon_cluster_Sam[recon_cluster_Sam>0.15])
# Out:
# 8

# %%
cluster_length = len(cluster[1])
print('cluster length ',cluster_length)
print('name of samples', cluster[1])
# Out:
# cluster length  5553
# name of samples ['2226' '2227' '2244' ..., '142728' '142825' '142826']

# %%
#now you tile the vector to a size equivalent to N_samples_in_cluster x NDHS
kar = np.tile(recon_cluster_Sam, cluster_length).reshape(cluster_length, Nsamples)
print(kar.shape)
kar = kar.T
# Out:
# (5553, 176)

# %%
kar.shape
# Out:
# (176, 5553)

# %%
sample_cosdists = spdist.cdist(BasisMat, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()    
#calculate cosine similarity of cluster mean to all DHS-component vectors 
DHScosdists = spdist.cdist(MixtureMat.T, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()
#now we sort these sample cosine distances

# %%
DHScosdists[np.isfinite(DHScosdists)].shape
# Out:
# (142969,)

# %%
sample_cosdists
# Out:
# array([ 0.66023464,  0.64214774,  0.60960991,  0.6313073 ,  0.4697448 ,
#         0.72574436,  0.72395996,  0.48572436,  0.44873567,  0.71574305,
#         0.64409009,  0.70213946,  0.7923714 ,  0.86282019,  0.86282019,
#         0.69338896,  0.68491382,  0.72093851,  0.52245613,  0.75253004,
#         0.78030437,  0.77184004,  0.73123654,  0.67606646,  0.73817555,
#         0.68747761,  0.74340242,  0.70594501,  0.83281174,  0.7828255 ,
#         0.7029652 ,  0.56435293,  0.65629252,  0.74273023,  0.80794105,
#         0.65609234,  0.69901341,  0.47131141,  0.5850186 ,  0.64180928,
#         0.62794095,  0.80292066,  0.76036299,  0.82966454,  0.55059091,
#         0.76528702,  0.57244301,  0.66227351,  0.74639847,  0.63586032,
#         0.62470417,  0.73581688,  0.61109028,  0.78877669,  0.66878174,
#         0.67128335,  0.59799629,  0.68407811,  0.6467219 ,  0.7366177 ,
#         0.72883049,  0.63146457,  0.68936733,  0.68113172,  0.80351232,
#         0.70881167,  0.65543328,  0.70035655,  0.64720747,  0.67082005,
#         0.80927853,  0.81088503,  0.81403265,  0.68702045,  0.68951863,
#         0.65047233,  0.58132478,  0.68749341,  0.75028079,  0.589302  ,
#         0.5879326 ,  0.59954403,  0.61042821,  0.61571018,  0.72593802,
#         0.78119737,  0.75287448,  0.69239829,  0.73276852,  0.84302356,
#         0.86129509,  0.49092178,  0.78575889,  0.79862688,  0.80217393,
#         0.75914543,  0.67282419,  0.60547978,  0.65886258,  0.53590634,
#         0.67574476,  0.65536663,  0.6592725 ,  0.62165964,  0.70369409,
#         0.69731448,  0.58400716,  0.83070242,  0.79698905,  0.78435261,
#         0.66383593,  0.67234829,  0.79220179,  0.5947704 ,  0.65175623,
#         0.70907923,  0.61319182,  0.72739696,  0.51862157,  0.64603718,
#         0.48382687,  0.81050372,  0.65774854,  0.66216066,  0.59368317,
#         0.58997932,  0.46371896,  0.79834692,  0.64440034,  0.47234841,
#         0.81000232,  0.73306466,  0.83909731,  0.58678197,  0.78979198,
#         0.6490663 ,  0.67975195,  0.57639181,  0.73125124,  0.48956579,
#         0.74689339,  0.66159998,  0.51695646,  0.48934161,  0.50516431,
#         0.53454178,  0.77541418,  0.76668479,  0.46898003,  0.48718373,
#         0.66208216,  0.68635864,  0.54091068,  0.46080149,  0.4736471 ,
#         0.47693602,  0.63073305,  0.63814489,  0.78552842,  0.56676086,
#         0.80435739,  0.80166353,  0.79041835,  0.80648898,  0.50431848,
#         0.80226228,  0.69515896,  0.70491253,  0.35897979,  0.39491857,
#         0.6621064 ,  0.6335019 ,  0.50837894,  0.59946219,  0.73391579,
#         0.66196333])

# %%
np.sort(sample_cosdists)
# Out:
# array([ 0.35897979,  0.39491857,  0.44873567,  0.46080149,  0.46371896,
#         0.46898003,  0.4697448 ,  0.47131141,  0.47234841,  0.4736471 ,
#         0.47693602,  0.48382687,  0.48572436,  0.48718373,  0.48934161,
#         0.48956579,  0.49092178,  0.50431848,  0.50516431,  0.50837894,
#         0.51695646,  0.51862157,  0.52245613,  0.53454178,  0.53590634,
#         0.54091068,  0.55059091,  0.56435293,  0.56676086,  0.57244301,
#         0.57639181,  0.58132478,  0.58400716,  0.5850186 ,  0.58678197,
#         0.5879326 ,  0.589302  ,  0.58997932,  0.59368317,  0.5947704 ,
#         0.59799629,  0.59946219,  0.59954403,  0.60547978,  0.60960991,
#         0.61042821,  0.61109028,  0.61319182,  0.61571018,  0.62165964,
#         0.62470417,  0.62794095,  0.63073305,  0.6313073 ,  0.63146457,
#         0.6335019 ,  0.63586032,  0.63814489,  0.64180928,  0.64214774,
#         0.64409009,  0.64440034,  0.64603718,  0.6467219 ,  0.64720747,
#         0.6490663 ,  0.65047233,  0.65175623,  0.65536663,  0.65543328,
#         0.65609234,  0.65629252,  0.65774854,  0.65886258,  0.6592725 ,
#         0.66023464,  0.66159998,  0.66196333,  0.66208216,  0.6621064 ,
#         0.66216066,  0.66227351,  0.66383593,  0.66878174,  0.67082005,
#         0.67128335,  0.67234829,  0.67282419,  0.67574476,  0.67606646,
#         0.67975195,  0.68113172,  0.68407811,  0.68491382,  0.68635864,
#         0.68702045,  0.68747761,  0.68749341,  0.68936733,  0.68951863,
#         0.69239829,  0.69338896,  0.69515896,  0.69731448,  0.69901341,
#         0.70035655,  0.70213946,  0.7029652 ,  0.70369409,  0.70491253,
#         0.70594501,  0.70881167,  0.70907923,  0.71574305,  0.72093851,
#         0.72395996,  0.72574436,  0.72593802,  0.72739696,  0.72883049,
#         0.73123654,  0.73125124,  0.73276852,  0.73306466,  0.73391579,
#         0.73581688,  0.7366177 ,  0.73817555,  0.74273023,  0.74340242,
#         0.74639847,  0.74689339,  0.75028079,  0.75253004,  0.75287448,
#         0.75914543,  0.76036299,  0.76528702,  0.76668479,  0.77184004,
#         0.77541418,  0.78030437,  0.78119737,  0.7828255 ,  0.78435261,
#         0.78552842,  0.78575889,  0.78877669,  0.78979198,  0.79041835,
#         0.79220179,  0.7923714 ,  0.79698905,  0.79834692,  0.79862688,
#         0.80166353,  0.80217393,  0.80226228,  0.80292066,  0.80351232,
#         0.80435739,  0.80648898,  0.80794105,  0.80927853,  0.81000232,
#         0.81050372,  0.81088503,  0.81403265,  0.82966454,  0.83070242,
#         0.83281174,  0.83909731,  0.84302356,  0.86129509,  0.86282019,
#         0.86282019])

# %%
np.sort(DHScosdists[np.isfinite(DHScosdists)])[0:50]
# Out:
# array([ 0.00708659,  0.01304132,  0.01440481,  0.0153048 ,  0.01538528,
#         0.01602576,  0.01631966,  0.01720278,  0.01737159,  0.0180378 ,
#         0.01827807,  0.01927728,  0.01929385,  0.01929385,  0.01930549,
#         0.01930549,  0.01948113,  0.01984151,  0.01986077,  0.02002447,
#         0.02010554,  0.02016422,  0.02017137,  0.02022556,  0.02027348,
#         0.02032024,  0.02045124,  0.02061076,  0.02082312,  0.0208321 ,
#         0.02086567,  0.0208923 ,  0.02102452,  0.0214732 ,  0.0214732 ,
#         0.02151757,  0.02166665,  0.02170902,  0.02170902,  0.02170902,
#         0.02171756,  0.02171756,  0.02171756,  0.02171756,  0.02171866,
#         0.02189743,  0.02192897,  0.0220662 ,  0.02210256,  0.02235327])

# %% [markdown]
# So there are SOME DHS within 0.05 and some samples within 0.5  if we use even the crappy unnormalized cluster

# %%
closers = np.argsort(DHScosdists)

# %%
closers
# Out:
# array([ 82969,  82957, 157485, ..., 100772, 100780, 199999])

# %%
DHScosdists[closers]
# Out:
# array([ 0.00708659,  0.01304132,  0.01440481, ...,         nan,
#                nan,         nan])

# %%
Num_DHSs = len(DHScosdists[DHScosdists<cosdist_sample_thresh])

# %%
Num_DHSs
# Out:
# 63205

# %%
chosenthresh = 0.15

# %% [markdown]
# Has to be this low or it won't work at all

# %%
Sample_appear_cut = np.dot(mean_of_cluster, BasisMat.T)>chosenthresh

# %%
Sample_appear_cut.shape
# Out:
# (176,)

# %%
Sample_appear_cut[Sample_appear_cut]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
cosdist_sample_thresh = 0.75

# %%
Sample_closeness = np.argsort(sample_cosdists[Sample_appear_cut])
print('close samples ',sample_cosdists[Sample_appear_cut])
Num_samples = len(sample_cosdists[Sample_appear_cut][sample_cosdists[Sample_appear_cut] < cosdist_sample_thresh])
print(' Num_samples', Num_samples)
# Out:
# close samples  [ 0.72574436  0.78030437  0.77184004  0.74340242  0.76036299  0.79862688
#   0.79220179  0.68635864]
#  Num_samples 3

# %% [markdown]
# yep this sucks too. Doesn't work unless i set ridiculously high cosdist sample threshold

# %%
BasisMat[Sample_appear_cut][Sample_closeness][0:Num_samples]
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   2.12094960e-02,   1.86337961e+00,
#           1.45197911e-02,   6.60361815e-02,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   2.20981430e-01,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           2.05229999e-03,   1.99095307e-02,   4.89285891e-02,
#           4.73894941e-02,   3.98663875e-01,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   2.85574787e-01,
#           2.83717562e-01,   2.47140222e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  0.00000000e+00,   4.66178787e-02,   4.25898477e-02,
#           3.43361694e-03,   0.00000000e+00,   1.49222180e-01,
#           0.00000000e+00,   0.00000000e+00,   1.20157780e-01,
#           0.00000000e+00,   2.09308827e-02,   2.50228652e+00,
#           8.46569517e-02,   6.94571541e-02,   4.02350945e-02,
#           3.15602772e-02]])

# %%
BasisMat[Sample_appear_cut][Sample_closeness][0:Num_samples].shape
# Out:
# (3, 16)

# %%
MixtureMat.T[closers][0:Num_DHSs].shape
# Out:
# (63205, 16)

# %%
sorted_Module = np.dot(BasisMat[Sample_appear_cut][Sample_closeness][0:Num_samples], MixtureMat.T[closers][0:Num_DHSs].T)

# %%
sorted_Module.shape
# Out:
# (3, 63205)

# %%
corresponding_data = a[Sample_appear_cut][Sample_closeness][0:Num_samples][:,np.arange(NDHS)[closers][0:Num_DHSs]]

# %%
corresponding_data.shape
# Out:
# (3, 63205)

# %%
flatsorted_Module = sorted_Module.flatten()
flatcorresponding_data = corresponding_data.flatten()
#calculate "density" i.e. number of entries of DHS hits within the module
if (len(flatsorted_Module) > 0):
    density_in_recon = len(flatsorted_Module[flatsorted_Module>chosenthresh])/len(flatsorted_Module)
else:
    density_in_recon = 0
if(len(flatcorresponding_data) > 0):
    density_in_data = len(flatcorresponding_data[flatcorresponding_data>chosenthresh])/len(flatcorresponding_data)
else:
    density_in_data = 0
#calculate true positives, false positives, False negatives, precision ,recall
TP =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
FP =len(flatcorresponding_data[ np.invert(flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
FN =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * np.invert(flatsorted_Module>chosenthresh)])
if ((TP + FN ) > 0):
    recall = TP / (TP + FN)
else: 
    recall = 0
if ((TP +FP) > 0):
    precision = TP / (TP + FP)
else:
    precision = 0
print('density in reconstruction,  density in data,  precision,  recall')
print(density_in_recon, density_in_data, precision, recall  )
# Out:
# density in reconstruction,  density in data,  precision,  recall
# 0.5774912322337368 0.4168024681591646 0.7184409274801143 0.9954195768802511

# %%
firstcut = np.zeros(NDHS)
firstcut[closers][0:Num_DHSs] += 1

# %%
list1 = [Num_samples, Num_DHSs, chosenthresh, cosdist_sample_thresh,  cosdist_DHS_thresh, density_in_recon, density_in_data, precision, recall]

# %%
theheader =  ' '.join(str(e) for e in list1)
namestr = ' '.join(names[Sample_appear_cut][Sample_closeness][0:Num_samples])
theheader +=' '+namestr

# %%
namestr
# Out:
# 'DS17767_fMuscle_back_LN4072 DS20346_fPlacenta_LN10066 DS23833A_h.f.Eye_LN20656'

# %% [markdown]
# # trying again via loop (using real DHS centroids)

# %%
chosenthresh = 0.15
#threshold for cosine similarity distance for samples to be included in this module. 0.1 gives about the same samples as in the original cluster for 80% component dominance. 
cosdist_sample_thresh = 0.75

#threshold for cosine similarity distance for DHS to be included in this module
cosdist_DHS_thresh = 0.3
for i, cluster in enumerate(ClustersDHS):

    print ('doing cluster ',i)
    # mean sample-wise component vector for this cluster
    mean_of_cluster = ClusterMeanRealDHS[i]
    #create a single 1 x NDHS prediction for the cluster to
    recon_cluster_Sam = np.dot(BasisMat, mean_of_cluster)
    #recon_cluster_DHS = np.dot(mean_of_cluster, MixtureMat)

    cluster_length = len(cluster[1])
    print('cluster length ',cluster_length)
    print('name of samples', cluster[1])

    #now you tile the vector to a size equivalent to N_DHS_in_cluster x NSamples
    kar = np.tile(recon_cluster_Sam, cluster_length).reshape(cluster_length, Nsamples)
    print(kar.shape)
    kar = kar.T

    #print(kar[0]-kar[1])    
    #***** NOTE: for some reason I decided to use original version of NMF matrices for cosine 
    #***** Similarity scores. Self-consistent? Not sure! 

    #calculate cosine similarity of cluster mean to all sample-component vectors 
    sample_cosdists = spdist.cdist(BasisMat, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()    
    #calculate cosine similarity of cluster mean to all DHS-component vectors 
    DHScosdists = spdist.cdist(MixtureMat.T, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()
    #now we sort these sample cosine distances

    closers = np.argsort(DHScosdists)

    #using the thresholds defined outside the loop, we find the samples that meet the closeness
    #criteria 
    Num_DHSs = len(DHScosdists[DHScosdists<cosdist_sample_thresh])
    print(' Num DHSs', Num_DHSs)
    print('DHSs meeting threshold ',closers[0:Num_DHSs])
    #First we use our decision threshold to figure out if the model predicts a positive
    #for a given position. Using the sample cluster mean component vector
    Sample_appear_cut = np.dot(mean_of_cluster, BasisMat.T)>chosenthresh
    #now sort the coside distances of DHS's that will appear from previous step    

    Sample_closeness = np.argsort(sample_cosdists[Sample_appear_cut])
    print('close samples ',sample_cosdists[Sample_appear_cut])
    Num_samples = len(sample_cosdists[Sample_appear_cut][sample_cosdists[Sample_appear_cut] < cosdist_sample_thresh])
    print(' Num_samples', Num_samples)

    sorted_Module = np.dot(BasisMat[Sample_appear_cut][Sample_closeness][0:Num_samples], MixtureMat.T[closers][0:Num_DHSs].T)
    corresponding_data = a[Sample_appear_cut][Sample_closeness][0:Num_samples][:,np.arange(NDHS)[closers][0:Num_DHSs]]
    flatsorted_Module = sorted_Module.flatten()
    flatcorresponding_data = corresponding_data.flatten()
    #calculate "density" i.e. number of entries of DHS hits within the module
    if (len(flatsorted_Module) > 0):
        density_in_recon = len(flatsorted_Module[flatsorted_Module>chosenthresh])/len(flatsorted_Module)
    else:
        density_in_recon = 0
    if(len(flatcorresponding_data) > 0):
        density_in_data = len(flatcorresponding_data[flatcorresponding_data>chosenthresh])/len(flatcorresponding_data)
    else:
        density_in_data = 0
    #calculate true positives, false positives, False negatives, precision ,recall
    TP =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
    FP =len(flatcorresponding_data[ np.invert(flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
    FN =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * np.invert(flatsorted_Module>chosenthresh)])
    if ((TP + FN ) > 0):
        recall = TP / (TP + FN)
    else: 
        recall = 0
    if ((TP +FP) > 0):
        precision = TP / (TP + FP)
    else:
        precision = 0
    print('density in reconstruction,  density in data,  precision,  recall')
    print(density_in_recon, density_in_data, precision, recall  )
    firstcut = np.zeros(NDHS)
    firstcut[closers][0:Num_DHSs] += 1
    list1 = [Num_samples, Num_DHSs, chosenthresh, cosdist_sample_thresh,  cosdist_DHS_thresh, density_in_recon, density_in_data, precision, recall]
    theheader =  ' '.join(str(e) for e in list1)
    namestr = ' '.join(names[Sample_appear_cut][Sample_closeness][0:Num_samples])
    theheader +=' '+namestr
    print(namestr)
# Out:
# doing cluster  0
# cluster length  8502
# name of samples ['31' '32' '33' ..., '142390' '142392' '142393']
# (8502, 176)
#  Num DHSs 127240
# DHSs meeting threshold  [ 82968  82958  29503 ..., 123761  67434  53861]
# close samples  [ 0.47409042  0.77938278  0.69272076  0.81374756  0.80374952  0.73376755
#   0.7758224   0.82396248  0.79187757  0.80070422  0.61490029  0.65169914
#   0.58886075  0.82113003  0.83858314  0.80880186  0.57242276  0.67909595
#   0.69645321  0.53516453  0.64115807  0.69393815  0.71021521]
#  Num_samples 13
# density in reconstruction,  density in data,  precision,  recall
# 0.3684587575266607 0.23255991101008391 0.5978243570285902 0.9471693502685334
# DS21042_h.H1.polyMSC_LN10043 DS17878_fStomach_LN4096 DS15192_HAh_LN3285 DS26410A_h.AL_LN26455 DS24888A_h.f.Tongue_LN21292 DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS17186_CD19+_LN3904 DS20786_fKidney_LN10113 DS20239_fMuscle_leg_LN4772 DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773 DS23559_h.EH_LN20491
# doing cluster  1
# cluster length  5553
# name of samples ['2226' '2227' '2244' ..., '142728' '142825' '142826']
# (5553, 176)
#  Num DHSs 128878
# DHSs meeting threshold  [ 82969  82957 157485 ..., 119882 119883 108310]
# close samples  [ 0.72574436  0.78030437  0.77184004  0.74340242  0.76036299  0.79862688
#   0.79220179  0.68635864]
#  Num_samples 3
# density in reconstruction,  density in data,  precision,  recall
# 0.40444192699038367 0.2651706782124697 0.6490781538776371 0.9899828332878156
# DS17767_fMuscle_back_LN4072 DS20346_fPlacenta_LN10066 DS23833A_h.f.Eye_LN20656
# doing cluster  2
# cluster length  3641
# name of samples ['1166' '1167' '1168' ..., '142949' '142967' '142968']
# (3641, 176)
#  Num DHSs 124918
# DHSs meeting threshold  [ 82968 158156  66488 ...,  72722 157249 157250]
# close samples  [ 0.78624017  0.46291801  0.44558755  0.76878814  0.75806906  0.75865991
#   0.7389119   0.65703691  0.7530307   0.74855238  0.72335862  0.67613735
#   0.49016081  0.72582761  0.84443869  0.55041674  0.58051289  0.63712279
#   0.50056045  0.48949354  0.74452536  0.58246313  0.45510445  0.66694106
#   0.65794528]
#  Num_samples 19
# density in reconstruction,  density in data,  precision,  recall
# 0.34918148410620525 0.22657600227854735 0.6085522743562084 0.9378538952888343
# DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS17885_CD8+_LN10088 DS17203_CD8+_LN3907 DS26455A_h.iPSC_LN26496 DS17189_CD56+_LN3905 DS32096A_h.neuronal_stem_cell_LN28669 DS15192_HAh_LN3285 DS17878_fStomach_LN4096 DS17186_CD19+_LN3904 DS21924A_fKidney_Right_LN20841 DS20351_fSpinal_cord_LN4807 DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS24833A_fSpinalCord_LN21289 DS23339E_h.f.Retina_LN26813 DS23833A_h.f.Eye_LN20656 DS17767_fMuscle_back_LN4072 DS24796A_h.f.Eye_LN21208
# doing cluster  3
# cluster length  2886
# name of samples ['1463' '1464' '1477' ..., '142752' '142753' '142754']
# (2886, 176)
#  Num DHSs 127082
# DHSs meeting threshold  [ 82968  71096  47064 ..., 109538 109537 189851]
# close samples  [ 0.75872071  0.77023126  0.75972405  0.73854263  0.7528452   0.75006465
#   0.82561323]
#  Num_samples 1
# density in reconstruction,  density in data,  precision,  recall
# 0.3869234037865315 0.2709195637462426 0.6822924081267414 0.9744401521972755
# DS23833A_h.f.Eye_LN20656
# doing cluster  4
# cluster length  11815
# name of samples ['206' '207' '208' ..., '142510' '142511' '142512']
# (11815, 176)
#  Num DHSs 127384
# DHSs meeting threshold  [ 82968  82969 171733 ..., 172136  85512 145160]
# close samples  [ 0.75921546  0.7991511   0.78979171  0.76438897  0.78027529  0.65037843
#   0.81867581  0.64233739  0.7194677 ]
#  Num_samples 3
# density in reconstruction,  density in data,  precision,  recall
# 0.3752302748644518 0.26679174778622117 0.661578158234248 0.9304791329508116
# DS17186_CD19+_LN3904 DS26113A_h.Fibroblast_LN26368 DS17767_fMuscle_back_LN4072
# doing cluster  5
# cluster length  3434
# name of samples ['0' '1' '52' ..., '142449' '142450' '142451']
# (3434, 176)
#  Num DHSs 126096
# DHSs meeting threshold  [171734  82968 171735 ...,  47728 111652 111651]
# close samples  [ 0.78413107  0.70958375  0.77612374  0.79319538  0.62075781  0.83797554
#   0.70555775  0.60773634  0.7223035 ]
#  Num_samples 5
# density in reconstruction,  density in data,  precision,  recall
# 0.36516305037431795 0.2508580763862454 0.6649582153343642 0.9679503796764057
# DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS17767_fMuscle_back_LN4072 DS23559_h.EH_LN20491 DS20242_fMuscle_trunk_LN4773
# doing cluster  6
# cluster length  4141
# name of samples ['11' '12' '13' ..., '142403' '142404' '142405']
# (4141, 176)
#  Num DHSs 126615
# DHSs meeting threshold  [ 82958  21033 127815 ..., 179656 181662  13392]
# close samples  [ 0.77986089  0.83548784  0.69356303  0.70594035]
#  Num_samples 2
# density in reconstruction,  density in data,  precision,  recall
# 0.37430794139714885 0.25952296331398333 0.6924229316565738 0.9986761819260792
# DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773
# doing cluster  7
# cluster length  3374
# name of samples ['739' '740' '741' ..., '141501' '141502' '142367']
# (3374, 176)
#  Num DHSs 125993
# DHSs meeting threshold  [ 34333 119776  34334 ..., 176901  49069 176198]
# close samples  []
#  Num_samples 0
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
#
# doing cluster  8
# cluster length  2954
# name of samples ['1249' '1307' '1308' ..., '142850' '142915' '142916']
# (2954, 176)
#  Num DHSs 121362
# DHSs meeting threshold  [ 22240 131984 131985 ...,  40171  40172  40173]
# close samples  [ 0.36155611  0.35256549  0.78716523  0.77439406  0.75375983  0.76948643
#   0.80469973  0.76790389  0.65194821  0.39713459  0.36490389  0.38762049
#   0.70715383  0.5161838   0.35914249  0.72981133]
#  Num_samples 10
# density in reconstruction,  density in data,  precision,  recall
# 0.3476269342957433 0.24039814769038084 0.6525515126088265 0.9436199237708739
# DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS17885_CD8+_LN10088 DS17198_CD3+_LN3906 DS17203_CD8+_LN3907 DS17189_CD56+_LN3905 DS17878_fStomach_LN4096 DS17186_CD19+_LN3904 DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773
# doing cluster  9
# cluster length  2371
# name of samples ['611' '612' '613' ..., '142227' '142368' '142373']
# (2371, 176)
#  Num DHSs 126044
# DHSs meeting threshold  [127815  82958  60661 ..., 184893 184895 184894]
# close samples  [ 0.66229716  0.53195698  0.7992631   0.75776098  0.50995037  0.48655565
#   0.72086772  0.65448146  0.81930576  0.81930576  0.70878363  0.7032087
#   0.66346002  0.54042608  0.82151478  0.81053108  0.75272852  0.76299447
#   0.69847053  0.78865272  0.71928377  0.82470731  0.67547297  0.57906199
#   0.69415972  0.75340213  0.82784298  0.6035967   0.67534337  0.47763187
#   0.84683483  0.80298883  0.82885001  0.57794565  0.7948955   0.7561586
#   0.65587573  0.65483248  0.72646769  0.56179779  0.81855656  0.69854498
#   0.69586331  0.75997963  0.58281527  0.8372334   0.7273559   0.69894834
#   0.6765436   0.83703285  0.83192985  0.8410563   0.69535018  0.68373119
#   0.59301345  0.62960007  0.58852688  0.82492985  0.76764544  0.69962951
#   0.68360113  0.81800314  0.75861447  0.846184    0.83478214  0.7283684
#   0.6507703   0.57362782  0.66955892  0.63705317  0.61736949  0.62520825
#   0.77795796  0.8344014   0.8535393   0.61666322  0.64783759  0.65351298
#   0.64301314  0.71208307  0.69438638  0.64464362  0.85494545  0.45742012
#   0.70998103  0.83476981  0.59763716  0.63899941  0.68680437  0.60217669
#   0.76895158  0.64346074  0.54026707  0.49227001  0.53085674  0.55607745
#   0.79463115  0.78875565  0.46469911  0.48997014  0.63014762  0.74251756
#   0.5746692   0.49991006  0.44112169  0.60803095  0.67668306  0.77790876
#   0.56496467  0.79777064  0.80247144  0.73346646  0.75520038  0.39636372
#   0.39290997  0.67617918  0.62738428  0.51609451  0.73419842  0.65517026]
#  Num_samples 79
# density in reconstruction,  density in data,  precision,  recall
# 0.3099819673178223 0.18723389340832958 0.561916233779277 0.9303011139914299
# DS20341_fThymus_LN4803 DS20325_Psoas_muscle_LN4801 DS18015_TH1_LN4128 DS14702_hTreg_LN3156 DS17597_TH2_LN4024 DS24567A_h.Daoy_LN20970 DS17212_CD4+_LN10089 DS17603_iTH2_LN4026 DS17198_CD3+_LN3906 DS17881_CD4+_LN4097 DS17885_CD8+_LN10088 DS20534_LHCN_M2_LN4866 DS17203_CD8+_LN3907 DS21042_h.H1.polyMSC_LN10043 DS17189_CD56+_LN3905 DS23123A_h.SJCRH30_LN20413 DS17215_h.CD14+_LN3909 DS25067A_h.L1_S8_LN21363 DS19310_Mesendoderm_LN4515 DS13185_HMVEC_Lly_LN2732 DS17878_fStomach_LN4096 DS24722A_h.f.Umbilical.Cord_LN21207 DS24235A_h.SJSA_1_LN20839 DS12436_GM12865_LN2528 DS26455A_h.iPSC_LN26496 DS26313A_h.ELR_LN26395 DS14790_HAsp_LN3184 DS15192_HAh_LN3285 DS24154A_h.G401_LN20867 DS18208_CD20+_LN4156 DS31642A_h.CD1_LN28530 DS13372_HMVEC_LBl_LN2776 DS13480_HCFaa_LN2800 DS20493_M059J_LN4859 DS26410A_h.AL_LN26455 DS17706_h.Cord.Blood_LN4062 DS13337_HMVEC_dBlAd_LN2768 DS38587A_h.HT29_LN32481 DS32096A_h.neuronal_stem_cell_LN28669 DS17186_CD19+_LN3904 DS34646A_h.HT29_LN29816 DS25027C_h.PC3_LN28558 DS13150_HMVEC_dLyNeo_LN2725 DS22913C_h.RPMI.8226_LN28562 DS10060_HUVEC_LN1812 DS24888A_h.f.Tongue_LN21292 DS20909_RPMI.7951_LN4931 DS24808A_h.f.Tongue_LN21290 DS18406_vHMEC_LN10000 DS22919_h.RPMI.8226_LN20400 DS13242_HMVEC_dBlNeo_LN2746 DS24547A_h.ACHN_LN20963 DS24211A_h.Caki_2_LN20836 DS20351_fSpinal_cord_LN4807 DS12763_HEEpiC_LN2613 DS18224_Skin_fibroblast_LN4158 DS24471A_h.ACHN_LN26820 DS26113A_h.Fibroblast_LN26368 DS15115_HFF_P5_LN3259 DS21924A_fKidney_Right_LN20841 DS13981_HVMF_LN2925 DS12829_NHLF_LN2632 DS11949_SKMC_LN2373 DS22980_MCF10a_ER_SRC_LN20496 DS11923_NHDF_neo_LN2368 DS12599_HCM_LN2565 DS23873E_fKidney_LN26814 DS22991_MCF10a_ER_SRC_LN20387 DS22985_MCF10a_ER_SRC_LN20386 DS26689_h.kidney.tubular_LN31651 DS23849C_fBrain_LN28707 DS23825A_h.EL_LN20660 DS20786_fKidney_LN10113 DS24872A_fBrain_LN21323 DS12543_NB4_LN2556 DS26685_h.podocytes_LN26974 DS20239_fMuscle_leg_LN4772 DS20770_Small_Bowel_Mucosa_LN4899 DS17767_fMuscle_back_LN4072
# doing cluster  10
# cluster length  3789
# name of samples ['933' '934' '935' ..., '142166' '142167' '142168']
# (3789, 176)
#  Num DHSs 126295
# DHSs meeting threshold  [ 82968 171734 171735 ..., 121404 121406 121405]
# close samples  [ 0.45086879  0.79000036  0.75747796  0.5305528   0.50596112  0.70944323
#   0.64295836  0.85251062  0.70838699  0.52896109  0.83521063  0.82518485
#   0.75741826  0.70505193  0.79690216  0.6650928   0.80944206  0.54477786
#   0.69794967  0.44573252  0.83654712  0.81362607  0.8088792   0.52347331
#   0.81317505  0.62786343  0.62671839  0.81678707  0.62720867  0.59722657
#   0.66809319  0.65379646  0.64585225  0.72843393  0.62202409  0.83459673
#   0.83839655  0.63336753  0.62521625  0.55164147  0.62888921  0.56567083
#   0.81681595  0.69460271  0.83418395  0.66113858  0.6100943   0.66068281
#   0.65791703  0.54594126  0.62864639  0.84270512  0.61651735  0.84790157
#   0.81685207  0.52777931  0.62771977  0.57090044  0.68327343  0.56193386
#   0.55188785  0.7946074   0.79223778  0.70488639  0.55353871  0.51736083
#   0.61169728  0.73303944  0.75241909  0.74787543  0.73635527  0.75560197
#   0.74910966  0.7005748   0.71631964  0.69019721  0.60016706  0.47567164
#   0.61106628]
#  Num_samples 55
# density in reconstruction,  density in data,  precision,  recall
# 0.32051452407602693 0.20045362768986033 0.5874887597097692 0.939362796216019
# DS24567A_h.Daoy_LN20970 DS21042_h.H1.polyMSC_LN10043 DS20534_LHCN_M2_LN4866 DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS24722A_h.f.Umbilical.Cord_LN21207 DS14790_HAsp_LN3184 DS23123A_h.SJCRH30_LN20413 DS17885_CD8+_LN10088 DS24235A_h.SJSA_1_LN20839 DS13480_HCFaa_LN2800 DS26313A_h.ELR_LN26395 DS17203_CD8+_LN3907 DS17878_fStomach_LN4096 DS17189_CD56+_LN3905 DS26410A_h.AL_LN26455 DS15192_HAh_LN3285 DS11949_SKMC_LN2373 DS20493_M059J_LN4859 DS13368_HMF_LN2775 DS20909_RPMI.7951_LN4931 DS18224_Skin_fibroblast_LN4158 DS13981_HVMF_LN2925 DS12599_HCM_LN2565 DS26113A_h.Fibroblast_LN26368 DS24888A_h.f.Tongue_LN21292 DS11923_NHDF_neo_LN2368 DS15115_HFF_P5_LN3259 DS24808A_h.f.Tongue_LN21290 DS13513_AoAF_LN2811 DS12863_NHDF_Ad_LN2643 DS12829_NHLF_LN2632 DS10060_HUVEC_LN1812 DS12501_HCF_LN2542 DS12447_HCPEpiC_LN2530 DS13411_HPAF_LN2784 DS13390_HPF_LN2780 DS13242_HMVEC_dBlNeo_LN2746 DS23825A_h.EL_LN20660 DS12374_AG10803_LN2497 DS17186_CD19+_LN3904 DS20351_fSpinal_cord_LN4807 DS23873E_fKidney_LN26814 DS21924A_fKidney_Right_LN20841 DS20239_fMuscle_leg_LN4772 DS17767_fMuscle_back_LN4072 DS23559_h.EH_LN20491 DS22985_MCF10a_ER_SRC_LN20386 DS20786_fKidney_LN10113 DS20242_fMuscle_trunk_LN4773 DS12543_NB4_LN2556 DS19174_fSkin_Fibroblast_LN4486 DS19706_fSkin_Fibroblast_LN4632 DS19561_fSkin_Fibroblast_LN4587 DS19943_fSkin_Fibroblast_LN4690
# doing cluster  11
# cluster length  12052
# name of samples ['175' '177' '178' ..., '142930' '142931' '142932']
# (12052, 176)
#  Num DHSs 127500
# DHSs meeting threshold  [ 82968 171734 171735 ...,  77466 181844 158759]
# close samples  [ 0.75481471  0.47831055  0.81289156  0.80316287  0.73705544  0.77884902
#   0.82903664  0.79400902  0.65537903  0.59931273  0.8263549   0.81507646
#   0.81889013  0.58252198  0.66686504  0.52608027  0.76864313  0.76268994
#   0.72540698  0.55499864  0.48773833  0.64412429  0.74059585]
#  Num_samples 12
# density in reconstruction,  density in data,  precision,  recall
# 0.35453071895424837 0.23840849673202613 0.6311943248185947 0.9386317217934835
# DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS17203_CD8+_LN3907 DS17878_fStomach_LN4096 DS15192_HAh_LN3285 DS26410A_h.AL_LN26455 DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS17186_CD19+_LN3904 DS17767_fMuscle_back_LN4072 DS23559_h.EH_LN20491 DS20242_fMuscle_trunk_LN4773
# doing cluster  12
# cluster length  4689
# name of samples ['1124' '1164' '1172' ..., '142396' '142397' '142398']
# (4689, 176)
#  Num DHSs 125110
# DHSs meeting threshold  [146610  82969  84486 ..., 154678 107433  59268]
# close samples  [ 0.78042504  0.72896577  0.40945406  0.38825535  0.70444735  0.81110483
#   0.79942156  0.78003444  0.66476515  0.79426138  0.81815585  0.79351497
#   0.79543901  0.81672671  0.8207662   0.69438612  0.84335892  0.84349841
#   0.8251746   0.61312472  0.63951021  0.44309832  0.41135485  0.43277637
#   0.76024748  0.75380942  0.39333121  0.41313189  0.74967419  0.5319339
#   0.40190744  0.59820133]
#  Num_samples 17
# density in reconstruction,  density in data,  precision,  recall
# 0.3391561308401548 0.21927903444968427 0.6039778689967713 0.9341649906299182
# DS17212_CD4+_LN10089 DS17597_TH2_LN4024 DS17881_CD4+_LN4097 DS17885_CD8+_LN10088 DS17198_CD3+_LN3906 DS17603_iTH2_LN4026 DS17203_CD8+_LN3907 DS17189_CD56+_LN3905 DS17878_fStomach_LN4096 DS18208_CD20+_LN4156 DS15192_HAh_LN3285 DS17186_CD19+_LN3904 DS21924A_fKidney_Right_LN20841 DS26113A_h.Fibroblast_LN26368 DS20786_fKidney_LN10113 DS12734_h.CD34+_LN10087 DS17767_fMuscle_back_LN4072
# doing cluster  13
# cluster length  4079
# name of samples ['319' '320' '327' ..., '142520' '142521' '142522']
# (4079, 176)
#  Num DHSs 126330
# DHSs meeting threshold  [ 82968  47064 158149 ..., 116574 116659 116660]
# close samples  [ 0.76068986  0.75491817  0.48713251  0.8107238   0.80093129  0.77732012
#   0.8144464   0.79153547  0.78953337  0.68198222  0.79187112  0.81232698
#   0.81874088  0.82174842  0.59684533  0.66341041  0.53490237  0.7395554
#   0.56382878  0.49717379  0.75304068]
#  Num_samples 8
# density in reconstruction,  density in data,  precision,  recall
# 0.35709748278318687 0.24551274439958837 0.6368520658248752 0.9262992443324937
# DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS17203_CD8+_LN3907 DS17878_fStomach_LN4096 DS15192_HAh_LN3285 DS17186_CD19+_LN3904 DS26113A_h.Fibroblast_LN26368 DS17767_fMuscle_back_LN4072
# doing cluster  14
# cluster length  1541
# name of samples ['5826' '5827' '5828' ..., '142067' '142364' '142365']
# (1541, 176)
#  Num DHSs 126470
# DHSs meeting threshold  [171773 171772 171774 ..., 142263 115311 115310]
# close samples  [ 0.71613873  0.77278907]
#  Num_samples 1
# density in reconstruction,  density in data,  precision,  recall
# 0.4708310271210564 0.26831659682138054 0.5689718872804218 0.9984086756645253
# DS20346_fPlacenta_LN10066
# doing cluster  15
# cluster length  1423
# name of samples ['1584' '1585' '1586' ..., '141874' '141875' '141876']
# (1423, 176)
#  Num DHSs 126856
# DHSs meeting threshold  [ 56602 171745  79404 ...,   6968   6966   6967]
# close samples  [ 0.57080073  0.59941884  0.52154713  0.7634137   0.7866312   0.61823079
#   0.71796489  0.64930982  0.62639259  0.63389745  0.84333106  0.84333106
#   0.62751105  0.62036187  0.69108272  0.50125751  0.85969345  0.8519299
#   0.77202176  0.75934205  0.61557031  0.82659636  0.69885759  0.84536339
#   0.54055297  0.54205543  0.70779431  0.78330999  0.84194899  0.54362596
#   0.39099318  0.49657706  0.88022707  0.84218336  0.84778794  0.6012454
#   0.84013042  0.44849997  0.48249385  0.81135606  0.66268419  0.66919631
#   0.83227474  0.55065447  0.55113757  0.70717307  0.68068794  0.78795345
#   0.64500699  0.70498893  0.70469554  0.74180564  0.68491222  0.70391279
#   0.64241375  0.59653017  0.84934425  0.84543188  0.85123899  0.66129942
#   0.67228255  0.5510037   0.62411181  0.57046041  0.52283475  0.85819502
#   0.70871119  0.55688105  0.84185761  0.627211    0.87736922  0.60030019
#   0.6474577   0.57485195  0.3786029   0.65742346  0.62885102  0.66719703
#   0.59588015  0.72103549  0.70627986  0.58933922  0.81235242  0.81699873
#   0.80069979  0.69992942  0.81623459  0.65790113  0.54580742  0.68098396
#   0.66450401  0.66767487  0.64480422  0.57201925  0.57620532  0.56694863
#   0.26898256  0.82220968  0.63846992  0.56289957  0.85459269  0.55641664
#   0.62173424  0.54285317  0.68299139  0.57410445  0.74567965  0.37699853
#   0.77258838  0.71219635  0.66474636  0.59399983  0.72562102  0.7238068
#   0.70522899  0.736052    0.56070383  0.62612188  0.67845874  0.66425139
#   0.78556769  0.51609997  0.81296243  0.81626726  0.41150251  0.72551406
#   0.74742936  0.39632254  0.73237307  0.52514912  0.44804715  0.53092317
#   0.67698393  0.61544003]
#  Num_samples 99
# density in reconstruction,  density in data,  precision,  recall
# 0.29619888740466405 0.17814910471938913 0.5614916693683624 0.9335618498665149
# DS14289_A549_LN3027 DS44414_h.RKO_LN35453 DS21975C_h.NCI_H226_LN27452 DS24567A_h.Daoy_LN20970 DS20325_Psoas_muscle_LN4801 DS19794_T_47D_LN4656 DS20534_LHCN_M2_LN4866 DS24790A_HeLa_S3_LN21209 DS24744A_h.A172_LN21224 DS24640A_h.MG_63_LN21068 DS23123A_h.SJCRH30_LN20413 DS19310_Mesendoderm_LN4515 DS21042_h.H1.polyMSC_LN10043 DS27166A_h.PC9_LN26744 DS20493_M059J_LN4859 DS20548_LHCN_M2_LN4870 DS24211A_h.Caki_2_LN20836 DS24235A_h.SJSA_1_LN20839 DS38587A_h.HT29_LN32481 DS24547A_h.ACHN_LN20963 DS25027C_h.PC3_LN28558 DS25129C_h.PC3_LN21648 DS26313A_h.ELR_LN26395 DS11909_H7_hESC_LN2365 DS14790_HAsp_LN3184 DS24471A_h.ACHN_LN26820 DS17878_fStomach_LN4096 DS26689_h.kidney.tubular_LN31651 DS34890A_h.FUCCI.cells_LN30023 DS26455A_h.iPSC_LN26496 DS18406_vHMEC_LN10000 DS34646A_h.HT29_LN29816 DS15192_HAh_LN3285 DS13185_HMVEC_Lly_LN2732 DS34628A_h.LoVo_LN29819 DS13480_HCFaa_LN2800 DS17215_h.CD14+_LN3909 DS13372_HMVEC_LBl_LN2776 DS12763_HEEpiC_LN2613 DS15153_h.IPS_LN10036 DS26685_h.podocytes_LN26974 DS24722A_h.f.Umbilical.Cord_LN21207 DS20909_RPMI.7951_LN4931 DS22980_MCF10a_ER_SRC_LN20496 DS17212_CD4+_LN10089 DS22991_MCF10a_ER_SRC_LN20387 DS39386_h.glomerular_LN32272 DS26410A_h.AL_LN26455 DS17881_CD4+_LN4097 DS10518_SAEC_LN1926 DS26693A_h.renal.cell.carcinoma_LN26937 DS22985_MCF10a_ER_SRC_LN20386 DS13337_HMVEC_dBlAd_LN2768 DS10666_HRCEpiC_LN1959 DS27192_h.786_O_LN31650 DS12684_HIPEpiC_LN2583 DS27824_h.kidney.tubular_LN29654 DS12436_GM12865_LN2528 DS13150_HMVEC_dLyNeo_LN2725 DS10060_HUVEC_LN1812 DS13242_HMVEC_dBlNeo_LN2746 DS31642A_h.CD1_LN28530 DS12829_NHLF_LN2632 DS24808A_h.f.Tongue_LN21290 DS18224_Skin_fibroblast_LN4158 DS32096A_h.neuronal_stem_cell_LN28669 DS17203_CD8+_LN3907 DS13368_HMF_LN2775 DS13981_HVMF_LN2925 DS24888A_h.f.Tongue_LN21292 DS26113A_h.Fibroblast_LN26368 DS20770_Small_Bowel_Mucosa_LN4899 DS18208_CD20+_LN4156 DS11949_SKMC_LN2373 DS22913C_h.RPMI.8226_LN28562 DS15115_HFF_P5_LN3259 DS12599_HCM_LN2565 DS22919_h.RPMI.8226_LN20400 DS23825A_h.EL_LN20660 DS13513_AoAF_LN2811 DS12663_HAEpiC_LN2579 DS12501_HCF_LN2542 DS12447_HCPEpiC_LN2530 DS17706_h.Cord.Blood_LN4062 DS13411_HPAF_LN2784 DS11923_NHDF_neo_LN2368 DS21924A_fKidney_Right_LN20841 DS23873E_fKidney_LN26814 DS17186_CD19+_LN3904 DS20786_fKidney_LN10113 DS13390_HPF_LN2780 DS17317_fIntestine.Sm_LN3929 DS20239_fMuscle_leg_LN4772 DS17313_h.f.Intestine.Lg_LN3928 DS20351_fSpinal_cord_LN4807 DS17767_fMuscle_back_LN4072 DS12543_NB4_LN2556 DS15363_K562_LN3327 DS20242_fMuscle_trunk_LN4773
# doing cluster  16
# cluster length  3258
# name of samples ['1292' '1293' '1294' ..., '142822' '142823' '142824']
# (3258, 176)
#  Num DHSs 127583
# DHSs meeting threshold  [ 82969 141356  82968 ...,   9860   9859   9858]
# close samples  [ 0.4617617   0.76433756  0.80648549  0.79748364  0.70746851  0.76920584
#   0.66461239  0.78705834  0.62123083  0.53906822  0.5613747   0.8232247
#   0.55072996  0.67033508  0.76275359  0.75704195  0.70227165  0.5325628
#   0.60944704  0.71854471]
#  Num_samples 12
# density in reconstruction,  density in data,  precision,  recall
# 0.36312570379021236 0.23357343846750742 0.6057264760479473 0.9416946308724832
# DS21042_h.H1.polyMSC_LN10043 DS17878_fStomach_LN4096 DS26313A_h.ELR_LN26395 DS15192_HAh_LN3285 DS26410A_h.AL_LN26455 DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS23825A_h.EL_LN20660 DS17186_CD19+_LN3904 DS17767_fMuscle_back_LN4072 DS23559_h.EH_LN20491 DS20242_fMuscle_trunk_LN4773
# doing cluster  17
# cluster length  2393
# name of samples ['654' '655' '656' ..., '140442' '140455' '140456']
# (2393, 176)
#  Num DHSs 127703
# DHSs meeting threshold  [ 82968  21033  21032 ..., 166515  31856 185174]
# close samples  [ 0.76901453  0.48157224  0.46077526  0.70850127  0.754578    0.74383265
#   0.72428995  0.61775622  0.64250795  0.73716966  0.73399394  0.70834025
#   0.66624733  0.61036138  0.71315464  0.73328083  0.83951086  0.84183497
#   0.56480757  0.55391212  0.64746751  0.51712699  0.50664839  0.72589899
#   0.71297659  0.74889332  0.53650084  0.47199186  0.65743768  0.64523638]
#  Num_samples 26
# density in reconstruction,  density in data,  precision,  recall
# 0.33939146059456465 0.22093782508573076 0.6132726462763362 0.9420727260334663
# DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS17885_CD8+_LN10088 DS17203_CD8+_LN3907 DS17189_CD56+_LN3905 DS17878_fStomach_LN4096 DS15192_HAh_LN3285 DS32096A_h.neuronal_stem_cell_LN28669 DS26410A_h.AL_LN26455 DS21924A_fKidney_Right_LN20841 DS24547A_h.ACHN_LN20963 DS20351_fSpinal_cord_LN4807 DS17186_CD19+_LN3904 DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS24833A_fSpinalCord_LN21289 DS20786_fKidney_LN10113 DS17317_fIntestine.Sm_LN3929 DS23339E_h.f.Retina_LN26813 DS23833A_h.f.Eye_LN20656 DS17313_h.f.Intestine.Lg_LN3928 DS26693A_h.renal.cell.carcinoma_LN26937 DS24796A_h.f.Eye_LN21208 DS24728A_h.f.Eye_LN21204 DS23368A_h.f.Retina_LN20458 DS17767_fMuscle_back_LN4072
# doing cluster  18
# cluster length  3870
# name of samples ['64' '65' '66' ..., '142964' '142965' '142966']
# (3870, 176)
#  Num DHSs 125057
# DHSs meeting threshold  [ 21033 119832 119776 ..., 169433 146048  63381]
# close samples  [ 0.5984436]
#  Num_samples 1
# density in reconstruction,  density in data,  precision,  recall
# 0.38590402776333993 0.2711883381178183 0.6087028595109821 0.8661909535884885
# DS17186_CD19+_LN3904
# doing cluster  19
# cluster length  6122
# name of samples ['209' '210' '211' ..., '142058' '142059' '142060']
# (6122, 176)
#  Num DHSs 127700
# DHSs meeting threshold  [ 82968  21033 171735 ...,  36709  36708  36707]
# close samples  [ 0.75920736  0.77526019  0.81586353]
#  Num_samples 0
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
#
# doing cluster  20
# cluster length  2483
# name of samples ['280' '281' '282' ..., '141172' '141173' '141174']
# (2483, 176)
#  Num DHSs 128430
# DHSs meeting threshold  [ 21033 127815 157717 ..., 129532 129538 129535]
# close samples  [ 0.77113846  0.7786139   0.76841215  0.73778407  0.77412948  0.75263098
#   0.76531165  0.7501976   0.7690348   0.63084999  0.62949945  0.64692939]
#  Num_samples 4
# density in reconstruction,  density in data,  precision,  recall
# 0.37060460951491087 0.25012847465545435 0.668743138974825 0.9908479641389615
# DS20239_fMuscle_leg_LN4772 DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773 DS23833A_h.f.Eye_LN20656
# doing cluster  21
# cluster length  2893
# name of samples ['15' '16' '17' ..., '141441' '141442' '141443']
# (2893, 176)
#  Num DHSs 126000
# DHSs meeting threshold  [ 82968  10309 119831 ..., 105509 105510 105511]
# close samples  [ 0.50453681  0.80510599  0.72362073  0.49962994  0.47580925  0.70890036
#   0.84421447  0.84421447  0.52304646  0.82393885  0.81203754  0.72560872
#   0.76926543  0.78855291  0.81366159  0.68750997  0.72472338  0.79560311
#   0.69378414  0.84973619  0.80373275  0.81455539  0.55372661  0.79981061
#   0.76637834  0.63029165  0.62795785  0.78361911  0.66005436  0.72740904
#   0.69816004  0.65333384  0.8022339   0.79910389  0.8063409   0.68694106
#   0.61819456  0.62775562  0.54859801  0.82896363  0.69077625  0.84888327
#   0.60111734  0.8607881   0.58690036  0.62277744  0.64897821  0.82205619
#   0.61054988  0.73476921  0.66510275  0.53250309  0.49096809  0.52283428
#   0.7931317   0.78878044  0.46456898  0.49101682  0.64937253  0.70961853
#   0.55107799  0.49111779  0.62530137  0.67145118  0.53009152  0.70507831
#   0.72330345  0.39320077  0.67670682]
#  Num_samples 45
# density in reconstruction,  density in data,  precision,  recall
# 0.3303567901234568 0.20314197530864198 0.5754373845177279 0.9357969812860573
# DS20341_fThymus_LN4803 DS17597_TH2_LN4024 DS17212_CD4+_LN10089 DS17198_CD3+_LN3906 DS17603_iTH2_LN4026 DS17881_CD4+_LN4097 DS17885_CD8+_LN10088 DS21042_h.H1.polyMSC_LN10043 DS17203_CD8+_LN3907 DS23123A_h.SJCRH30_LN20413 DS19310_Mesendoderm_LN4515 DS17189_CD56+_LN3905 DS26455A_h.iPSC_LN26496 DS17878_fStomach_LN4096 DS24722A_h.f.Umbilical.Cord_LN21207 DS31642A_h.CD1_LN28530 DS13480_HCFaa_LN2800 DS15192_HAh_LN3285 DS26313A_h.ELR_LN26395 DS32096A_h.neuronal_stem_cell_LN28669 DS18208_CD20+_LN4156 DS26410A_h.AL_LN26455 DS24888A_h.f.Tongue_LN21292 DS24808A_h.f.Tongue_LN21290 DS13981_HVMF_LN2925 DS17706_h.Cord.Blood_LN4062 DS12599_HCM_LN2565 DS11949_SKMC_LN2373 DS17186_CD19+_LN3904 DS18224_Skin_fibroblast_LN4158 DS20351_fSpinal_cord_LN4807 DS26113A_h.Fibroblast_LN26368 DS21924A_fKidney_Right_LN20841 DS23873E_fKidney_LN26814 DS24547A_h.ACHN_LN20963 DS12543_NB4_LN2556 DS20239_fMuscle_leg_LN4772 DS20786_fKidney_LN10113 DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773 DS12734_h.CD34+_LN10087 DS24044A_h.CD34+_LN20861 DS23530_h.KBM_7_LN20483 DS12274_h.CD34+_LN2482 DS16924_K562_LN3817
# doing cluster  22
# cluster length  2472
# name of samples ['303' '304' '305' ..., '142479' '142480' '142481']
# (2472, 176)
#  Num DHSs 125264
# DHSs meeting threshold  [ 34333  34337  34335 ..., 194441  31920 173984]
# close samples  [ 0.74427433  0.41278242  0.81014888  0.81014888  0.71846914  0.65358279
#   0.78975694  0.79609707  0.62358192  0.47144858  0.46012038  0.42459657]
#  Num_samples 8
# density in reconstruction,  density in data,  precision,  recall
# 0.3508230616937029 0.24642854291735855 0.658676656312933 0.9377118352372352
# DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS17203_CD8+_LN3907 DS17189_CD56+_LN3905 DS17186_CD19+_LN3904 DS26113A_h.Fibroblast_LN26368 DS23559_h.EH_LN20491 DS20346_fPlacenta_LN10066
# doing cluster  23
# cluster length  5273
# name of samples ['2' '3' '4' ..., '142359' '142391' '142394']
# (5273, 176)
#  Num DHSs 127018
# DHSs meeting threshold  [171752  82968  82969 ..., 139782 139783 139785]
# close samples  [ 0.44796054  0.78238501  0.71352602  0.79544229  0.67560539  0.81766207
#   0.8115392   0.81694193  0.61911364  0.60234196  0.62823264  0.55828038
#   0.56788702  0.79704648  0.81387236  0.54350085  0.84213862  0.57226553
#   0.68986437  0.7656552   0.76309208  0.68905352  0.53798095  0.61757448
#   0.6878236   0.70120038]
#  Num_samples 16
# density in reconstruction,  density in data,  precision,  recall
# 0.35820562833614134 0.23022868805996 0.6068378533937199 0.9441600714696372
# DS21042_h.H1.polyMSC_LN10043 DS17878_fStomach_LN4096 DS13480_HCFaa_LN2800 DS26313A_h.ELR_LN26395 DS26410A_h.AL_LN26455 DS15192_HAh_LN3285 DS11949_SKMC_LN2373 DS18224_Skin_fibroblast_LN4158 DS24888A_h.f.Tongue_LN21292 DS26113A_h.Fibroblast_LN26368 DS23825A_h.EL_LN20660 DS20239_fMuscle_leg_LN4772 DS17767_fMuscle_back_LN4072 DS17186_CD19+_LN3904 DS20242_fMuscle_trunk_LN4773 DS23559_h.EH_LN20491
# doing cluster  24
# cluster length  3834
# name of samples ['599' '600' '601' ..., '142282' '142283' '142284']
# (3834, 176)
#  Num DHSs 126672
# DHSs meeting threshold  [ 29503 119832  82958 ...,  16315  11815  11814]
# close samples  [ 0.79119082  0.81604951  0.81604951  0.7156347   0.63551683  0.57130301
#   0.82148023  0.64672954  0.69124483  0.62698185  0.68567078  0.70144821]
#  Num_samples 8
# density in reconstruction,  density in data,  precision,  recall
# 0.3671292787672098 0.24403972464317292 0.6344882270723579 0.9545134732960243
# DS26410A_h.AL_LN26455 DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS17186_CD19+_LN3904 DS20239_fMuscle_leg_LN4772 DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773 DS23559_h.EH_LN20491
# doing cluster  25
# cluster length  7580
# name of samples ['920' '947' '948' ..., '142352' '142353' '142354']
# (7580, 176)
#  Num DHSs 127992
# DHSs meeting threshold  [ 82969  82968  82957 ..., 194980 194981  68748]
# close samples  [ 0.7756622   0.46092029  0.81613686  0.80637682  0.73409688  0.77924829
#   0.82464516  0.79509747  0.64998523  0.58969152  0.82156553  0.83593829
#   0.57776253  0.65101466  0.51807759  0.50801193  0.70278132  0.54250573
#   0.47280377  0.64006246  0.70349644  0.71730101]
#  Num_samples 14
# density in reconstruction,  density in data,  precision,  recall
# 0.35073341637423766 0.2355364844231336 0.6343959584709018 0.9446683489118717
# DS17212_CD4+_LN10089 DS17881_CD4+_LN4097 DS17203_CD8+_LN3907 DS17189_CD56+_LN3905 DS17878_fStomach_LN4096 DS15192_HAh_LN3285 DS26410A_h.AL_LN26455 DS18224_Skin_fibroblast_LN4158 DS26113A_h.Fibroblast_LN26368 DS17186_CD19+_LN3904 DS17767_fMuscle_back_LN4072 DS20239_fMuscle_leg_LN4772 DS20242_fMuscle_trunk_LN4773 DS23559_h.EH_LN20491
# doing cluster  26
# cluster length  7667
# name of samples ['28' '29' '30' ..., '142528' '142529' '142530']
# (7667, 176)
#  Num DHSs 127791
# DHSs meeting threshold  [ 82968  47051  82958 ...,  75723  13377 161450]
# close samples  [ 0.77628909  0.7675224   0.78462481  0.64926315  0.83613584  0.69238974
#   0.52966633  0.70803884]
#  Num_samples 4
# density in reconstruction,  density in data,  precision,  recall
# 0.3801382726483086 0.2546443020243992 0.6413055225332325 0.9573541274536166
# DS17878_fStomach_LN4096 DS26113A_h.Fibroblast_LN26368 DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773
# doing cluster  27
# cluster length  3006
# name of samples ['368' '369' '370' ..., '142174' '142175' '142176']
# (3006, 176)
#  Num DHSs 128449
# DHSs meeting threshold  [ 68208  68207 119776 ...,  38698  38697  77363]
# close samples  [ 0.77258343  0.73426675  0.75305285  0.59248455  0.67698012]
#  Num_samples 3
# density in reconstruction,  density in data,  precision,  recall
# 0.3775142923131619 0.26656753523447696 0.6684768412224865 0.9467002852386561
# DS17186_CD19+_LN3904 DS17767_fMuscle_back_LN4072 DS23833A_h.f.Eye_LN20656
# doing cluster  28
# cluster length  7374
# name of samples ['1984' '1985' '1986' ..., '142703' '142704' '142705']
# (7374, 176)
#  Num DHSs 127436
# DHSs meeting threshold  [ 21033 158149  82968 ..., 192236 192239 192240]
# close samples  [ 0.73796068  0.773122    0.79700911]
#  Num_samples 1
# density in reconstruction,  density in data,  precision,  recall
# 0.46337769547066765 0.2648859035123513 0.5707269986960424 0.9984002843938855
# DS20346_fPlacenta_LN10066
# doing cluster  29
# cluster length  3599
# name of samples ['2030' '2031' '2032' ..., '142370' '142371' '142372']
# (3599, 176)
#  Num DHSs 128967
# DHSs meeting threshold  [127815  82968  29503 ...,  40109  40110  40140]
# close samples  [ 0.73966504]
#  Num_samples 1
# density in reconstruction,  density in data,  precision,  recall
# 0.38125256848651207 0.2669520109795529 0.6821371189163904 0.9742070407807598
# DS23833A_h.f.Eye_LN20656
# doing cluster  30
# cluster length  2860
# name of samples ['596' '597' '598' ..., '140393' '140394' '141267']
# (2860, 176)
#  Num DHSs 125490
# DHSs meeting threshold  [108934 171752  68208 ..., 199014 164606  42096]
# close samples  []
#  Num_samples 0
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
#
# doing cluster  31
# cluster length  2041
# name of samples ['2574' '4511' '4512' ..., '140620' '140621' '140622']
# (2041, 176)
#  Num DHSs 128389
# DHSs meeting threshold  [157485 171752  47051 ..., 163317 163316 163315]
# close samples  [ 0.7718652   0.80231084  0.76810287  0.82431673  0.6371483   0.65758023
#   0.65535516  0.67080631]
#  Num_samples 4
# density in reconstruction,  density in data,  precision,  recall
# 0.36939691095031507 0.2492347475250995 0.6493785120133259 0.9624597643676365
# DS17186_CD19+_LN3904 DS20239_fMuscle_leg_LN4772 DS17767_fMuscle_back_LN4072 DS20242_fMuscle_trunk_LN4773

# %% [markdown]
# # now even though it is in consistent, lets use the normalized DHS vectors for cluster means

# %%
chosenthresh = 0.3
#threshold for cosine similarity distance for samples to be included in this module. 0.1 gives about the same samples as in the original cluster for 80% component dominance. 
cosdist_sample_thresh = 0.5

#threshold for cosine similarity distance for DHS to be included in this module
cosdist_DHS_thresh = 0.3
for i, cluster in enumerate(ClustersDHS):

    print ('doing cluster ',i)
    # mean sample-wise component vector for this cluster
    mean_of_cluster = ClusterMeansDHS[i]
    #create a single 1 x NDHS prediction for the cluster to
    recon_cluster_Sam = np.dot(BasisMat, mean_of_cluster)
    #recon_cluster_DHS = np.dot(mean_of_cluster, MixtureMat)

    cluster_length = len(cluster[1])
    print('cluster length ',cluster_length)
    print('name of samples', cluster[1])

    #now you tile the vector to a size equivalent to N_DHS_in_cluster x NSamples
    kar = np.tile(recon_cluster_Sam, cluster_length).reshape(cluster_length, Nsamples)
    print(kar.shape)
    kar = kar.T

    #print(kar[0]-kar[1])    
    #***** NOTE: for some reason I decided to use original version of NMF matrices for cosine 
    #***** Similarity scores. Self-consistent? Not sure! 

    #calculate cosine similarity of cluster mean to all sample-component vectors 
    sample_cosdists = spdist.cdist(BasisMat, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()    
    #calculate cosine similarity of cluster mean to all DHS-component vectors 
    DHScosdists = spdist.cdist(MixtureMat.T, np.reshape(mean_of_cluster, (1,NMFcomps)), 'cosine').flatten()
    #now we sort these sample cosine distances

    closers = np.argsort(DHScosdists)

    #using the thresholds defined outside the loop, we find the samples that meet the closeness
    #criteria 
    Num_DHSs = len(DHScosdists[DHScosdists<cosdist_sample_thresh])
    print(' Num DHSs', Num_DHSs)
    print('DHSs meeting threshold ',closers[0:Num_DHSs])
    #First we use our decision threshold to figure out if the model predicts a positive
    #for a given position. Using the sample cluster mean component vector
    Sample_appear_cut = np.dot(mean_of_cluster, BasisMat.T)>chosenthresh
    #now sort the coside distances of DHS's that will appear from previous step    

    Sample_closeness = np.argsort(sample_cosdists[Sample_appear_cut])
    print('close samples ',sample_cosdists[Sample_appear_cut])
    Num_samples = len(sample_cosdists[Sample_appear_cut][sample_cosdists[Sample_appear_cut] < cosdist_sample_thresh])
    print(' Num_samples', Num_samples)

    sorted_Module = np.dot(BasisMat[Sample_appear_cut][Sample_closeness][0:Num_samples], MixtureMat.T[closers][0:Num_DHSs].T)
    corresponding_data = a[Sample_appear_cut][Sample_closeness][0:Num_samples][:,np.arange(NDHS)[closers][0:Num_DHSs]]
    flatsorted_Module = sorted_Module.flatten()
    flatcorresponding_data = corresponding_data.flatten()
    #calculate "density" i.e. number of entries of DHS hits within the module
    if (len(flatsorted_Module) > 0):
        density_in_recon = len(flatsorted_Module[flatsorted_Module>chosenthresh])/len(flatsorted_Module)
    else:
        density_in_recon = 0
    if(len(flatcorresponding_data) > 0):
        density_in_data = len(flatcorresponding_data[flatcorresponding_data>chosenthresh])/len(flatcorresponding_data)
    else:
        density_in_data = 0
    #calculate true positives, false positives, False negatives, precision ,recall
    TP =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
    FP =len(flatcorresponding_data[ np.invert(flatcorresponding_data>chosenthresh) * (flatsorted_Module>chosenthresh)])
    FN =len(flatcorresponding_data[ (flatcorresponding_data>chosenthresh) * np.invert(flatsorted_Module>chosenthresh)])
    if ((TP + FN ) > 0):
        recall = TP / (TP + FN)
    else: 
        recall = 0
    if ((TP +FP) > 0):
        precision = TP / (TP + FP)
    else:
        precision = 0
    print('density in reconstruction,  density in data,  precision,  recall')
    print(density_in_recon, density_in_data, precision, recall  )
    firstcut = np.zeros(NDHS)
    firstcut[closers][0:Num_DHSs] += 1
    list1 = [Num_samples, Num_DHSs, chosenthresh, cosdist_sample_thresh,  cosdist_DHS_thresh, density_in_recon, density_in_data, precision, recall]
    theheader =  ' '.join(str(e) for e in list1)
    namestr = ' '.join(names[Sample_appear_cut][Sample_closeness][0:Num_samples])
    theheader +=' '+namestr
    print(namestr)
# Out:
# doing cluster  0
# cluster length  8502
# name of samples ['31' '32' '33' ..., '142390' '142392' '142393']
# (8502, 176)
#  Num DHSs 35264
# DHSs meeting threshold  [153690 153689 153688 ...,  55942 177333 131876]
# close samples  [ 0.08435226]
#  Num_samples 1
# density in reconstruction,  density in data,  precision,  recall
# 0.7206215970961888 0.6240074863883848 0.7970643790335274 0.9204726198591229
# DS26455A_h.iPSC_LN26496
# doing cluster  1
# cluster length  5553
# name of samples ['2226' '2227' '2244' ..., '142728' '142825' '142826']
# (5553, 176)
#  Num DHSs 31503
# DHSs meeting threshold  [44285 44286 44289 ..., 90960 90961 66598]
# close samples  [ 0.00450358  0.01513161  0.0321376   0.02027089  0.65312444  0.00170648
#   0.00677009  0.00181057  0.01660937  0.01040684  0.60252754  0.01998297
#   0.04710005  0.08557821  0.62166314  0.31769092]
#  Num_samples 13
# density in reconstruction,  density in data,  precision,  recall
# 0.5095045893065129 0.42013825301131275 0.7239746575802015 0.877969115963339
# DS17189_CD56+_LN3905 DS17203_CD8+_LN3907 DS17885_CD8+_LN10088 DS17198_CD3+_LN3906 DS17603_iTH2_LN4026 DS17212_CD4+_LN10089 DS17597_TH2_LN4024 DS17881_CD4+_LN4097 DS14702_hTreg_LN3156 DS14108_h.Tn_LN2964 DS18015_TH1_LN4128 DS18018_iTH1_LN4129 DS20341_fThymus_LN4803
# doing cluster  2
# cluster length  3641
# name of samples ['1166' '1167' '1168' ..., '142949' '142967' '142968']
# (3641, 176)
#  Num DHSs 14017
# DHSs meeting threshold  [117786 117787 117785 ...,  33492  33493 164492]
# close samples  [ 0.03991892  0.03991892  0.03129213  0.63622294  0.04524038  0.04418271
#   0.03489457  0.03967859  0.03251448  0.04075166  0.06368906  0.05936956
#   0.06289016]
#  Num_samples 12
# density in reconstruction,  density in data,  precision,  recall
# 0.33924282418967444 0.27170578583149035 0.5715537485542042 0.7136230361909763
# DS22919_h.RPMI.8226_LN20400 DS29219C_h.Oci_Ly_7_LN28035 DS27648A_h.Karpas_422_LN26836 DS27641A_h.Karpas_422_LN26838 DS22816_h.NAMALWA_LN20368 DS22823_h.NAMALWA_LN20369 DS22913C_h.RPMI.8226_LN28562 DS27522A_h.b.lymphoblast.mm.1s_LN26797 DS12436_GM12865_LN2528 DS17706_h.Cord.Blood_LN4062 DS18208_CD20+_LN4156 DS17186_CD19+_LN3904
# doing cluster  3
# cluster length  2886
# name of samples ['1463' '1464' '1477' ..., '142752' '142753' '142754']
# (2886, 176)
#  Num DHSs 10906
# DHSs meeting threshold  [39811 39812 46319 ..., 47830 46204 69541]
# close samples  [ 0.0590555   0.04884124  0.0594744   0.07129367  0.06712576  0.05624534
#   0.04761982  0.07397174  0.07449675  0.07537503  0.07168711  0.07544024
#   0.04272396  0.05241322  0.04924169  0.05254301]
#  Num_samples 16
# density in reconstruction,  density in data,  precision,  recall
# 0.5737724646983312 0.42438222079589216 0.6424925839733922 0.8686616342349398
# DS31642A_h.CD1_LN28530 DS12543_NB4_LN2556 DS23530_h.KBM_7_LN20483 DS16924_K562_LN3817 DS15363_K562_LN3327 DS17215_h.CD14+_LN3909 DS12274_h.CD34+_LN2482 DS12734_h.CD34+_LN10087 DS24044A_h.CD34+_LN20861 DS24074A_h.CD34+_LN21381 DS24094A_h.CD34+_LN20866 DS25969A_h.CD34+_LN26316 DS25687A_h.CD34+_LN26240 DS25769A_h.CD34+_LN26258 DS25730A_h.CD34+_LN26288 DS26444A_h.CD34+_LN26445
# doing cluster  4
# cluster length  11815
# name of samples ['206' '207' '208' ..., '142510' '142511' '142512']
# (11815, 176)
#  Num DHSs 51970
# DHSs meeting threshold  [ 46071 189475  46149 ..., 129338 129336 129339]
# close samples  []
#  Num_samples 0
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
#
# doing cluster  5
# cluster length  3434
# name of samples ['0' '1' '52' ..., '142449' '142450' '142451']
# (3434, 176)
#  Num DHSs 17838
# DHSs meeting threshold  [136502 132968  14371 ..., 184076 153322 166588]
# close samples  [ 0.07847719  0.07342546  0.15151813  0.4480241   0.05150942  0.05625442
#   0.06876588  0.06592587  0.02943429  0.49472905  0.40777598  0.09530425
#   0.05927408  0.09012206  0.0531049   0.03923712  0.03967076  0.0969744
#   0.05575181  0.15979337  0.14904633]
#  Num_samples 21
# density in reconstruction,  density in data,  precision,  recall
# 0.7222382393926289 0.578265233663821 0.7540445538516128 0.9417820392674628
# DS12684_HIPEpiC_LN2583 DS13480_HCFaa_LN2800 DS13513_AoAF_LN2811 DS12447_HCPEpiC_LN2530 DS13411_HPAF_LN2784 DS13981_HVMF_LN2925 DS12501_HCF_LN2542 DS13368_HMF_LN2775 DS12663_HAEpiC_LN2579 DS12599_HCM_LN2565 DS11752_HGF_LN2307 DS21042_h.H1.polyMSC_LN10043 DS13390_HPF_LN2780 DS13219_IMR90_LN2741 DS13573_HPdLF_LN2823 DS14790_HAsp_LN3184 DS11949_SKMC_LN2373 DS34574A_h.CEC_LN29827 DS12863_NHDF_Ad_LN2643 DS12374_AG10803_LN2497 DS12829_NHLF_LN2632
# doing cluster  6
# cluster length  4141
# name of samples ['11' '12' '13' ..., '142403' '142404' '142405']
# (4141, 176)
#  Num DHSs 13583
# DHSs meeting threshold  [ 26190  26186  26187 ...,  91779  57347 108695]
# close samples  [ 0.04821579  0.03650042  0.03780224  0.03407483  0.03938639  0.03893448]
#  Num_samples 6
# density in reconstruction,  density in data,  precision,  recall
# 0.44722569879015434 0.38317504724042306 0.6789124231782265 0.7923978480850519
# DS30557A_h.Trophoblast_LN28110 DS20346_fPlacenta_LN10066 DS30582A_h.Trophoblast_LN28078 DS35787A_h.Trophoblast_LN30439 DS31397A_h.Trophoblast_LN28443 DS19317_h.Trophoblast_LN10001
# doing cluster  7
# cluster length  3374
# name of samples ['739' '740' '741' ..., '141501' '141502' '142367']
# (3374, 176)
#  Num DHSs 13887
# DHSs meeting threshold  [  1077   1078   1079 ..., 182966 180270  76767]
# close samples  [  7.33117864e-01   1.95875252e-02   9.60344080e-04   3.38492354e-04
#    3.47815594e-03   1.53161774e-01   2.54812614e-01   2.84575911e-03
#    1.83190851e-03   1.57480185e-02   3.34495101e-02   1.60115301e-01
#    1.57035995e-01   1.52529151e-01   8.00314942e-03   5.51541676e-01
#    1.52514813e-01   4.35730073e-02   4.40725455e-01   7.38745676e-01
#    1.06974804e-01]
#  Num_samples 18
# density in reconstruction,  density in data,  precision,  recall
# 0.31737116247809705 0.2606554491410832 0.6183885443452831 0.752942982119561
# DS23368A_h.f.Retina_LN20458 DS23341_h.f.Retina_LN20451 DS24796A_h.f.Eye_LN21208 DS24728A_h.f.Eye_LN21204 DS23833A_h.f.Eye_LN20656 DS23339E_h.f.Retina_LN26813 DS24833A_fSpinalCord_LN21289 DS23286_h.f.Retina_LN20434 DS24872A_fBrain_LN21323 DS23849C_fBrain_LN28707 DS20351_fSpinal_cord_LN4807 DS32096A_h.neuronal_stem_cell_LN28669 DS26980A_h.Bipolar_neuron_LN26594 DS21924A_fKidney_Right_LN20841 DS26986A_h.Bipolar_neuron_LN26591 DS25067A_h.L1_S8_LN21363 DS24154A_h.G401_LN20867 DS15192_HAh_LN3285
# doing cluster  8
# cluster length  2954
# name of samples ['1249' '1307' '1308' ..., '142850' '142915' '142916']
# (2954, 176)
#  Num DHSs 11081
# DHSs meeting threshold  [164586 141300 141290 ...,  81805 177089 177090]
# close samples  [  3.68756489e-04   3.68756489e-04   3.89109755e-02   7.28249600e-01
#    6.47817105e-02   7.14826720e-01   4.21138815e-02   3.79343754e-03
#    3.66728166e-04   1.40348821e-03   5.41773909e-02   3.37707328e-01
#    7.66286718e-02   6.16266860e-02   7.69001349e-02   4.74288065e-01]
#  Num_samples 14
# density in reconstruction,  density in data,  precision,  recall
# 0.2726739463947297 0.22844766459963645 0.5567953476277157 0.6645880361173815
# DS27641A_h.Karpas_422_LN26838 DS22816_h.NAMALWA_LN20368 DS22823_h.NAMALWA_LN20369 DS29219C_h.Oci_Ly_7_LN28035 DS27648A_h.Karpas_422_LN26836 DS22919_h.RPMI.8226_LN20400 DS27522A_h.b.lymphoblast.mm.1s_LN26797 DS22913C_h.RPMI.8226_LN28562 DS17706_h.Cord.Blood_LN4062 DS12436_GM12865_LN2528 DS17186_CD19+_LN3904 DS18208_CD20+_LN4156 DS24147C_h.G401_LN28708 DS20341_fThymus_LN4803
# doing cluster  9
# cluster length  2371
# name of samples ['611' '612' '613' ..., '142227' '142368' '142373']
# (2371, 176)
#  Num DHSs 7491
# DHSs meeting threshold  [100745 100746 100747 ...,  25822  25821  28958]
# close samples  [ 0.03483078  0.02084515  0.50524624  0.02046585  0.18310781  0.07242609
#   0.02187848  0.24368383  0.48619761]
#  Num_samples 8
# density in reconstruction,  density in data,  precision,  recall
# 0.5577192631157389 0.421138699773061 0.6493731861293122 0.8599730565021
# DS24726A_fLung_LN21205 DS23983C_fLung_LN20738 DS14724_fLung_LN3167 DS20786_fKidney_LN10113 DS23873E_fKidney_LN26814 DS24722A_h.f.Umbilical.Cord_LN21207 DS17878_fStomach_LN4096 DS20351_fSpinal_cord_LN4807
# doing cluster  10
# cluster length  3789
# name of samples ['933' '934' '935' ..., '142166' '142167' '142168']
# (3789, 176)
#  Num DHSs 17227
# DHSs meeting threshold  [ 86477  86476 165698 ..., 166040   2879   2880]
# close samples  [ 0.09219771  0.04877682  0.03540055  0.00706308  0.00578738  0.00531911
#   0.42735455]
#  Num_samples 7
# density in reconstruction,  density in data,  precision,  recall
# 0.5530106394447255 0.4265314415079319 0.6458980011096616 0.8374258773208905
# DS20242_fMuscle_trunk_LN4773 DS20239_fMuscle_leg_LN4772 DS17767_fMuscle_back_LN4072 DS24888A_h.f.Tongue_LN21292 DS24808A_h.f.Tongue_LN21290 DS23123A_h.SJCRH30_LN20413 DS20534_LHCN_M2_LN4866
# doing cluster  11
# cluster length  12052
# name of samples ['175' '177' '178' ..., '142930' '142931' '142932']
# (12052, 176)
#  Num DHSs 48654
# DHSs meeting threshold  [115473 115474 158209 ..., 140256  11013 119412]
# close samples  []
#  Num_samples 0
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
#
# doing cluster  12
# cluster length  4689
# name of samples ['1124' '1164' '1172' ..., '142396' '142397' '142398']
# (4689, 176)
#  Num DHSs 20897
# DHSs meeting threshold  [ 26106  26107  26108 ..., 163262 163261  66199]
# close samples  [ 0.07022716  0.02723092  0.00904763  0.37634748  0.7639094   0.66272495
#   0.46154591  0.63233543]
#  Num_samples 5
# density in reconstruction,  density in data,  precision,  recall
# 0.37642723835957315 0.4016365985548165 0.8353970150771656 0.782961992136304
# DS23929C_h.brain_LN20744 DS23541_h.brain_LN20488 DS21387_SK_N_DZ_LN10005 DS24154A_h.G401_LN20867 DS25067A_h.L1_S8_LN21363
# doing cluster  13
# cluster length  4079
# name of samples ['319' '320' '327' ..., '142520' '142521' '142522']
# (4079, 176)
#  Num DHSs 18290
# DHSs meeting threshold  [178916  88548 178913 ...,  58228  73039  91454]
# close samples  [ 0.68738932  0.46817943  0.08786065  0.09210287  0.07006822  0.073506
#   0.06772221  0.25973799  0.06763647]
#  Num_samples 8
# density in reconstruction,  density in data,  precision,  recall
# 0.6656027884089667 0.5235579551667577 0.7244201209557352 0.9209602255668542
# DS20770_Small_Bowel_Mucosa_LN4899 DS17317_fIntestine.Sm_LN3929 DS38587A_h.HT29_LN32481 DS17313_h.f.Intestine.Lg_LN3928 DS34646A_h.HT29_LN29816 DS34628A_h.LoVo_LN29819 DS17878_fStomach_LN4096 DS21924A_fKidney_Right_LN20841
# doing cluster  14
# cluster length  1541
# name of samples ['5826' '5827' '5828' ..., '142067' '142364' '142365']
# (1541, 176)
#  Num DHSs 7616
# DHSs meeting threshold  [ 70503  70564  70501 ...,  54617  54618 106728]
# close samples  [ 0.8508399   0.58806582  0.00174721  0.00140681  0.00251889  0.00109151
#   0.0015675 ]
#  Num_samples 5
# density in reconstruction,  density in data,  precision,  recall
# 0.7081670168067227 0.5612132352941176 0.7096822041754737 0.8955126105470029
# DS24812A_fHeart_LN26948 DS12531_fHeart_LN2553 DS24799A_fHeart_LN26949 DS24731A_fHeart_LN21203 DS23853E_fHeart_LN26812
# doing cluster  15
# cluster length  1423
# name of samples ['1584' '1585' '1586' ..., '141874' '141875' '141876']
# (1423, 176)
#  Num DHSs 6045
# DHSs meeting threshold  [197733 197734 197735 ..., 147974 147972  13082]
# close samples  [ 0.01477616  0.02900773  0.00835652  0.00157941  0.00271045  0.00637243
#   0.03403091  0.00204804  0.00201943  0.00186792  0.09100485  0.0285017
#   0.0496313   0.00885357  0.00460282  0.08726668]
#  Num_samples 16
# density in reconstruction,  density in data,  precision,  recall
# 0.47423490488006614 0.3352047146401985 0.5659501177291357 0.8006847413713334
# DS24094A_h.CD34+_LN20866 DS25730A_h.CD34+_LN26288 DS25769A_h.CD34+_LN26258 DS25687A_h.CD34+_LN26240 DS24074A_h.CD34+_LN21381 DS16924_K562_LN3817 DS12274_h.CD34+_LN2482 DS24044A_h.CD34+_LN20861 DS15363_K562_LN3327 DS12734_h.CD34+_LN10087 DS26444A_h.CD34+_LN26445 DS23530_h.KBM_7_LN20483 DS12543_NB4_LN2556 DS31642A_h.CD1_LN28530 DS17215_h.CD14+_LN3909 DS25969A_h.CD34+_LN26316
# doing cluster  16
# cluster length  3258
# name of samples ['1292' '1293' '1294' ..., '142822' '142823' '142824']
# (3258, 176)
#  Num DHSs 37688
# DHSs meeting threshold  [ 11060 189815 154184 ...,  22228  73880  87509]
# close samples  [ 0.19665982  0.19835631  0.41159682  0.41159682  0.37095519  0.19557431
#   0.29199724  0.40922661  0.41152964  0.37807421  0.37455767  0.18066162
#   0.20562288  0.19742506  0.19645436  0.19678027  0.19943772  0.1958307
#   0.16237366  0.20742456  0.17986113  0.13505714]
#  Num_samples 22
# density in reconstruction,  density in data,  precision,  recall
# 0.4113173230929546 0.34529317265201365 0.7145215489183023 0.851146544648003
# DS20341_fThymus_LN4803 DS17706_h.Cord.Blood_LN4062 DS18208_CD20+_LN4156 DS14702_hTreg_LN3156 DS12436_GM12865_LN2528 DS17603_iTH2_LN4026 DS17198_CD3+_LN3906 DS17885_CD8+_LN10088 DS17203_CD8+_LN3907 DS17189_CD56+_LN3905 DS17212_CD4+_LN10089 DS17597_TH2_LN4024 DS17186_CD19+_LN3904 DS17881_CD4+_LN4097 DS27522A_h.b.lymphoblast.mm.1s_LN26797 DS22919_h.RPMI.8226_LN20400 DS22913C_h.RPMI.8226_LN28562 DS29219C_h.Oci_Ly_7_LN28035 DS27648A_h.Karpas_422_LN26836 DS27641A_h.Karpas_422_LN26838 DS22823_h.NAMALWA_LN20369 DS22816_h.NAMALWA_LN20368
# doing cluster  17
# cluster length  2393
# name of samples ['654' '655' '656' ..., '140442' '140455' '140456']
# (2393, 176)
#  Num DHSs 8059
# DHSs meeting threshold  [ 99130  99116  99117 ...,  46614 100713 102293]
# close samples  [ 0.02025588  0.041975    0.49406899  0.01977179  0.07651075  0.01140346
#   0.00693805  0.01230693  0.01094024  0.01447847  0.01341669  0.01445508
#   0.57241241  0.35987788  0.36169784]
#  Num_samples 14
# density in reconstruction,  density in data,  precision,  recall
# 0.5063460549873257 0.4254781699253718 0.714855852544242 0.8507238829288616
# DS26693A_h.renal.cell.carcinoma_LN26937 DS27824_h.kidney.tubular_LN29654 DS24471A_h.ACHN_LN26820 DS26685_h.podocytes_LN26974 DS26689_h.kidney.tubular_LN31651 DS39386_h.glomerular_LN32272 DS27192_h.786_O_LN31650 DS24547A_h.ACHN_LN20963 DS10666_HRCEpiC_LN1959 DS24211A_h.Caki_2_LN20836 DS24744A_h.A172_LN21224 DS20493_M059J_LN4859 DS20534_LHCN_M2_LN4866 DS24235A_h.SJSA_1_LN20839
# doing cluster  18
# cluster length  3870
# name of samples ['64' '65' '66' ..., '142964' '142965' '142966']
# (3870, 176)
#  Num DHSs 17193
# DHSs meeting threshold  [ 25501 142243 181158 ...,  51920  51921  51922]
# close samples  [ 0.03772463  0.02136551  0.03139862  0.0185706   0.01776366  0.02707593]
#  Num_samples 6
# density in reconstruction,  density in data,  precision,  recall
# 0.7369278194614087 0.6096570309622134 0.7832280978689818 0.9467332368701404
# DS13337_HMVEC_dBlAd_LN2768 DS13242_HMVEC_dBlNeo_LN2746 DS13150_HMVEC_dLyNeo_LN2725 DS13372_HMVEC_LBl_LN2776 DS13185_HMVEC_Lly_LN2732 DS10060_HUVEC_LN1812
# doing cluster  19
# cluster length  6122
# name of samples ['209' '210' '211' ..., '142058' '142059' '142060']
# (6122, 176)
#  Num DHSs 34720
# DHSs meeting threshold  [ 14042  14041  46658 ..., 124730  56555 109877]
# close samples  [ 0.35685794]
#  Num_samples 1
# density in reconstruction,  density in data,  precision,  recall
# 0.6955069124423963 0.6386232718894009 0.8745651813814809 0.9524647093311686
# DS22985_MCF10a_ER_SRC_LN20386
# doing cluster  20
# cluster length  2483
# name of samples ['280' '281' '282' ..., '141172' '141173' '141174']
# (2483, 176)
#  Num DHSs 11006
# DHSs meeting threshold  [131423 114523 126059 ...,  80546  80547  92676]
# close samples  [ 0.06597892  0.01814706  0.28629646  0.00200548  0.00313807  0.00096197
#   0.00133274]
#  Num_samples 7
# density in reconstruction,  density in data,  precision,  recall
# 0.3820643285480647 0.33223436567067316 0.6716833701375913 0.7724253789654634
# DS31397A_h.Trophoblast_LN28443 DS35787A_h.Trophoblast_LN30439 DS30582A_h.Trophoblast_LN28078 DS30557A_h.Trophoblast_LN28110 DS20346_fPlacenta_LN10066 DS19317_h.Trophoblast_LN10001 DS27166A_h.PC9_LN26744
# doing cluster  21
# cluster length  2893
# name of samples ['15' '16' '17' ..., '141441' '141442' '141443']
# (2893, 176)
#  Num DHSs 12283
# DHSs meeting threshold  [  9407 106974 106972 ...,  45075  57478  87750]
# close samples  [ 0.04820414  0.05849926  0.21241746  0.13400446  0.02599195  0.19340909
#   0.04887411  0.04819486  0.04997635  0.18345383  0.04135818  0.05473762
#   0.30425635  0.40568447  0.29514092  0.10367523  0.23673884  0.03117195
#   0.24536921  0.04180175  0.05389667  0.0593081   0.06129439  0.04763129
#   0.05898425  0.05913921  0.22907155  0.13455382  0.05327542]
#  Num_samples 29
# density in reconstruction,  density in data,  precision,  recall
# 0.6809860558607775 0.5451212356859916 0.735740316277229 0.919114617666447
# DS11923_NHDF_neo_LN2368 DS15115_HFF_P5_LN3259 DS12863_NHDF_Ad_LN2643 DS18224_Skin_fibroblast_LN4158 DS19706_fSkin_Fibroblast_LN4632 DS12829_NHLF_LN2632 DS23559_h.EH_LN20491 DS12374_AG10803_LN2497 DS26113A_h.Fibroblast_LN26368 DS20909_RPMI.7951_LN4931 DS19174_fSkin_Fibroblast_LN4486 DS26410A_h.AL_LN26455 DS23825A_h.EL_LN20660 DS19745_fSkin_Fibroblast_LN4644 DS19943_fSkin_Fibroblast_LN4690 DS19449_fSkin_Fibroblast_LN4535 DS19561_fSkin_Fibroblast_LN4587 DS14426_HSMM_LN3058 DS24640A_h.MG_63_LN21068 DS20548_LHCN_M2_LN4870 DS26313A_h.ELR_LN26395 DS11949_SKMC_LN2373 DS24235A_h.SJSA_1_LN20839 DS20493_M059J_LN4859 DS14790_HAsp_LN3184 DS15192_HAh_LN3285 DS13573_HPdLF_LN2823 DS13219_IMR90_LN2741 DS13368_HMF_LN2775
# doing cluster  22
# cluster length  2472
# name of samples ['303' '304' '305' ..., '142479' '142480' '142481']
# (2472, 176)
#  Num DHSs 9475
# DHSs meeting threshold  [103019 103017 103018 ...,  31405 141894  71005]
# close samples  [ 0.79889909  0.59509665  0.06605975  0.0694334   0.05727673  0.00371875
#   0.00488628  0.36622802  0.32470028  0.00576197]
#  Num_samples 8
# density in reconstruction,  density in data,  precision,  recall
# 0.50155672823219 0.36067282321899735 0.6171287284970277 0.8581879366472804
# DS17313_h.f.Intestine.Lg_LN3928 DS17317_fIntestine.Sm_LN3929 DS20770_Small_Bowel_Mucosa_LN4899 DS38587A_h.HT29_LN32481 DS34646A_h.HT29_LN29816 DS34628A_h.LoVo_LN29819 DS19794_T_47D_LN4656 DS17878_fStomach_LN4096
# doing cluster  23
# cluster length  5273
# name of samples ['2' '3' '4' ..., '142359' '142391' '142394']
# (5273, 176)
#  Num DHSs 25427
# DHSs meeting threshold  [ 43029 189737  41839 ...,  73013  71161 164137]
# close samples  [ 0.01363419  0.02346469  0.01274921  0.38100603  0.00525711  0.03652884]
#  Num_samples 6
# density in reconstruction,  density in data,  precision,  recall
# 0.7083415267235615 0.5864238801274236 0.7710473229322822 0.9313482216708023
# DS34890A_h.FUCCI.cells_LN30023 DS26455A_h.iPSC_LN26496 DS15153_h.IPS_LN10036 DS11909_H7_hESC_LN2365 DS19310_Mesendoderm_LN4515 DS32096A_h.neuronal_stem_cell_LN28669
# doing cluster  24
# cluster length  3834
# name of samples ['599' '600' '601' ..., '142282' '142283' '142284']
# (3834, 176)
#  Num DHSs 19077
# DHSs meeting threshold  [136682 194946 194947 ..., 127887  58915  48968]
# close samples  [ 0.61876756  0.05003076  0.03450516  0.0325895   0.02489618  0.10956638
#   0.25486656  0.03244293  0.03460379  0.0376618   0.05674107  0.13175298
#   0.13507914  0.13455054  0.03733576  0.45329615  0.12291044  0.06302348
#   0.37341869  0.07813622]
#  Num_samples 19
# density in reconstruction,  density in data,  precision,  recall
# 0.374413388401023 0.2977517705255433 0.6375017500423694 0.801638189837293
# DS23833A_h.f.Eye_LN20656 DS24728A_h.f.Eye_LN21204 DS23368A_h.f.Retina_LN20458 DS23341_h.f.Retina_LN20451 DS24796A_h.f.Eye_LN21208 DS23339E_h.f.Retina_LN26813 DS24833A_fSpinalCord_LN21289 DS23286_h.f.Retina_LN20434 DS24872A_fBrain_LN21323 DS23849C_fBrain_LN28707 DS20351_fSpinal_cord_LN4807 DS21924A_fKidney_Right_LN20841 DS32096A_h.neuronal_stem_cell_LN28669 DS25067A_h.L1_S8_LN21363 DS26980A_h.Bipolar_neuron_LN26594 DS26986A_h.Bipolar_neuron_LN26591 DS24154A_h.G401_LN20867 DS15192_HAh_LN3285 DS23873E_fKidney_LN26814
# doing cluster  25
# cluster length  7580
# name of samples ['920' '947' '948' ..., '142352' '142353' '142354']
# (7580, 176)
#  Num DHSs 30027
# DHSs meeting threshold  [ 36624  36661  36666 ..., 134250  22741 134942]
# close samples  [ 0.09098835  0.66689226  0.70424348  0.08144473  0.04893427  0.08925897
#   0.10423869  0.10752086]
#  Num_samples 6
# density in reconstruction,  density in data,  precision,  recall
# 0.6995148810514981 0.5682607875134601 0.7423864916763208 0.9138592875492044
# DS24888A_h.f.Tongue_LN21292 DS24808A_h.f.Tongue_LN21290 DS17767_fMuscle_back_LN4072 DS23123A_h.SJCRH30_LN20413 DS20239_fMuscle_leg_LN4772 DS20242_fMuscle_trunk_LN4773
# doing cluster  26
# cluster length  7667
# name of samples ['28' '29' '30' ..., '142528' '142529' '142530']
# (7667, 176)
#  Num DHSs 41984
# DHSs meeting threshold  [   583 173008 124920 ..., 141338  51363 145065]
# close samples  []
#  Num_samples 0
# density in reconstruction,  density in data,  precision,  recall
# 0 0 0 0
#
# doing cluster  27
# cluster length  3006
# name of samples ['368' '369' '370' ..., '142174' '142175' '142176']
# (3006, 176)
#  Num DHSs 12211
# DHSs meeting threshold  [125719   4390   4391 ...,  11130  71071  30503]
# close samples  [ 0.0146044   0.01509922  0.01326083  0.01442972  0.01975135  0.05650703
#   0.03313034  0.01176802  0.46466903  0.29985273  0.01559446]
#  Num_samples 11
# density in reconstruction,  density in data,  precision,  recall
# 0.6364083054771779 0.5109551000960386 0.7127616017219798 0.887763725375918
# DS12763_HEEpiC_LN2613 DS22985_MCF10a_ER_SRC_LN20386 DS22991_MCF10a_ER_SRC_LN20387 DS18406_vHMEC_LN10000 DS10518_SAEC_LN1926 DS25027C_h.PC3_LN28558 DS22980_MCF10a_ER_SRC_LN20496 DS25129C_h.PC3_LN21648 DS24790A_HeLa_S3_LN21209 DS27166A_h.PC9_LN26744 DS26313A_h.ELR_LN26395
# doing cluster  28
# cluster length  7374
# name of samples ['1984' '1985' '1986' ..., '142703' '142704' '142705']
# (7374, 176)
#  Num DHSs 41329
# DHSs meeting threshold  [39129 80102 80101 ..., 92960 64142 64141]
# close samples  [ 0.02347807  0.0192471   0.04446385  0.02958229  0.58959213  0.02816304
#   0.0252648   0.02634855  0.02524647  0.02852684  0.03399569  0.0531841 ]
#  Num_samples 11
# density in reconstruction,  density in data,  precision,  recall
# 0.5945440027803501 0.5160585017344194 0.788261540339856 0.9081454328459997
# DS17212_CD4+_LN10089 DS17885_CD8+_LN10088 DS17597_TH2_LN4024 DS17198_CD3+_LN3906 DS17203_CD8+_LN3907 DS17189_CD56+_LN3905 DS17603_iTH2_LN4026 DS14702_hTreg_LN3156 DS17881_CD4+_LN4097 DS14108_h.Tn_LN2964 DS18015_TH1_LN4128
# doing cluster  29
# cluster length  3599
# name of samples ['2030' '2031' '2032' ..., '142370' '142371' '142372']
# (3599, 176)
#  Num DHSs 11156
# DHSs meeting threshold  [ 70628  70627  70626 ...,  31392 156237  36627]
# close samples  [ 0.05479468  0.05162437  0.04780494  0.0516718   0.05097267]
#  Num_samples 5
# density in reconstruction,  density in data,  precision,  recall
# 0.7504840444603801 0.6031731803513805 0.7369213128851942 0.9168970129291127
# DS23853E_fHeart_LN26812 DS24799A_fHeart_LN26949 DS12531_fHeart_LN2553 DS24812A_fHeart_LN26948 DS24731A_fHeart_LN21203
# doing cluster  30
# cluster length  2860
# name of samples ['596' '597' '598' ..., '140393' '140394' '141267']
# (2860, 176)
#  Num DHSs 25510
# DHSs meeting threshold  [195310 195309  71806 ...,  85235  85234  85233]
# close samples  [ 0.20616168  0.34858832  0.33979245  0.10926514  0.34416948  0.42560402
#   0.09210232  0.34401417  0.30221674  0.23520992  0.1711749   0.09051008
#   0.12513482  0.10922443  0.25362314  0.43054196  0.15349987  0.26181365]
#  Num_samples 18
# density in reconstruction,  density in data,  precision,  recall
# 0.390358900648983 0.3724095126094342 0.8150185500292895 0.8543008017403203
# DS25067A_h.L1_S8_LN21363 DS24154A_h.G401_LN20867 DS26980A_h.Bipolar_neuron_LN26594 DS23541_h.brain_LN20488 DS26986A_h.Bipolar_neuron_LN26591 DS23849C_fBrain_LN28707 DS24872A_fBrain_LN21323 DS23286_h.f.Retina_LN20434 DS24833A_fSpinalCord_LN21289 DS23339E_h.f.Retina_LN26813 DS20351_fSpinal_cord_LN4807 DS24796A_h.f.Eye_LN21208 DS23368A_h.f.Retina_LN20458 DS24728A_h.f.Eye_LN21204 DS23833A_h.f.Eye_LN20656 DS23341_h.f.Retina_LN20451 DS21924A_fKidney_Right_LN20841 DS32096A_h.neuronal_stem_cell_LN28669
# doing cluster  31
# cluster length  2041
# name of samples ['2574' '4511' '4512' ..., '140620' '140621' '140622']
# (2041, 176)
#  Num DHSs 37401
# DHSs meeting threshold  [50136 50135 73442 ..., 67298 85959 12588]
# close samples  [ 0.39587808  0.20236917  0.13856944  0.40961092  0.40905725  0.40566536
#   0.40241912  0.21651018  0.61591354  0.20505955  0.20801873  0.18228385
#   0.21451329  0.21138973  0.10046194]
#  Num_samples 14
# density in reconstruction,  density in data,  precision,  recall
# 0.41058107690015927 0.3555214337278988 0.7498813876252407 0.8660155998195063
# DS17881_CD4+_LN4097 DS17212_CD4+_LN10089 DS17203_CD8+_LN3907 DS17885_CD8+_LN10088 DS17189_CD56+_LN3905 DS17198_CD3+_LN3906 DS17603_iTH2_LN4026 DS17597_TH2_LN4024 DS14702_hTreg_LN3156 DS20346_fPlacenta_LN10066 DS35787A_h.Trophoblast_LN30439 DS31397A_h.Trophoblast_LN28443 DS30557A_h.Trophoblast_LN28110 DS30582A_h.Trophoblast_LN28078
